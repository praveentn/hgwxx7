# %% [markdown]
# # Udemy | Python | Pandas | Visualizations | Sub plots | Violin plots | Box plots

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

# %%
warnings.filterwarnings('ignore')

# %%
# %matplotlib inline

# %%
sns.set_style('darkgrid')

# %%
os.getcwd()
# Out:
# 'C:\\Users\\praveen\\DS_Notebooks\\hgwxx7'

# %%
# os.listdir()

# %%
movies = pd.read_csv('plots_ds_python_sns_1.csv')

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'CriticRating', 'AudienceRating', 'BudgetMillions',
#        'Year'],
#       dtype='object')

# %%
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating)

# %%
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating)

# %%
f, ax = plt.subplots(1,2)

# %%
f, axii = plt.subplots(1,2, figsize=(12,7))
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axii[1])

# %%
f, axii = plt.subplots(2,2, figsize=(12,7))
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[0,1])
#k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axii[1])

# %%
f, axii = plt.subplots(2,2, figsize=(12,7))
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[1,1])

# %%
f, axii = plt.subplots(1,2, figsize=(12,7))
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axii[1])
k1.set(xlim=(-25,200))
# Out:
# [(-25, 200)]

# %%
f, axii = plt.subplots(1,2, figsize=(12,7))
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axii[1])
k1.set(xlim=(-25,200))
k2.set(xlim=(-25,200))
# Out:
# [(-25, 200)]

# %%
f, axii = plt.subplots(1,2, figsize=(12,7), sharex=True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axii[1])
k1.set(xlim=(-25,200))
# Out:
# [(-25, 200)]

# %%
f, axii = plt.subplots(1,2, figsize=(12,7), sharex=True, sharey=True)
k1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[0])
k2 = sns.kdeplot(movies.BudgetMillions, movies.AudienceRating, ax=axii[1])
k1.set(xlim=(-25,200))
# Out:
# [(-25, 200)]

# %%
vp1 = sns.violinplot(data=movies, x='Genre', y='CriticRating')

# %%
bp1 = sns.boxplot(data=movies, x='Genre', y='CriticRating')

# %%
bp2 = sns.boxplot(data=movies[movies.Genre=='Comedy'], x='Year', y='CriticRating')

# %%
vp2 = sns.violinplot(data=movies[movies.Genre=='Comedy'], x='Year', y='CriticRating')

# %%
# facet grid

# %%
fg1 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')

# %%
#fg1 = fg1.map()

plt.scatter(movies.CriticRating, movies.AudienceRating)

# %%
# fg1 = fg1.map(plt.scatter, movies.CriticRating, movies.AudienceRating)

# %%
fg1 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
fg1 = fg1.map(plt.scatter, 'CriticRating', 'AudienceRating')

# %%
fg2 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
fg2 = fg2.map(plt.hist, 'BudgetMillions')

# %%
fg3 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
fg3 = fg3.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)

# %%
fg4 = sns.FacetGrid(movies, row='Genre', col='Year', hue='Genre')
kws = dict(s=50, linewidth=0.5, edgecolor='black')
fg4 = fg4.map(plt.scatter, 'CriticRating', 'AudienceRating', **kws)
fg4.set(xlim=(0,100), ylim=(0,100))

for ax in fg4.axes.flat:
    ax.plot((20,60),(20,60), c='gray', ls='--')
fg4.add_legend()

# %%
f, axii = plt.subplots(2,2, figsize=(12,7))
dbp1 = sns.kdeplot(movies.BudgetMillions, movies.CriticRating, ax=axii[0,0])
dbp2 = sns.violinplot(data=movies, x='Genre', y='CriticRating', ax=axii[0,1])
dbp3 = sns.boxplot(data=movies, x='Genre', y='CriticRating', ax=axii[1,0])
dbp4 = axii[1,1].hist(movies.CriticRating, bins=13)

dbp1.set(xlim=(0,100))
#dbp2.set(xlim=(0,100))
# Out:
# [(0, 100)]
