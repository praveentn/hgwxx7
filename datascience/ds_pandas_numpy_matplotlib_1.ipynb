# %% [markdown]
# # Pandas | Numpy | Matplotlib

# %%
import pandas as pd

# %%
s1 = pd.Series([1,2,3], index=['a','b','c'])

# %%
s1
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
s1.values
# Out:
# array([1, 2, 3], dtype=int64)

# %%
s1.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
s1[s1>2]
# Out:
# c    3
# dtype: int64

# %%
s1.isnull()
# Out:
# a    False
# b    False
# c    False
# dtype: bool

# %%
s2 = pd.Series([1,2,0], index=['a','b','c'])

# %%
s2
# Out:
# a    1
# b    2
# c    0
# dtype: int64

# %%
s1+s2
# Out:
# a    2
# b    4
# c    3
# dtype: int64

# %%
s3 = pd.Series([1,2,3], index=['a','b','d'])

# %%
ss23 = s2 + s3

# %%
# if index is present only in one series
# then we'll get Not a Number -> NaN

# %%
ss23
# Out:
# a    2.0
# b    4.0
# c    NaN
# d    NaN
# dtype: float64

# %%
ss23.isnull()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
ss23_2 = s2.add(s3, fill_value=5)

# %%
ss23_2
# Out:
# a    2.0
# b    4.0
# c    5.0
# d    8.0
# dtype: float64

# %%
# indices c and d has now values
# 0+5 and 3+5

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\praveen\\DS_Notebooks\\hgwxx7'

# %%
#os.chdir('C:\\Users\\praveen\\Desktop\\ds\\sl\\dataset\\')

# %%
#os.listdir()

# %%
studs = pd.read_csv('ds_pandas_numpy_matplotlib_1.csv', index_col='ID')

# %%
studs.head()
# Out:
#      Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 70        0     4    1       1     1    57     52     41     47   57
# 121       1     4    2       1     3    68     59     53     63   61
# 86        0     4    3       1     1    44     33     54     58   31
# 141       0     4    3       1     3    63     44     47     53   56
# 172       0     4    2       1     2    47     52     57     53   61

# %%
cat_gender = pd.Categorical(studs.Gender)

# %%
cat_gender.describe()
# Out:
#             counts  freqs
# categories
# 0               91  0.455
# 1              109  0.545

# %%
# reading categorical variables

# %%
# also we can set a column as type categorical

# %%
studs.Gender = pd.Categorical(studs.Gender)

# %%
studs.Gender.describe()
# Out:
# count     200
# unique      2
# top         1
# freq      109
# Name: Gender, dtype: int64

# %%
# gender vanishes if we run describe()
# as Gender is no longer a quantitative value

# %%
studs.describe()
# Out:
#              Race         SEB      School        Prog        Read       Write  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     3.430000    2.055000    1.160000    2.025000   52.230000   52.775000
# std      1.039472    0.724291    0.367526    0.690477   10.252937    9.478586
# min      1.000000    1.000000    1.000000    1.000000   28.000000   31.000000
# 25%      3.000000    2.000000    1.000000    2.000000   44.000000   45.750000
# 50%      4.000000    2.000000    1.000000    2.000000   50.000000   54.000000
# 75%      4.000000    3.000000    1.000000    2.250000   60.000000   60.000000
# max      4.000000    3.000000    2.000000    3.000000   76.000000   67.000000
#
#             Math1       Math2         SST
# count  200.000000  200.000000  200.000000
# mean    52.645000   51.850000   52.405000
# std      9.368448    9.900891   10.735793
# min     33.000000   26.000000   26.000000
# 25%     45.000000   44.000000   46.000000
# ...

# %%
studs.Gender.unique()
# Out:
# [0, 1]
# Categories (2, int64): [0, 1]

# %%
type(studs.Gender)
# Out:
# pandas.core.series.Series

# %%
studs.dtypes[studs.dtypes == 'int64']
# Out:
# Race      int64
# SEB       int64
# School    int64
# Prog      int64
# Read      int64
# Write     int64
# Math1     int64
# Math2     int64
# SST       int64
# dtype: object

# %%
studs.dtypes[studs.dtypes == 'bool']
# Out:
# Series([], dtype: object)

# %%
studs.dtypes[studs.dtypes == 'float64']
# Out:
# Series([], dtype: object)

# %%
studs.dtypes[studs.dtypes == 'category']
# Out:
# Gender    category
# dtype: object

# %%
studs.dtypes
# Out:
# Gender    category
# Race         int64
# SEB          int64
# School       int64
# Prog         int64
# Read         int64
# Write        int64
# Math1        int64
# Math2        int64
# SST          int64
# dtype: object

# %%
# how to find the categorical type

# %%
studs.mean()
# Out:
# Gender     0.545
# Race       3.430
# SEB        2.055
# School     1.160
# Prog       2.025
# Read      52.230
# Write     52.775
# Math1     52.645
# Math2     51.850
# SST       52.405
# dtype: float64

# %%
# plots

# %%
studs.boxplot()

# %% [markdown]
# ## Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
studs.boxplot()
plt.show()

# %%
# alternately we can use %matplotlib inline
# we need not have to use plt.show() each time

# %%
# %matplotlib inline

# %%
studs.boxplot('Read')

# %%
studs.Read.median()
# Out:
# 50.0

# %%
studs.boxplot('Read')
plt.text(x=0.9, y=studs['Read'].median(), s='median')
# Out:
# Text(0.9,50,'median')

# %%
studs.boxplot('Write')
plt.text(x=0.9, y=studs['Write'].median(), s='median')
# Out:
# Text(0.9,54,'median')

# %%
# boxplot gives an idea about skewness

# %%
test1 = pd.DataFrame([1,2,3,2,1,4,2,3,2,1,2,3,4,5,-90])

# %%
test1.boxplot()

# %%
test2 = pd.DataFrame([1,2,3,2,1,4,2,3,2,1,2,3,4,5,90])

# %%
test2.boxplot()

# %%
test1.skew()
# Out:
# 0   -3.856594
# dtype: float64

# %%
test2.skew()
# Out:
# 0    3.85484
# dtype: float64

# %%
test1.mean(), test2.mean()
# Out:
# (0   -3.666667
#  dtype: float64, 0    8.333333
#  dtype: float64)

# %%
test3 = pd.DataFrame([1,2,3,2,1,4,2,3,2,1,2,3,4,5,-90,90])

# %%
test3.boxplot()

# %%
test3.mean()
# Out:
# 0    2.1875
# dtype: float64

# %%
test3.skew()
# Out:
# 0   -0.227555
# dtype: float64

# %%
pd.crosstab(studs.Gender,studs.Read)
# Out:
# Read    28  31  34  35  36  37  39  41  42  43 ...  57  60  61  63  65  66  \
# Gender                                         ...
# 0        0   1   4   0   1   2   3   0   5   0 ...   5   5   0  10   5   0
# 1        1   0   2   1   2   0   5   2   8   2 ...   9   4   1   6   4   1
#
# Read    68  71  73  76
# Gender
# 0        5   0   3   1
# 1        6   2   2   1
#
# [2 rows x 30 columns]

# %%
# groups in pandas

# %%
grp = studs.groupby(studs.Gender)

# %%
g = grp.get_group(1)

# %%
g
# Out:
#     Gender  Race  SEB  School  Prog  Read  Write  Math1  Math2  SST
# ID
# 121      1     4    2       1     3    68     59     53     63   61
# 82       1     4    3       1     2    68     62     65     69   61
# 8        1     1    1       1     2    39     44     52     44   48
# 129      1     4    1       1     1    44     44     46     47   51
# 173      1     4    1       1     1    50     62     61     63   51
# 57       1     4    2       1     2    71     65     72     66   56
# 100      1     4    3       1     2    63     65     71     69   71
# 1        1     1    1       1     3    34     44     40     39   41
# 194      1     4    3       2     2    63     63     69     61   61
# 88       1     4    3       1     2    68     60     64     69   66
# 99       1     4    3       1     1    47     59     56     66   61
# 47       1     3    1       1     2    47     46     49     33   41
# 120      1     4    3       1     2    63     52     54     50   51
# ...

# %%
grp

# %%
g.boxplot()

# %%
g.boxplot('Math1')

# %% [markdown]
# # Numpy

# %%
import numpy as np

# %%
normal = pd.DataFrame(np.random.normal(size=5))

# %%
normal.plot(kind='density')
plt.vlines(normal.mean(), ymin=0, ymax=0.7)

# %%
# line representing the mean!

# %%
studs.Math1.plot(kind='density')

# %%
# density refers to probability density function (pdf)

# %%
studs.dtypes
# Out:
# Gender    category
# Race         int64
# SEB          int64
# School       int64
# Prog         int64
# Read         int64
# Write        int64
# Math1        int64
# Math2        int64
# SST          int64
# dtype: object

# %%
studs.Prog.plot(kind='pie')

# %%
studs.Race.plot(kind='pie')

# %%
# to do - plot a pie chart for categorical values

# %%
studs.Gender.value_counts().plot.pie()

# %%
studs.Read.plot(kind='box', figsize=(5,5))
plt.hlines(studs.Read.mean(), xmin=0.9, xmax=1.1, linewidth=2.3, color='black')

# %%
studs.Race.value_counts().plot.pie()

# %%
studs.Race.value_counts().plot(kind='pie', autopct='%1.1f%%')
