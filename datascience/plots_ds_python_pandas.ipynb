# %% [markdown]
# # Udemy | Data Science | Python | Pandas | Seaborn | Kirill Eremenko

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\praveen\\DS_Notebooks\\hgwxx7'

# %%
# os.listdir()

# %%
import pandas as pd

# %%
data = pd.read_csv('plots_ds_python_pandas.csv')

# %%
data.head()
# Out:
#            Country Name Country Code  Birth rate  Internet users  \
# 0                 Aruba          ABW      10.244            78.9
# 1           Afghanistan          AFG      35.253             5.9
# 2                Angola          AGO      45.985            19.1
# 3               Albania          ALB      12.877            57.2
# 4  United Arab Emirates          ARE      11.044            88.0
#
#           Income Group
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
data.describe()
# Out:
#        Birth rate  Internet users
# count  195.000000      195.000000
# mean    21.469928       42.076471
# std     10.605467       29.030788
# min      7.900000        0.900000
# 25%     12.120500       14.520000
# 50%     19.680000       41.000000
# 75%     29.759500       66.225000
# max     49.661000       96.546800

# %%
len(data)
# Out:
# 195

# %%
max(data['Internet users'])
# Out:
# 96.5468

# %%
max(data['Birth rate'])
# Out:
# 49.661

# %%
data.columns
# Out:
# Index(['Country Name', 'Country Code', 'Birth rate', 'Internet users',
#        'Income Group'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 5 columns):
# Country Name      195 non-null object
# Country Code      195 non-null object
# Birth rate        195 non-null float64
# Internet users    195 non-null float64
# Income Group      195 non-null object
# dtypes: float64(2), object(3)
# memory usage: 7.7+ KB

# %%
data.describe().transpose()
# Out:
#                 count       mean        std  min      25%    50%      75%  \
# Birth rate      195.0  21.469928  10.605467  7.9  12.1205  19.68  29.7595
# Internet users  195.0  42.076471  29.030788  0.9  14.5200  41.00  66.2250
#
#                     max
# Birth rate      49.6610
# Internet users  96.5468

# %%
data.columns = ['A', 'B', 'C', 'D', 'E']

# %%
data.head(2)
# Out:
#              A    B       C     D            E
# 0        Aruba  ABW  10.244  78.9  High income
# 1  Afghanistan  AFG  35.253   5.9   Low income

# %%
data.columns = ['Country Name', 'Country Code', 
                'Birth rate', 'Internet users', 'Income Group']

# %%
data.head(2)
# Out:
#   Country Name Country Code  Birth rate  Internet users Income Group
# 0        Aruba          ABW      10.244            78.9  High income
# 1  Afghanistan          AFG      35.253             5.9   Low income

# %%
data[10:13]
# Out:
#    Country Name Country Code  Birth rate  Internet users         Income Group
# 10   Azerbaijan          AZE      18.300         58.7000  Upper middle income
# 11      Burundi          BDI      44.151          1.3000           Low income
# 12      Belgium          BEL      11.200         82.1702          High income

# %%
data[::-1]
# Out:
#                        Country Name Country Code  Birth rate  Internet users  \
# 194                        Zimbabwe          ZWE      35.715        18.50000
# 193                          Zambia          ZMB      40.471        15.40000
# 192                Congo, Dem. Rep.          COD      42.394         2.20000
# 191                    South Africa          ZAF      20.850        46.50000
# 190                     Yemen, Rep.          YEM      32.947        20.00000
# 189                           Samoa          WSM      26.172        15.30000
# 188              West Bank and Gaza          PSE      30.394        46.60000
# 187                         Vanuatu          VUT      26.739        11.30000
# 186                         Vietnam          VNM      15.537        43.90000
# 185           Virgin Islands (U.S.)          VIR      10.700        45.30000
# 184                   Venezuela, RB          VEN      19.842        54.90000
# ...

# %%
data[::17]
# Out:
#          Country Name Country Code  Birth rate  Internet users  \
# 0               Aruba          ABW      10.244        78.90000
# 17            Bahrain          BHR      15.040        90.00004
# 34      Cote d'Ivoire          CIV      37.320         8.40000
# 51   Egypt, Arab Rep.          EGY      28.032        29.40000
# 68             Greece          GRC       8.500        59.86630
# 85             Israel          ISR      21.300        70.80000
# 102     Liechtenstein          LIE       9.200        93.80000
# 119          Mongolia          MNG      24.275        20.00000
# 136            Panama          PAN      19.680        44.03000
# 153   Solomon Islands          SLB      30.578         8.00000
# 170        Tajikistan          TJK      30.792        16.00000
# 187           Vanuatu          VUT      26.739        11.30000
#
#             Income Group
# 0            High income
# 17           High income
# 34   Lower middle income
# 51   Lower middle income
# ...

# %%
data[['Country Code', 'Internet users']].tail()
# Out:
#     Country Code  Internet users
# 190          YEM            20.0
# 191          ZAF            46.5
# 192          COD             2.2
# 193          ZMB            15.4
# 194          ZWE            18.5

# %%
data[['Country Code', 'Internet users']].tail()[2:3]
# Out:
#     Country Code  Internet users
# 192          COD             2.2

# %%
data[['Country Code', 'Internet users']][2:3]
# Out:
#   Country Code  Internet users
# 2          AGO            19.1

# %%
data.columns = ['CountryName', 'CountryCode', 
                'BirthRate', 'InternetUsers', 'IncomeGroup']

# %%
data.columns
# Out:
# Index(['CountryName', 'CountryCode', 'BirthRate', 'InternetUsers',
#        'IncomeGroup'],
#       dtype='object')

# %%
data.dtypes
# Out:
# CountryName       object
# CountryCode       object
# BirthRate        float64
# InternetUsers    float64
# IncomeGroup       object
# dtype: object

# %%
data['Product'] = data.BirthRate * data.InternetUsers

# %%
data[0:2]
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup   Product
# 0        Aruba         ABW     10.244           78.9  High income  808.2516
# 1  Afghanistan         AFG     35.253            5.9   Low income  207.9927

# %%
data.drop('Product', axis=1) # this won't drop from the actual object
# Out:
#                         CountryName CountryCode  BirthRate  InternetUsers  \
# 0                             Aruba         ABW     10.244       78.90000
# 1                       Afghanistan         AFG     35.253        5.90000
# 2                            Angola         AGO     45.985       19.10000
# 3                           Albania         ALB     12.877       57.20000
# 4              United Arab Emirates         ARE     11.044       88.00000
# 5                         Argentina         ARG     17.716       59.90000
# 6                           Armenia         ARM     13.308       41.90000
# 7               Antigua and Barbuda         ATG     16.447       63.40000
# 8                         Australia         AUS     13.200       83.00000
# 9                           Austria         AUT      9.400       80.61880
# 10                       Azerbaijan         AZE     18.300       58.70000
# 11                          Burundi         BDI     44.151        1.30000
# ...

# %%
data = data.drop('Product', axis=1)

# %%
data[7:8]
# Out:
#            CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 7  Antigua and Barbuda         ATG     16.447           63.4  High income

# %%
data.head()
# Out:
#             CountryName CountryCode  BirthRate  InternetUsers  \
# 0                 Aruba         ABW     10.244           78.9
# 1           Afghanistan         AFG     35.253            5.9
# 2                Angola         AGO     45.985           19.1
# 3               Albania         ALB     12.877           57.2
# 4  United Arab Emirates         ARE     11.044           88.0
#
#            IncomeGroup
# 0          High income
# 1           Low income
# 2  Upper middle income
# 3  Upper middle income
# 4          High income

# %%
myCountry = data.CountryCode == 'ABW'

# %%
myCountry
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10     False
# 11     False
# 12     False
# 13     False
# 14     False
# 15     False
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181    False
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Name: CountryCode, Length: 195, dtype: bool

# %%
data[data.CountryCode == 'ABW']
# Out:
#   CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 0       Aruba         ABW     10.244           78.9  High income

# %%
data[data.InternetUsers > 90]
# Out:
#        CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 17         Bahrain         BHR      15.04       90.00004  High income
# 22         Bermuda         BMU      10.40       95.30000  High income
# 47         Denmark         DNK      10.00       94.62970  High income
# 56         Finland         FIN      10.70       91.51440  High income
# 84         Iceland         ISL      13.40       96.54680  High income
# 102  Liechtenstein         LIE       9.20       93.80000  High income
# 106     Luxembourg         LUX      11.30       93.77650  High income
# 130    Netherlands         NLD      10.20       93.95640  High income
# 131         Norway         NOR      11.60       95.05340  High income
# 163         Sweden         SWE      11.80       94.78360  High income

# %%
# filters

f1 = data.InternetUsers > 80
f2 = data.BirthRate > 10

# %%
f1 and f2
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-7bafe38a9153> in <module>()
# ----> 1 f1 and f2
#
# E:\Python\Anaconda\lib\site-packages\pandas\core\generic.py in __nonzero__(self)
#    1119         raise ValueError("The truth value of a {0} is ambiguous. "
#    1120                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# -> 1121                          .format(self.__class__.__name__))
#    1122
#    1123     __bool__ = __nonzero__
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
# bitwise operator
f0 = f1 & f2

# %%
f0
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
# 5      False
# 6      False
# 7      False
# 8       True
# 9      False
# 10     False
# 11     False
# 12      True
# 13     False
# 14     False
# 15     False
# 16     False
# 17      True
# 18     False
# 19     False
# 20     False
# 21     False
# 22      True
# 23     False
# 24     False
# 25     False
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 165    False
# 166    False
# 167    False
# 168    False
# 169    False
# 170    False
# 171    False
# 172    False
# 173    False
# 174    False
# 175    False
# 176    False
# 177    False
# 178    False
# 179    False
# 180    False
# 181     True
# 182    False
# 183    False
# 184    False
# 185    False
# 186    False
# 187    False
# 188    False
# 189    False
# 190    False
# 191    False
# 192    False
# 193    False
# 194    False
# Length: 195, dtype: bool

# %%
data[f0]
# Out:
#               CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 4    United Arab Emirates         ARE     11.044       88.00000  High income
# 8               Australia         AUS     13.200       83.00000  High income
# 12                Belgium         BEL     11.200       82.17020  High income
# 17                Bahrain         BHR     15.040       90.00004  High income
# 22                Bermuda         BMU     10.400       95.30000  High income
# 30                 Canada         CAN     10.900       85.80000  High income
# 31            Switzerland         CHE     10.200       86.34000  High income
# 56                Finland         FIN     10.700       91.51440  High income
# 58                 France         FRA     12.300       81.91980  High income
# 61         United Kingdom         GBR     12.200       89.84410  High income
# 84                Iceland         ISL     13.400       96.54680  High income
# ...

# %%
data[f0].IncomeGroup.unique
# Out:
# <bound method Series.unique of 4      High income
# 8      High income
# 12     High income
# 17     High income
# 22     High income
# 30     High income
# 31     High income
# 56     High income
# 58     High income
# 61     High income
# 84     High income
# 106    High income
# 130    High income
# 131    High income
# 133    High income
# 145    High income
# 163    High income
# 181    High income
# Name: IncomeGroup, dtype: object>

# %%
data[data.CountryName == 'India']
# Out:
#    CountryName CountryCode  BirthRate  InternetUsers          IncomeGroup
# 80       India         IND     20.291           15.1  Lower middle income

# %%
data[data.CountryName == 'Malta']
# Out:
#     CountryName CountryCode  BirthRate  InternetUsers  IncomeGroup
# 116       Malta         MLT        9.5        68.9138  High income

# %%
data.iat[(3,4)]
# Out:
# 'Upper middle income'

# %%
data.iat[3,4]
# Out:
# 'Upper middle income'

# %%
data[f0].iat[1,1]
# Out:
# 'AUS'

# %%
data.at[7,'CountryName']
# Out:
# 'Antigua and Barbuda'

# %%
data.at[1,'CountryName']
# Out:
# 'Afghanistan'

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
v1 = sns.distplot(data['InternetUsers'])

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
plt.rcParams['figure.figsize'] = 9,4

# %%
v1 = sns.distplot(data['InternetUsers'], bins=23)

# %%
v2 = sns.boxplot(data=data, x='IncomeGroup', y='BirthRate')

# %%
v3 = sns.boxplot(data=data[data.BirthRate < 10], x='IncomeGroup', y='BirthRate')

# %%
data[data.BirthRate < 10]
# Out:
#                 CountryName CountryCode  BirthRate  InternetUsers  \
# 9                   Austria         AUT      9.400        80.6188
# 16                 Bulgaria         BGR      9.200        53.0615
# 19   Bosnia and Herzegovina         BIH      9.062        57.7900
# 45                  Germany         DEU      8.500        84.1700
# 53                    Spain         ESP      9.100        71.6350
# 68                   Greece         GRC      8.500        59.8663
# 74     Hong Kong SAR, China         HKG      7.900        74.2000
# 76                  Croatia         HRV      9.400        66.7476
# 78                  Hungary         HUN      9.200        72.6439
# 86                    Italy         ITA      8.500        58.4593
# 89                    Japan         JPN      8.200        89.7100
# 95              Korea, Rep.         KOR      8.600        84.7700
# 102           Liechtenstein         LIE      9.200        93.8000
# ...

# %%
d3 = data[(data.BirthRate < 10) & (data.IncomeGroup == 'Upper middle income')]

# %%
d3
# Out:
#                 CountryName CountryCode  BirthRate  InternetUsers  \
# 16                 Bulgaria         BGR      9.200        53.0615
# 19   Bosnia and Herzegovina         BIH      9.062        57.7900
# 146                 Romania         ROU      8.800        49.7645
# 157                  Serbia         SRB      9.200        51.5000
#
#              IncomeGroup
# 16   Upper middle income
# 19   Upper middle income
# 146  Upper middle income
# 157  Upper middle income

# %%
v4 = sns.distplot(d3['BirthRate'], bins=27)

# %%
v5 = sns.distplot(d3['InternetUsers'], bins=27)

# %%
d4 = data.sort_values(['InternetUsers'], ascending=1)

# %%
v6 = sns.barplot(x=d4.BirthRate, y=d4.InternetUsers, dodge=True)

# %%
d5 = data.sort_values(['InternetUsers', 'BirthRate'], ascending=[1,0])

# %%
v7 = sns.barplot(x=d5.BirthRate, y=d5.InternetUsers)

# %%
v8 = sns.lmplot(data=data, x='InternetUsers', y='BirthRate')

# %%
v9 = sns.lmplot(data=data, x='InternetUsers', y='BirthRate', fit_reg=False)

# %%
v10 = sns.lmplot(data=data, x='InternetUsers', y='BirthRate', hue='IncomeGroup')

# %%
v11 = sns.lmplot(data=data, x='InternetUsers', y='BirthRate', hue='IncomeGroup', fit_reg=False, \
                size=9, aspect=2)

# %%
v11 = sns.lmplot(data=data, x='InternetUsers', y='BirthRate', hue='IncomeGroup', fit_reg=False, \
                size=9, aspect=2, scatter_kws={'s': 100})

# %%
len(data)
# Out:
# 195

# %%
data[190:195]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
data[195:189:-1][::-1]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income

# %%
data[190:]
# Out:
#           CountryName CountryCode  BirthRate  InternetUsers  \
# 190       Yemen, Rep.         YEM     32.947           20.0
# 191      South Africa         ZAF     20.850           46.5
# 192  Congo, Dem. Rep.         COD     42.394            2.2
# 193            Zambia         ZMB     40.471           15.4
# 194          Zimbabwe         ZWE     35.715           18.5
#
#              IncomeGroup
# 190  Lower middle income
# 191  Upper middle income
# 192           Low income
# 193  Lower middle income
# 194           Low income
