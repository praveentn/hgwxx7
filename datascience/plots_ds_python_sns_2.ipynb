# %% [markdown]
# # Udemy | Python | Pandas | Visualizations

# %%
import os

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
os.getcwd()
# Out:
# 'C:\\Users\\praveen\\DS_Notebooks\\hgwxx7'

# %%
# os.chdir('C:\\Users\\praveen\\Desktop\\ds\\udemy')

# %%
# os.listdir()

# %%
movies = pd.read_csv('plots_ds_python_sns_2.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
# Film                         559 non-null object
# Genre                        559 non-null object
# Rotten Tomatoes Ratings %    559 non-null int64
# Audience Ratings %           559 non-null int64
# Budget (million $)           559 non-null int64
# Year of release              559 non-null int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
len(movies)
# Out:
# 559

# %%
list(movies)
# Out:
# ['Film',
#  'Genre',
#  'Rotten Tomatoes Ratings %',
#  'Audience Ratings %',
#  'Budget (million $)',
#  'Year of release']

# %%
movies.describe()
# Out:
#        Rotten Tomatoes Ratings %  Audience Ratings %  Budget (million $)  \
# count                 559.000000          559.000000          559.000000
# mean                   47.309481           58.744186           50.236136
# std                    26.413091           16.826887           48.731817
# min                     0.000000            0.000000            0.000000
# 25%                    25.000000           47.000000           20.000000
# 50%                    46.000000           58.000000           35.000000
# 75%                    70.000000           72.000000           65.000000
# max                    97.000000           96.000000          300.000000
#
#        Year of release
# count       559.000000
# mean       2009.152057
# std           1.362632
# min        2007.000000
# 25%        2008.000000
# 50%        2009.000000
# 75%        2010.000000
# max        2011.000000

# %%
movies.dtypes
# Out:
# Film                         object
# Genre                        object
# Rotten Tomatoes Ratings %     int64
# Audience Ratings %            int64
# Budget (million $)            int64
# Year of release               int64
# dtype: object

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns = ['Film', 'Genre', 'CriticRating', 'AudienceRating',
       'BudgetMillions', 'Year']

# %%
movies.head()
# Out:
#                     Film      Genre  CriticRating  AudienceRating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    BudgetMillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
movies.Film = movies.Film.astype('category')
movies.Genre = movies.Genre.astype('category')
movies.Year = movies.Year.astype('category')

# %%
movies.dtypes
# Out:
# Film              category
# Genre             category
# CriticRating         int64
# AudienceRating       int64
# BudgetMillions       int64
# Year              category
# dtype: object

# %%
movies.Genre.cat.categories
# Out:
# Index(['Action', 'Adventure', 'Comedy', 'Drama', 'Horror', 'Romance',
#        'Thriller'],
#       dtype='object')

# %%
movies.describe()
# Out:
#        CriticRating  AudienceRating  BudgetMillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set_style('darkgrid')

# %%
v1 = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating')

# %%
v2 = sns.jointplot(data=movies, x='CriticRating', y='AudienceRating', kind='hex')

# %%
v3 = sns.jointplot(data=movies, x='CriticRating', y='CriticRating', kind='hex')

# %%
v3 = sns.jointplot(data=movies, x='CriticRating', y='BudgetMillions', kind='hex')

# %%
v4 = sns.distplot(movies.CriticRating, bins=103)

# %%
v5 = sns.distplot(movies.AudienceRating, bins=103)

# %%
v6 = sns.distplot(movies.BudgetMillions, bins=17)

# %%
v7 = plt.hist(movies.BudgetMillions, bins=103)

# %%
sns.set_style('white')

# %%
v8 = plt.hist(movies.CriticRating, bins=103)

# %%
# STACKED HISTOGRAMS

# %%
plt.hist(movies.BudgetMillions)
plt.show()

# %%
movies[movies.Genre == 'Adventure'].BudgetMillions
# Out:
# 1      105
# 3       18
# 19     200
# 21      45
# 24      40
# 32      78
# 46      20
# 65      38
# 68     140
# 130     73
# 165     12
# 166    125
# 167    250
# 168    150
# 176     36
# 178    150
# 192     70
# 193     60
# 241     60
# 272     37
# 341     19
# 363     70
# 386    130
# 401    155
# 459     59
# 463     25
# 506     38
# 540    100
# 548     60
# Name: BudgetMillions, dtype: int64

# %%
plt.hist(movies[movies.Genre == 'Adventure'].BudgetMillions)
plt.show()

# %%
sns.set_style('darkgrid')

# %%
plt.hist(movies[movies.Genre == 'Comedy'].BudgetMillions)
plt.hist(movies[movies.Genre == 'Action'].BudgetMillions)
plt.hist(movies[movies.Genre == 'Adventure'].BudgetMillions)
plt.show()

# %%
plt.hist([movies[movies.Genre == 'Adventure'].BudgetMillions,
          movies[movies.Genre == 'Comedy'].BudgetMillions,
         movies[movies.Genre == 'Thriller'].BudgetMillions],
         stacked=True, bins=17)
plt.show()

# %%
for gen in movies.Genre.cat.categories:
    print(gen)
# Out:
# Action
# Adventure
# Comedy
# Drama
# Horror
# Romance
# Thriller

# %%
tl = []
for gen in movies.Genre.cat.categories:
    tl.append(movies[movies.Genre == gen].BudgetMillions)
plt.hist(tl, stacked=True)
plt.show()

# %%
tl = []
for gen in movies.Genre.cat.categories:
    tl.append(movies[movies.Genre == gen].BudgetMillions)
plt.hist(tl, stacked=True, bins=30, rwidth=2)
plt.show()

# %%
mylabels = []
tl = []
for gen in movies.Genre.cat.categories:
    tl.append(movies[movies.Genre == gen].BudgetMillions)
    mylabels.append(gen)
plt.hist(tl, stacked=True, bins=30, rwidth=2, label=mylabels)
plt.legend()
plt.show()

# %%
v10 = sns.lmplot(data=movies, x='CriticRating', y='AudienceRating', fit_reg=False, hue='Genre')

# %%
# KERNEL DENSITY PLOT

# %%
v11 = sns.kdeplot(movies.CriticRating, movies.AudienceRating)

# %%
v12 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True)

# %%
v13 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True,
                  shade_lowest=False, cmap='Reds')

# %%
v13 = sns.kdeplot(movies.CriticRating, movies.AudienceRating, shade=True,
                  shade_lowest=False, cmap='Reds')
v13b = sns.kdeplot(movies.CriticRating, movies.AudienceRating, cmap='Reds')

# %%
v13 = sns.kdeplot(movies.CriticRating, movies.BudgetMillions, shade=True,
                  shade_lowest=False, cmap='Reds')
v13b = sns.kdeplot(movies.CriticRating, movies.BudgetMillions, cmap='Reds')
