# %% [markdown]
# <a href="https://colab.research.google.com/github/praveentn/hgwxx7/blob/master/GAN/SinGAN_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SinGAN

# %%
# Clone the entire repo.
#!git clone -l -s git://github.com/jakevdp/PythonDataScienceHandbook.git cloned-repo
# !git clone -l -s git://github.com/tamarott/SinGAN.git
# %cd SinGAN
# !ls
# Out:
# Cloning into 'SinGAN'...
# ...
# remote: Enumerating objects: 620, done.
# remote: Total 620 (delta 0), reused 0 (delta 0), pack-reused 620
# Receiving objects: 100% (620/620), 74.19 MiB | 9.48 MiB/s, done.
# Resolving deltas: 100% (200/200), done.
# /content/SinGAN
# animation.py  editing.py	Input		random_samples.py  SR.py
# config.py     harmonization.py	main_train.py	README.md
# Downloads     imgs		paint2image.py	SinGAN

# %%
import os

os.getcwd()
# Out:
# '/content/SinGAN'

# %%
os.chdir('/content/SinGAN/Input/Images')
os.getcwd()
# Out:
# '/content/SinGAN/Input/Images'

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-4bed1eed-ca9a-4fe6-8057-bf3371ffda94" name="files[]" multiple disabled />
#      <output id="result-4bed1eed-ca9a-4fe6-8057-bf3371ffda94">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving i2_van_peer.jpg to i2_van_peer.jpg
# ...

# %%
os.chdir('/content/SinGAN')
os.getcwd()
# Out:
# '/content/SinGAN'

# %%
# !python main_train.py --input_name i2_van_peer.jpg
# Out:
# Random Seed:  1285
# GeneratorConcatSkip2CleanAdd(
#   (head): ConvBlock(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1))
#     (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#   )
#   (body): Sequential(
#     (block1): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block2): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
#       (norm): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (LeakyRelu): LeakyReLU(negative_slope=0.2, inplace=True)
#     )
#     (block3): ConvBlock(
#       (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1))
# ...

# %%
# !python random_samples.py --input_name i2_van_peer.jpg --mode random_samples --gen_start_scale 1
# Out:
# Random Seed:  169

# %%
# !python animation.py --input_name i2_van_peer.jpg --fast_training FAST_TRAINING
# Out:
# Random Seed:  5615
# output already exist

# %%
# !ls
# Out:
# animation.py  harmonization.py	Output		   README.md
# config.py     imgs		paint2image.py	   SinGAN
# Downloads     Input		__pycache__	   SR.py
# editing.py    main_train.py	random_samples.py  TrainedModels

# %%
# %cd ../../
# %cd Output/Animation/
# Out:
# /content/SinGAN
# /content/SinGAN/Output/Animation

# %%
# !ls -ltr
# Out:
# total 4
# drwxr-xr-x 5 root root 4096 Oct 30 08:45 i2_van_peer

# %%
# %cd i2_van_peer
# Out:
# /content/SinGAN/Output/Animation/i2_van_peer

# %%
# !ls -ltr
# Out:
# total 12
# drwxr-xr-x 2 root root 4096 Oct 30 08:44 'start_scale=0'
# drwxr-xr-x 2 root root 4096 Oct 30 08:45 'start_scale=1'
# drwxr-xr-x 2 root root 4096 Oct 30 08:45 'start_scale=2'

# %%
# %cd start_scale=2/
# Out:
# /content/SinGAN/Output/Animation/i2_van_peer/start_scale=2

# %%
# !ls -ltr
# Out:
# total 4764
# -rw-r--r-- 1 root root 1219207 Oct 30 08:45 'alpha=0.100000_beta=0.800000.gif'
# -rw-r--r-- 1 root root 1218349 Oct 30 08:45 'alpha=0.100000_beta=0.850000.gif'
# -rw-r--r-- 1 root root 1217148 Oct 30 08:45 'alpha=0.100000_beta=0.900000.gif'
# -rw-r--r-- 1 root root 1216478 Oct 30 08:45 'alpha=0.100000_beta=0.950000.gif'

# %%
files.download('alpha=0.100000_beta=0.950000.gif')

# %%
# %cd Output/RandomSamples/
# Out:
# /content/SinGAN/Output/RandomSamples

# %%
# !ls -ltr
# Out:
# total 4
# drwxr-xr-x 4 root root 4096 Oct 30 07:51 i2_van_peer
