# %% [markdown]
# <a href="https://colab.research.google.com/github/praveentn/hgwxx7/blob/master/nlp/similarity/similarity_annoy_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install annoy
# Out:
# ...
#      |████████████████████████████████| 645kB 8.2MB/s
# ...
#   Created wheel for annoy: filename=annoy-1.16.3-cp36-cp36m-linux_x86_64.whl size=301866 sha256=c41bd650c5d9737d25cb1a0146aa45721b1b481b129c5c1fc5299eeea26d1eed
#   Stored in directory: /root/.cache/pip/wheels/f3/01/54/6ef760fe9f9fc6ba8c19cebbe6358212b5f3b5b0195c0b813f
# Successfully built annoy
# ...

# %%
#load libraries
from annoy import AnnoyIndex
import random

# %%
f = 40
t = AnnoyIndex(f, 'angular')  # Length of item vector that will be indexed
for i in range(1000):
    v = [random.gauss(0, 1) for z in range(f)]
    t.add_item(i, v)

t.build(10) # 10 trees
t.save('test.ann')
# Out:
# True

# %%
v
# Out:
# [0.7038374530840219,
#  -0.28435775839956806,
#  -0.7403550887727859,
#  2.5355411409196718,
#  -0.6522975673875012,
#  1.5184139101041165,
#  -0.1725387394204394,
#  1.5171340411617829,
#  -0.4621179764905237,
#  1.2451049801020555,
#  0.03141750479880846,
#  -0.4970976058566791,
#  -0.4886559095157963,
#  0.2912459630840435,
#  0.5522130811103119,
#  -0.0955865583029714,
#  0.9130501391782717,
#  0.8308499569457741,
#  0.5728940175393881,
#  -0.652243297085536,
#  0.8109939706223942,
#  0.4318824883071019,
#  -0.19584422872985566,
#  0.5971958883767386,
#  -0.12707876399448517,
#  -2.1722355587879174,
#  1.0824915855702637,
#  -0.8428858971279254,
#  -2.1825689678498743,
#  0.9119069429427482,
#  0.2812952694541681,
#  -0.7256161406658584,
#  -0.1563938758486855,
#  -2.0917094923073716,
#  1.8831399456035138,
#  0.6492106971259607,
#  -0.3432319303373032,
#  1.0617235214243792,
#  -0.1715163785750291,
#  0.6925797901892813]

# %%
t

# %%
# ...

u = AnnoyIndex(f, 'angular')
u.load('test.ann') # super fast, will just mmap the file
print(u.get_nns_by_item(0, 1000)) # will find the 1000 nearest neighbors
# Out:
# [0, 679, 111, 731, 205, 204, 176, 532, 695, 43, 481, 151, 431, 23, 31, 260, 799, 861, 602, 805, 613, 42, 589, 989, 319, 464, 96, 983, 558, 398, 914, 28, 310, 809, 442, 430, 615, 349, 951, 137, 358, 9, 158, 612, 814, 448, 298, 634, 468, 55, 372, 235, 354, 733, 769, 652, 142, 702, 632, 581, 607, 371, 549, 961, 701, 812, 46, 912, 802, 474, 155, 279, 51, 923, 845, 640, 751, 292, 882, 667, 392, 366, 157, 538, 360, 229, 482, 14, 565, 250, 294, 76, 540, 659, 716, 160, 772, 895, 671, 368, 645, 67, 815, 840, 58, 935, 859, 275, 191, 420, 662, 773, 708, 872, 340, 740, 86, 570, 435, 159, 985, 437, 728, 330, 83, 457, 513, 282, 444, 182, 908, 41, 929, 587, 822, 797, 685, 984, 593, 50, 443, 944, 828, 255, 246, 163, 344, 13, 793, 241, 87, 3, 730, 639, 289, 869, 684, 871, 59, 820, 189, 722, 73, 891, 216, 415, 967, 699, 611, 425, 243, 757, 487, 857, 455, 965, 628, 350, 647, 959, 52, 603, 116, 70, 503, 894, 915, 21, 620, 381, 657, 893, 576, 526, 555, 642, 566, 813, 6, 15, 211, 690, 221, 897, 449, 564, 
# ...
