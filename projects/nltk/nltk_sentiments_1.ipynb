# %%
import os
import re
import nltk
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.classify import SklearnClassifier
from nltk.classify import NaiveBayesClassifier
from nltk.tokenize import word_tokenize
from nltk.sentiment.vader import SentimentIntensityAnalyzer 
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
os.getcwd()
# Out:
# 'C:\\Users\\praveen\\DS_Notebooks\\nltk'

# %%
data = pd.read_csv("train.csv", sep=',')

# %%
data.head()
# Out:
#                    Id  Category  \
# 0  635769805279248384  negative
# 1  635930169241374720   neutral
# 2  635950258682523648   neutral
# 3  636030803433009153  negative
# 4  636100906224848896  positive
#
#                                                Tweet
# 0                                      Not Available
# 1  IOS 9 App Transport Security. Mm need to check...
# 2  Mar if you have an iOS device, you should down...
# 3  @jimmie_vanagon my phone does not run on lates...
# 4  Not sure how to start your publication on iOS?...

# %%
len(data)
# Out:
# 86

# %%
data.Category.value_counts()
# Out:
# positive    41
# neutral     34
# negative    11
# Name: Category, dtype: int64

# %%
tweets = data[data.Tweet != 'Not Available']
tweets = pd.DataFrame([tweets['Tweet']]).T

# %%
len(tweets)
# Out:
# 80

# %%
tweets.head()
# Out:
#                                                Tweet
# 1  IOS 9 App Transport Security. Mm need to check...
# 2  Mar if you have an iOS device, you should down...
# 3  @jimmie_vanagon my phone does not run on lates...
# 4  Not sure how to start your publication on iOS?...
# 5  Two Dollar Tuesday is here with Forklift 2, Qu...

# %%
tweets['Tweet'] = tweets['Tweet'].str.replace('http\S+|www.\S+', '', case=False)

# %%
tweets['Tweet'][:30]
# Out:
# 1     IOS 9 App Transport Security. Mm need to check...
# 2     Mar if you have an iOS device, you should down...
# 3     @jimmie_vanagon my phone does not run on lates...
# 4     Not sure how to start your publication on iOS?...
# 5     Two Dollar Tuesday is here with Forklift 2, Qu...
# 6     If you're not already signed up to test my iOS...
# 7     YouTube Gaming Officially Launches On Web, And...
# 8     YouTube Gaming Launches Tomorrow with iOS and ...
# 9     @astrill Yashan from BBC @bbcchinese the VPN a...
# 10    Parkrun app for iOS downloaded Where have you ...
# 11    Today @YouTubeGaming launches, with apps for i...
# 12    Got a project you want to work on? Need help w...
# 13    Met with iOS Developer today. We may have a "g...
# 14    #CrossSkyHigh is going IOS #saturday. For now ...
# 15    What's the best way to get audio recordings fr...
# 16    Five Great Free Apps and Games for iOS - Augus...
# 17    @clayrussell @Nostradamion looks interesting b...
# 18    See news through the eyes of real people &amp;...
# 19    Siri knows all about #Apple's iOS event on the...
# 20    Who's ready for 0.12.1 Build 12 Tomorrow, Migh...
# 21    @facebook As I've been on FB for many years, I...
# 22    @Yurt try beat mp3 it may be on android i have...
# 23    @androidcentral Even though there are other di...
# 24    Huawei Watch Pre-Order Suggests Android Wear C...
# 25    SpeedeNews: Rumor: Android Wear will soon work...
# 26    Over here in NW near 11th &amp; Rhode Island, ...
# 27    @NarisDRIFT @T_Dogg_94ebooks I wish that Custo...
# 28    So today i checked my old iPod 4th gen which i...
# 29    @_tomcc @bartwerf please stop walking and work...
# 30    @notch  Hi i have heard that they said MCPE up...
# Name: Tweet, dtype: object

# %%
mytext = "this is my @string circle"
re.sub(r'\@\S*', '', mytext)
# Out:
# 'this is my  circle'

# %%
tweets['Tweet'] = tweets['Tweet'].str.replace(r'\@\S*', '', case=False)

# %%
tweets[:30]
# Out:
#                                                 Tweet
# 1   IOS 9 App Transport Security. Mm need to check...
# 2   Mar if you have an iOS device, you should down...
# 3    my phone does not run on latest IOS which may...
# 4   Not sure how to start your publication on iOS?...
# 5   Two Dollar Tuesday is here with Forklift 2, Qu...
# 6   If you're not already signed up to test my iOS...
# 7   YouTube Gaming Officially Launches On Web, And...
# 8   YouTube Gaming Launches Tomorrow with iOS and ...
# 9    Yashan from BBC  the VPN access on IOS may be...
# 10  Parkrun app for iOS downloaded Where have you ...
# 11  Today  launches, with apps for iOS and Android...
# 12  Got a project you want to work on? Need help w...
# 13  Met with iOS Developer today. We may have a "g...
# 14  #CrossSkyHigh is going IOS #saturday. For now ...
# 15  What's the best way to get audio recordings fr...
# 16  Five Great Free Apps and Games for iOS - Augus...
# 17    looks interesting but I've ALWAYS ended up b...
# 18  See news through the eyes of real people &amp;...
# 19  Siri knows all about #Apple's iOS event on the...
# 20  Who's ready for 0.12.1 Build 12 Tomorrow, Migh...
# 21   As I've been on FB for many years, I have a f...
# 22   try beat mp3 it may be on android i have it o...
# 23   Even though there are other differences in th...
# 24  Huawei Watch Pre-Order Suggests Android Wear C...
# 25  SpeedeNews: Rumor: Android Wear will soon work...
# 26  Over here in NW near 11th &amp; Rhode Island, ...
# 27    I wish that CustomFolderIcons worked on iOS ...
# 28  So today i checked my old iPod 4th gen which i...
# 29    please stop walking and work !! You have mor...
# 30    Hi i have heard that they said MCPE update 0...

# %%
stop_words = set(stopwords.words('english'))
stop_words
# Out:
# {'a',
#  'about',
#  'above',
#  'after',
#  'again',
#  'against',
#  'ain',
#  'all',
#  'am',
#  'an',
#  'and',
#  'any',
#  'are',
#  'aren',
#  "aren't",
#  'as',
#  'at',
#  'be',
#  'because',
#  'been',
#  'before',
#  'being',
#  'below',
#  'between',
#  'both',
#  'but',
#  'by',
#  'can',
#  'couldn',
#  "couldn't",
#  'd',
#  'did',
#  'didn',
#  "didn't",
#  'do',
#  'does',
#  'doesn',
#  "doesn't",
#  'doing',
#  'don',
#  "don't",
#  'down',
#  'during',
#  'each',
#  'few',
#  'for',
#  'from',
#  'further',
#  'had',
#  'hadn',
#  "hadn't",
#  'has',
#  'hasn',
#  "hasn't",
#  'have',
#  'haven',
#  "haven't",
#  'having',
#  'he',
#  'her',
#  'here',
#  'hers',
#  'herself',
#  'him',
#  'himself',
#  'his',
#  'how',
#  'i',
#  'if',
#  'in',
#  'into',
#  'is',
#  'isn',
#  "isn't",
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'just',
#  'll',
#  'm',
#  'ma',
#  'me',
#  'mightn',
#  "mightn't",
#  'more',
#  'most',
#  'mustn',
#  "mustn't",
#  'my',
#  'myself',
#  'needn',
#  "needn't",
#  'no',
#  'nor',
#  'not',
#  'now',
#  'o',
#  'of',
#  'off',
#  'on',
#  'once',
#  'only',
#  'or',
#  'other',
#  'our',
#  'ours',
#  'ourselves',
#  'out',
#  'over',
#  'own',
#  're',
#  's',
#  'same',
#  'shan',
#  "shan't",
#  'she',
#  "she's",
#  'should',
#  "should've",
#  'shouldn',
#  "shouldn't",
#  'so',
#  'some',
#  'such',
#  't',
#  'than',
#  'that',
#  "that'll",
#  'the',
#  'their',
#  'theirs',
#  'them',
#  'themselves',
#  'then',
#  'there',
#  'these',
#  'they',
#  'this',
#  'those',
#  'through',
#  'to',
#  'too',
#  'under',
#  'until',
#  'up',
#  've',
#  'very',
#  'was',
#  'wasn',
#  "wasn't",
#  'we',
#  'were',
#  'weren',
#  "weren't",
#  'what',
#  'when',
#  'where',
#  'which',
#  'while',
#  'who',
#  'whom',
#  'why',
#  'will',
#  'with',
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't",
#  'y',
#  'you',
#  "you'd",
#  "you'll",
#  "you're",
#  "you've",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves'}

# %%
for word in stop_words:
    tweets['Tweet'] = tweets['Tweet'].replace(to_replace=r'\b%s\b'%word, value="", regex=True)

# %%
tweets[:30]
# Out:
#                                                 Tweet
# 1   IOS 9 App Transport Security. Mm need  check  ...
# 2              Mar     iOS device,   download  app :
# 3     phone   run  latest IOS  may account  proble...
# 4   Not sure   start  publication  iOS? We'  live ...
# 5   Two Dollar Tuesday    Forklift 2, QuickKey  iO...
# 6   If   already signed   test  iOS game, nows  ch...
# 7   YouTube Gaming Officially Launches On Web, And...
# 8   YouTube Gaming Launches Tomorrow  iOS  Android...
# 9    Yashan  BBC   VPN access  IOS may  limited  C...
# 10  Parkrun app  iOS downloaded Where     ?Great a...
# 11  Today  launches,  apps  iOS  Android devices  ...
# 12  Got  project  want  work ? Need help  Swift? N...
# 13       Met  iOS Developer today. We may   "go". 8-)
# 14  #CrossSkyHigh  going IOS #saturday. For  try  ...
# 15  What'  best way  get audio recordings   3rd pa...
# 16  Five Great Free Apps  Games  iOS - August 27th...
# 17    looks interesting  I' ALWAYS ended  back  iO...
# 18  See news   eyes  real people &amp;    reporter...
# 19  Siri knows   #Apple' iOS event   9th. #GiveUsA...
# 20  Who' ready  0.12.1 Build 12 Tomorrow, Might   ...
# 21   As I'   FB  many years, I    hundred photo al...
# 22   try beat mp3  may   android     ios   fairly ...
# 23   Even though    differences   IOS features  st...
# 24  Huawei Watch Pre-Order Suggests Android Wear C...
# 25  SpeedeNews: Rumor: Android Wear  soon work  iO...
# 26  Over   NW near 11th &amp; Rhode Island,   need...
# 27    I wish  CustomFolderIcons worked  iOS 5.1.1 ...
# 28  So today  checked  old iPod 4th gen    iOS 6.1...
# 29    please stop walking  work !! You    one mont...
# 30    Hi   heard   said MCPE update 0,12,0/0,12,1 ...

# %%
train = []
sia = SentimentIntensityAnalyzer()
sia

# %%
tweets = list(tweets['Tweet'])

# %%
for tweet in tweets:
    print(tweet)
    s = sia.polarity_scores(tweet)
    for v in s:
        print('{0}: {1}, '.format(v, s[v]), end='\n')
        if v == 'compound' and s[v] > 0:
            train.append((tweet, "pos"))
        elif v == 'compound' and s[v] <= 0:
            train.append((tweet, "neg"))
# Out:
# IOS 9 App Transport Security. Mm need  check   3rd party network pod supports
# neg: 0.0,
# neu: 0.542,
# pos: 0.458,
# compound: 0.765,
# Mar     iOS device,   download  app :
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#   phone   run  latest IOS  may account  problem   day .. time   replaced
# neg: 0.213,
# neu: 0.787,
# pos: 0.0,
# compound: -0.4019,
# Not sure   start  publication  iOS? We'  live helping  ask  anything sessions today  Friday
# neg: 0.129,
# neu: 0.725,
# pos: 0.145,
# compound: 0.0613,
# Two Dollar Tuesday    Forklift 2, QuickKey  iOS  Suite  Pages   $1.99 today:
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# If   already signed   test  iOS game, nows  chance!
# neg: 0.0,
# neu: 0.753,
# pos: 0.247,
# compound: 0.3164,
# YouTube Gaming Officially Launches On Web, Android, iOS On August 26: YouTube  finally going  r...  #webseries
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# YouTube Gaming Launches Tomorrow  iOS  Android Apps  Go Head--Head  Twitch  #ios #game
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#  Yashan  BBC   VPN access  IOS may  limited  China' military parade? Any chance    chat  ?
# neg: 0.125,
# neu: 0.721,
# pos: 0.155,
# compound: 0.1179,
# Parkrun app  iOS downloaded Where     ?Great app easier access  info &amp; ready  Saturday' run
# neg: 0.0,
# neu: 0.539,
# pos: 0.461,
# compound: 0.8555,
# Today  launches,  apps  iOS  Android devices   US  UK,     need  know
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Got  project  want  work ? Need help  Swift? Need  excuse  hang  iOS devs   Sat? Hang  us!
# neg: 0.0,
# neu: 0.581,
# pos: 0.419,
# compound: 0.7124,
# Met  iOS Developer today. We may   "go". 8-)
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# #CrossSkyHigh  going IOS #saturday. For  try   #indiedev
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# What'  best way  get audio recordings   3rd party app    iOS device? Jailbreaking '  option.
# neg: 0.0,
# neu: 0.615,
# pos: 0.385,
# compound: 0.7845,
# Five Great Free Apps  Games  iOS - August 27th Edition:  It'  time   week ...  #News #LCHBuzz
# neg: 0.0,
# neu: 0.637,
# pos: 0.363,
# compound: 0.8126,
#   looks interesting  I' ALWAYS ended  back  iOS keyboard, always glitches  iOS 8/9 3rd party ones
# neg: 0.0,
# neu: 0.707,
# pos: 0.293,
# compound: 0.6597,
# See news   eyes  real people &amp;    reporter  Fresco 2.0  iOS, coming September 8th!
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Siri knows   #Apple' iOS event   9th. #GiveUsAHint
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Who' ready  0.12.1 Build 12 Tomorrow, Might   last build till  come  iOS !
# neg: 0.0,
# neu: 0.798,
# pos: 0.202,
# compound: 0.4199,
#  As I'   FB  many years, I    hundred photo albums,    1st 200 appear   IOS app. Is  right?
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#  try beat mp3  may   android     ios   fairly decent
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#  Even though    differences   IOS features  still may make people lean  little  towards Apple.
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Huawei Watch Pre-Order Suggests Android Wear Coming To iOS: IPhone owners  want  use Android Wear may soo...
# neg: 0.0,
# neu: 0.925,
# pos: 0.075,
# compound: 0.0772,
# SpeedeNews: Rumor: Android Wear  soon work  iOS - Android Wear may   close  working  iOS. That...
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Over   NW near 11th &amp; Rhode Island,   need  Lyft let  know !  Download  LYFT app  IOS  Android !
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#   I wish  CustomFolderIcons worked  iOS 5.1.1    received  December 11th.
# neg: 0.0,
# neu: 0.722,
# pos: 0.278,
# compound: 0.4019,
# So today  checked  old iPod 4th gen    iOS 6.1.6   '  upgraded    randomly open twitter
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#   please stop walking  work !! You    one month  late --" The update  annonced  29  july, IOS wait!
# neg: 0.108,
# neu: 0.736,
# pos: 0.156,
# compound: 0.2444,
#   Hi   heard   said MCPE update 0,12,0/0,12,1  come today 29 august  ios   cant see     update:)
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#      news   update  October  ios  android users
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#   follow- guess might      female,   iOS device, visiting  site,  may   disposable income?
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#  loving  new iPhone 6  T-Mobile I'  love  iOS! Can' wait   Sept 9th event
# neg: 0.0,
# neu: 0.544,
# pos: 0.456,
# compound: 0.8553,
#    Android wear  comparable  iOS  I believe. I may  wrong though
# neg: 0.307,
# neu: 0.693,
# pos: 0.0,
# compound: -0.4767,
# Google Expands Android Wear Smartwatch Platform  iOS -  Google  Monday rolled  Android Wear smartwatch harmony  ...
# neg: 0.0,
# neu: 0.76,
# pos: 0.24,
# compound: 0.4767,
#  yes, I asked  attendant  print   paper pass. But     1st time delta IOS app lost  login info. Annoying.
# neg: 0.242,
# neu: 0.628,
# pos: 0.13,
# compound: -0.3182,
# The two companies announced  partnership Monday aimed  making iOS devices  apps  compatible ...  #FF
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#  zeroes    latest   short video. Making iPhone &amp; iOS great  enterprises. 1st  &amp;
# neg: 0.0,
# neu: 0.728,
# pos: 0.272,
# compound: 0.6249,
# To  Nintendo fans  ; I may sound crazy  I say   Kirby   rainbow curse / Kirby canvas curse    iOS
# neg: 0.461,
# neu: 0.539,
# pos: 0.0,
# compound: -0.8555,
#  Life long Catholic    rules nonsensical.  Remember Venial sin,  meat  Friday'? So I  worry  Pope.
# neg: 0.382,
# neu: 0.618,
# pos: 0.0,
# compound: -0.7778,
#    And   Pope   forgiven annulments.   I think  words  "fuck   fucked"   I may  translated  wrong.
# neg: 0.534,
# neu: 0.34,
# pos: 0.126,
# compound: -0.8555,
# December 8 begins  Pope' "year  mercy".
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# This pope   cool I may  remake  MySpace  I  add    top 8
# neg: 0.0,
# neu: 0.594,
# pos: 0.406,
# compound: 0.4767,
# Anyone else feel like Cool Pope may   jeopardy  going  Julius Caesar-style?
# neg: 0.195,
# neu: 0.503,
# pos: 0.302,
# compound: 0.1779,
#  We understand   site  reopen next Tues. Pope' Urn   officially launched  Lord True  Mon 21 Sept
# neg: 0.0,
# neu: 0.751,
# pos: 0.249,
# compound: 0.5106,
# Families take  refugees  Pope calls  Europe' churches  open  doors -  1st X I disagree   Holiness
# neg: 0.191,
# neu: 0.809,
# pos: 0.0,
# compound: -0.3818,
# Are  closing  schools 4  Pope visit   Million man march anniversary???? Foolishness. ...
# neg: 0.273,
# neu: 0.727,
# pos: 0.0,
# compound: -0.5803,
# C'mon,   wanna popular pope   strong spiritual leader? Popularity   Pope  #catholic #popefrancis
# neg: 0.0,
# neu: 0.465,
# pos: 0.535,
# compound: 0.8481,
#  The Pope may get applause,    actually another e.g.   church  pulled along  modernity. Still  long way  go.
# neg: 0.0,
# neu: 0.843,
# pos: 0.157,
# compound: 0.4215,
# Pope simplifies Catholic marriage annulment: Pope Francis, making   substantial changes  Catholic mar...
# neg: 0.0,
# neu: 0.859,
# pos: 0.141,
# compound: 0.2023,
#  Re Pope:   possible  take MFL  2nd  34th  MORNING  MONDAY Sept 28? When  MFL resume regular sched/stops?
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Join  Moral March  Washington, DC  September 24: On September 24, Pope Francis  address Congress ...
# neg: 0.0,
# neu: 0.864,
# pos: 0.136,
# compound: 0.296,
# Tried  get Pope tickets   sold  hotter   concert!  Will try tomorrow  noon!
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# The Pope Wants To Make Annulling  Marriage Easier - Pope Francis  Tuesday revolutionized  procedure  Roma...
# neg: 0.0,
# neu: 0.823,
# pos: 0.177,
# compound: 0.4215,
# It    matter  time. This Pope' day may  numbered  head  church -&gt; Conservative dissent  (cont)
# neg: 0.0,
# neu: 0.922,
# pos: 0.078,
# compound: 0.0258,
# Pope radically simplifies Catholic marriage annulment procedures: VATICAN CITY (Reuters) - Pope Francis  Tuesday made  simpler ...
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#  I  hope  You Only Pope Once pale ale ' go quite  fast  Cape May  weekend
# neg: 0.0,
# neu: 0.805,
# pos: 0.195,
# compound: 0.4404,
# #World: Pope' faster annulment plan may mean less  U.S.: Pope Francis   reformed ...  via .
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
#   Thanks 'pope' Francis  quickie divorce VII style. 2nd Council + Novus Ordo  work  Masonic infiltrators
# neg: 0.0,
# neu: 0.818,
# pos: 0.182,
# compound: 0.4404,
# Its   hard days fishing  today  1st fish  ruffe  good start I thought I'  blessed   pope!
# neg: 0.072,
# neu: 0.564,
# pos: 0.364,
# compound: 0.7712,
#  call Hafiz saeed sir  may help u . Maybe Pope  b handy . Try .
# neg: 0.0,
# neu: 0.769,
# pos: 0.231,
# compound: 0.4019,
# Celebrating  Pope: What Makes Pope Francis Tick? FREE webinar: Sept 10, 7-8p EDT More info:   presents
# neg: 0.0,
# neu: 0.644,
# pos: 0.356,
# compound: 0.8286,
# As  Jesuit Pope visits  US,  may  questions  us. Check   US  Canada Jesuits' resource page:
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Pope Addresses Portugal' Bishops  5-Yearly Visit: Pope Francis  Monday received  audience  bishops ...
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Question!!!!!! Somebody settle   .....    pope comes  town  weekend   25th ...
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# The Pope    nice       lure  back : Cool Pope strikes : Pope Francis  Tuesday...
# neg: 0.16,
# neu: 0.513,
# pos: 0.327,
# compound: 0.3818,
# Pope Francis USA tshirts  sale  $10  Mr. Hylka-room 219  Thursday 3pm. These   worn 9/23,  day  pope arrives   US.
# neg: 0.115,
# neu: 0.885,
# pos: 0.0,
# compound: -0.296,
# I wish  Pope would  ANYTHING   canonize Serra   visits  school   23rd.  I really like...
# neg: 0.0,
# neu: 0.787,
# pos: 0.213,
# compound: 0.4019,
# Looks like I   1/3 shot  getting tickets   Pope' Mass. So  anyone ' busy  12EST tomorrow, I' appreciate  help.
# neg: 0.0,
# neu: 0.622,
# pos: 0.378,
# compound: 0.7845,
# Pope Benedict XVI 1st  quit   600 yrs, feared  bad pope would  chosen.
# neg: 0.401,
# neu: 0.599,
# pos: 0.0,
# compound: -0.7717,
# Hey everyone go vote   POPE vs Woodstock game   shown live  TV  Friday!
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Went   tour   Basilica,  Michelangelo  buried. Going   Sistine Chapel tomorrow. Pope  speaking .
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# It   Disrespectful Travestys  POTUS  send 2 Pro-Aborts (Pelosi &amp; Biden)   Pope' Installation!
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# I  glad  Sanhedrin  back  business (   3rd Temple)    trying Obama   Pope  absentia Well deserved.
# neg: 0.0,
# neu: 0.662,
# pos: 0.338,
# compound: 0.6249,
# If  missed   Pope tix  Independence Hall, annnounced 2  tix avails online 4&amp;8pm Wed
# neg: 0.167,
# neu: 0.833,
# pos: 0.0,
# compound: -0.296,
# LADY TECNIQ NEWS A Quick Pope Primer: Things  Know Before His Historic Visit   United States Later This Mon...
# neg: 0.0,
# neu: 0.851,
# pos: 0.149,
# compound: 0.4215,
# Pope' faster annulment plan may  mean  much   US.
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,
# Today  Pope announced making  easy  get  annulment. Coincidence  today   25th wedding anniversary? #omen #wtf #SignFromGod
# neg: 0.0,
# neu: 0.828,
# pos: 0.172,
# compound: 0.4404,
# Sen. Schumer  announce Wednesday  winners  tickets  see Pope
# neg: 0.0,
# neu: 0.693,
# pos: 0.307,
# compound: 0.4767,
# WISCTV_News3: Pope' marriage annulment changes expected  make church  inclusive #news3
# neg: 0.0,
# neu: 1.0,
# pos: 0.0,
# compound: 0.0,

# %%
len(train)
# Out:
# 80

# %%
train
# Out:
# [('IOS 9 App Transport Security. Mm need  check   3rd party network pod supports  ',
#   'pos'),
#  ('Mar     iOS device,   download  app : ', 'neg'),
#  ('  phone   run  latest IOS  may account  problem   day .. time   replaced',
#   'neg'),
#  ("Not sure   start  publication  iOS? We'  live helping  ask  anything sessions today  Friday ",
#   'pos'),
#  ('Two Dollar Tuesday    Forklift 2, QuickKey  iOS  Suite  Pages   $1.99 today:   ',
#   'neg'),
#  ('If   already signed   test  iOS game, nows  chance! ', 'pos'),
#  ('YouTube Gaming Officially Launches On Web, Android, iOS On August 26: YouTube  finally going  r...  #webseries',
#   'neg'),
#  ('YouTube Gaming Launches Tomorrow  iOS  Android Apps  Go Head--Head  Twitch  #ios #game',
#   'neg'),
#  (" Yashan  BBC   VPN access  IOS may  limited  China' military parade? Any chance    chat  ?",
#   'pos'),
#  ("Parkrun app  iOS downloaded Where     ?Great app easier access  info &amp; ready  Saturday' run ",
#   'pos'),
#  ('Today  launches,  apps  iOS  Android devices   US  UK,     need  know ',
#   'neg'),
#  ('Got  project  want  work ? Need help  Swift? Need  excuse  hang  iOS devs   Sat? Hang  us! ',
#   'pos'),
#  ('Met  iOS Developer today. We may   "go". 8-)', 'neg'),
#  ('#CrossSkyHigh  going IOS #saturday. For  try   #indiedev   ', 'neg'),
#  ("What'  best way  get audio recordings   3rd party app    iOS device? Jailbreaking '  option.",
#   'pos'),
#  ("Five Great Free Apps  Games  iOS - August 27th Edition:  It'  time   week ...  #News #LCHBuzz",
#   'pos'),
#  ("  looks interesting  I' ALWAYS ended  back  iOS keyboard, always glitches  iOS 8/9 3rd party ones",
#   'pos'),
#  ('See news   eyes  real people &amp;    reporter  Fresco 2.0  iOS, coming September 8th! ',
#   'neg'),
#  ("Siri knows   #Apple' iOS event   9th. #GiveUsAHint ", 'neg'),
#  ("Who' ready  0.12.1 Build 12 Tomorrow, Might   last build till  come  iOS !",
#   'pos'),
#  (" As I'   FB  many years, I    hundred photo albums,    1st 200 appear   IOS app. Is  right?",
#   'neg'),
#  (' try beat mp3  may   android     ios   fairly decent', 'neg'),
#  (' Even though    differences   IOS features  still may make people lean  little  towards Apple.',
#   'neg'),
#  ('Huawei Watch Pre-Order Suggests Android Wear Coming To iOS: IPhone owners  want  use Android Wear may soo... ',
#   'pos'),
#  ('SpeedeNews: Rumor: Android Wear  soon work  iOS - Android Wear may   close  working  iOS. That... ',
#   'neg'),
#  ('Over   NW near 11th &amp; Rhode Island,   need  Lyft let  know !  Download  LYFT app  IOS  Android !',
#   'neg'),
#  ('  I wish  CustomFolderIcons worked  iOS 5.1.1    received  December 11th.',
#   'pos'),
#  ("So today  checked  old iPod 4th gen    iOS 6.1.6   '  upgraded    randomly open twitter",
#   'neg'),
#  ('  please stop walking  work !! You    one month  late --" The update  annonced  29  july, IOS wait!',
#   'pos'),
#  ('  Hi   heard   said MCPE update 0,12,0/0,12,1  come today 29 august  ios   cant see     update:)',
#   'neg'),
#  ('     news   update  October  ios  android users', 'neg'),
#  ('  follow- guess might      female,   iOS device, visiting  site,  may   disposable income?',
#   'neg'),
#  (" loving  new iPhone 6  T-Mobile I'  love  iOS! Can' wait   Sept 9th event",
#   'pos'),
#  ('   Android wear  comparable  iOS  I believe. I may  wrong though', 'neg'),
#  ('Google Expands Android Wear Smartwatch Platform  iOS -  Google  Monday rolled  Android Wear smartwatch harmony  ...',
#   'pos'),
#  (' yes, I asked  attendant  print   paper pass. But     1st time delta IOS app lost  login info. Annoying.',
#   'neg'),
#  ('The two companies announced  partnership Monday aimed  making iOS devices  apps  compatible ...  #FF',
#   'neg'),
#  (' zeroes    latest   short video. Making iPhone &amp; iOS great  enterprises. 1st  &amp;   ',
#   'pos'),
#  ('To  Nintendo fans  ; I may sound crazy  I say   Kirby   rainbow curse / Kirby canvas curse    iOS',
#   'neg'),
#  (" Life long Catholic    rules nonsensical.  Remember Venial sin,  meat  Friday'? So I  worry  Pope.",
#   'neg'),
#  ('   And   Pope   forgiven annulments.   I think  words  "fuck   fucked"   I may  translated  wrong.',
#   'neg'),
#  ('December 8 begins  Pope\' "year  mercy".', 'neg'),
#  ('This pope   cool I may  remake  MySpace  I  add    top 8', 'pos'),
#  ('Anyone else feel like Cool Pope may   jeopardy  going  Julius Caesar-style?',
#   'pos'),
#  (" We understand   site  reopen next Tues. Pope' Urn   officially launched  Lord True  Mon 21 Sept",
#   'pos'),
#  ("Families take  refugees  Pope calls  Europe' churches  open  doors -  1st X I disagree   Holiness",
#   'neg'),
#  ('Are  closing  schools 4  Pope visit   Million man march anniversary???? Foolishness. ...',
#   'neg'),
#  ("C'mon,   wanna popular pope   strong spiritual leader? Popularity   Pope  #catholic #popefrancis",
#   'pos'),
#  (' The Pope may get applause,    actually another e.g.   church  pulled along  modernity. Still  long way  go.',
#   'pos'),
#  ('Pope simplifies Catholic marriage annulment: Pope Francis, making   substantial changes  Catholic mar... ',
#   'pos'),
#  (' Re Pope:   possible  take MFL  2nd  34th  MORNING  MONDAY Sept 28? When  MFL resume regular sched/stops?',
#   'neg'),
#  ('Join  Moral March  Washington, DC  September 24: On September 24, Pope Francis  address Congress ... ',
#   'pos'),
#  ('Tried  get Pope tickets   sold  hotter   concert!  Will try tomorrow  noon!',
#   'neg'),
#  ('The Pope Wants To Make Annulling  Marriage Easier - Pope Francis  Tuesday revolutionized  procedure  Roma... ',
#   'pos'),
#  ("It    matter  time. This Pope' day may  numbered  head  church -&gt; Conservative dissent  (cont) ",
#   'pos'),
#  ('Pope radically simplifies Catholic marriage annulment procedures: VATICAN CITY (Reuters) - Pope Francis  Tuesday made  simpler ...',
#   'neg'),
#  (" I  hope  You Only Pope Once pale ale ' go quite  fast  Cape May  weekend",
#   'pos'),
#  ("#World: Pope' faster annulment plan may mean less  U.S.: Pope Francis   reformed ...  via .",
#   'neg'),
#  ("  Thanks 'pope' Francis  quickie divorce VII style. 2nd Council + Novus Ordo  work  Masonic infiltrators",
#   'pos'),
#  ("Its   hard days fishing  today  1st fish  ruffe  good start I thought I'  blessed   pope! ",
#   'pos'),
#  (' call Hafiz saeed sir  may help u . Maybe Pope  b handy . Try .', 'pos'),
#  ('Celebrating  Pope: What Makes Pope Francis Tick? FREE webinar: Sept 10, 7-8p EDT More info:   presents',
#   'pos'),
#  ("As  Jesuit Pope visits  US,  may  questions  us. Check   US  Canada Jesuits' resource page: ",
#   'neg'),
#  ("Pope Addresses Portugal' Bishops  5-Yearly Visit: Pope Francis  Monday received  audience  bishops ... ",
#   'neg'),
#  ('Question!!!!!! Somebody settle   .....    pope comes  town  weekend   25th ... ',
#   'neg'),
#  ('The Pope    nice       lure  back : Cool Pope strikes : Pope Francis  Tuesday... ',
#   'pos'),
#  ('Pope Francis USA tshirts  sale  $10  Mr. Hylka-room 219  Thursday 3pm. These   worn 9/23,  day  pope arrives   US.',
#   'neg'),
#  ('I wish  Pope would  ANYTHING   canonize Serra   visits  school   23rd.  I really like... ',
#   'pos'),
#  ("Looks like I   1/3 shot  getting tickets   Pope' Mass. So  anyone ' busy  12EST tomorrow, I' appreciate  help.",
#   'pos'),
#  ('Pope Benedict XVI 1st  quit   600 yrs, feared  bad pope would  chosen.   ',
#   'neg'),
#  ('Hey everyone go vote   POPE vs Woodstock game   shown live  TV  Friday!           ',
#   'neg'),
#  ('Went   tour   Basilica,  Michelangelo  buried. Going   Sistine Chapel tomorrow. Pope  speaking .',
#   'neg'),
#  ("It   Disrespectful Travestys  POTUS  send 2 Pro-Aborts (Pelosi &amp; Biden)   Pope' Installation! ",
#   'neg'),
#  ('I  glad  Sanhedrin  back  business (   3rd Temple)    trying Obama   Pope  absentia Well deserved.',
#   'pos'),
#  ('If  missed   Pope tix  Independence Hall, annnounced 2  tix avails online 4&amp;8pm Wed  ',
#   'neg'),
#  ('LADY TECNIQ NEWS A Quick Pope Primer: Things  Know Before His Historic Visit   United States Later This Mon... ',
#   'pos'),
#  ("Pope' faster annulment plan may  mean  much   US.  ", 'neg'),
#  ('Today  Pope announced making  easy  get  annulment. Coincidence  today   25th wedding anniversary? #omen #wtf #SignFromGod',
#   'pos'),
#  ('Sen. Schumer  announce Wednesday  winners  tickets  see Pope ', 'pos'),
#  ("WISCTV_News3: Pope' marriage annulment changes expected  make church  inclusive #news3  ",
#   'neg')]

# %%
dictionary = set(word.lower() for tweet in train for word in word_tokenize(tweet[0]))
dictionary
# Out:
# {'!',
#  '#',
#  '$',
#  '&',
#  "'",
#  "''",
#  "'pope",
#  '(',
#  ')',
#  '+',
#  ',',
#  '-',
#  '--',
#  '.',
#  '..',
#  '...',
#  '/',
#  '0,12,0/0,12,1',
#  '0.12.1',
#  '1.99',
#  '1/3',
#  '10',
#  '11th',
#  '12',
#  '12est',
#  '1st',
#  '2',
#  '2.0',
#  '200',
#  '21',
#  '219',
#  '23rd',
#  '24',
#  '25th',
#  '26',
#  '27th',
#  '28',
#  '29',
#  '2nd',
#  '34th',
#  '3pm',
#  '3rd',
#  '4',
#  '4th',
#  '5-yearly',
#  '5.1.1',
#  '6',
#  '6.1.6',
#  '600',
#  '7-8p',
#  '8',
#  '8-',
#  '8/9',
#  '8pm',
#  '8th',
#  '9',
#  '9/23',
#  '9th',
#  ':',
#  ';',
#  '?',
#  '``',
#  'a',
#  'absentia',
#  'access',
#  'account',
#  'actually',
#  'add',
#  'address',
#  'addresses',
#  'aimed',
#  'albums',
#  'ale',
#  'along',
#  'already',
#  'always',
#  'amp',
#  'and',
#  'android',
#  'anniversary',
#  'annnounced',
#  'annonced',
#  'announce',
#  'announced',
#  'annoying',
#  'annulling',
#  'annulment',
#  'annulments',
#  'another',
#  'any',
#  'anyone',
#  'anything',
#  'app',
#  'appear',
#  'applause',
#  'apple',
#  'appreciate',
#  'apps',
#  'are',
#  'arrives',
#  'as',
#  'ask',
#  'asked',
#  'attendant',
#  'audience',
#  'audio',
#  'august',
#  'avails',
#  'b',
#  'back',
#  'bad',
#  'basilica',
#  'bbc',
#  'beat',
#  'before',
#  'begins',
#  'believe',
#  'benedict',
#  'best',
#  'biden',
#  'bishops',
#  'blessed',
#  'build',
#  'buried',
#  'business',
#  'busy',
#  'but',
#  "c'mon",
#  'caesar-style',
#  'call',
#  'calls',
#  'can',
#  'canada',
#  'canonize',
#  'cant',
#  'canvas',
#  'cape',
#  'catholic',
#  'celebrating',
#  'chance',
#  'changes',
#  'chapel',
#  'chat',
#  'check',
#  'checked',
#  'china',
#  'chosen',
#  'church',
#  'churches',
#  'city',
#  'close',
#  'closing',
#  'coincidence',
#  'come',
#  'comes',
#  'coming',
#  'companies',
#  'comparable',
#  'compatible',
#  'concert',
#  'congress',
#  'conservative',
#  'cont',
#  'cool',
#  'council',
#  'crazy',
#  'crossskyhigh',
#  'curse',
#  'customfoldericons',
#  'day',
#  'days',
#  'dc',
#  'december',
#  'decent',
#  'delta',
#  'deserved',
#  'developer',
#  'device',
#  'devices',
#  'devs',
#  'differences',
#  'disagree',
#  'disposable',
#  'disrespectful',
#  'dissent',
#  'divorce',
#  'dollar',
#  'doors',
#  'download',
#  'downloaded',
#  'e.g',
#  'easier',
#  'easy',
#  'edition',
#  'edt',
#  'else',
#  'ended',
#  'enterprises',
#  'europe',
#  'even',
#  'event',
#  'everyone',
#  'excuse',
#  'expands',
#  'expected',
#  'eyes',
#  'fairly',
#  'families',
#  'fans',
#  'fast',
#  'faster',
#  'fb',
#  'feared',
#  'features',
#  'feel',
#  'female',
#  'ff',
#  'finally',
#  'fish',
#  'fishing',
#  'five',
#  'follow-',
#  'foolishness',
#  'for',
#  'forgiven',
#  'forklift',
#  'francis',
#  'free',
#  'fresco',
#  'friday',
#  'fuck',
#  'fucked',
#  'game',
#  'games',
#  'gaming',
#  'gen',
#  'get',
#  'getting',
#  'giveusahint',
#  'glad',
#  'glitches',
#  'go',
#  'going',
#  'good',
#  'google',
#  'got',
#  'great',
#  'gt',
#  'guess',
#  'hafiz',
#  'hall',
#  'handy',
#  'hang',
#  'hard',
#  'harmony',
#  'head',
#  'heard',
#  'help',
#  'helping',
#  'hey',
#  'hi',
#  'his',
#  'historic',
#  'holiness',
#  'hope',
#  'hotter',
#  'huawei',
#  'hundred',
#  'hylka-room',
#  'i',
#  'if',
#  'inclusive',
#  'income',
#  'independence',
#  'indiedev',
#  'infiltrators',
#  'info',
#  'installation',
#  'interesting',
#  'ios',
#  'iphone',
#  'ipod',
#  'is',
#  'island',
#  'it',
#  'its',
#  'jailbreaking',
#  'jeopardy',
#  'jesuit',
#  'jesuits',
#  'join',
#  'julius',
#  'july',
#  'keyboard',
#  'kirby',
#  'know',
#  'knows',
#  'lady',
#  'last',
#  'late',
#  'later',
#  'latest',
#  'launched',
#  'launches',
#  'lchbuzz',
#  'leader',
#  'lean',
#  'less',
#  'let',
#  'life',
#  'like',
#  'limited',
#  'little',
#  'live',
#  'login',
#  'long',
#  'looks',
#  'lord',
#  'lost',
#  'love',
#  'loving',
#  'lure',
#  'lyft',
#  'made',
#  'make',
#  'makes',
#  'making',
#  'man',
#  'many',
#  'mar',
#  'march',
#  'marriage',
#  'masonic',
#  'mass',
#  'matter',
#  'may',
#  'maybe',
#  'mcpe',
#  'mean',
#  'meat',
#  'mercy',
#  'met',
#  'mfl',
#  'michelangelo',
#  'might',
#  'military',
#  'million',
#  'missed',
#  'mm',
#  'modernity',
#  'mon',
#  'monday',
#  'month',
#  'moral',
#  'more',
#  'morning',
#  'mp3',
#  'mr.',
#  'much',
#  'myspace',
#  'na',
#  'near',
#  'need',
#  'network',
#  'new',
#  'news',
#  'news3',
#  'next',
#  'nice',
#  'nintendo',
#  'nonsensical',
#  'noon',
#  'not',
#  'novus',
#  'nows',
#  'numbered',
#  'nw',
#  'obama',
#  'october',
#  'officially',
#  'old',
#  'omen',
#  'on',
#  'once',
#  'one',
#  'ones',
#  'online',
#  'only',
#  'open',
#  'option',
#  'ordo',
#  'over',
#  'owners',
#  'page',
#  'pages',
#  'pale',
#  'paper',
#  'parade',
#  'parkrun',
#  'partnership',
#  'party',
#  'pass',
#  'pelosi',
#  'people',
#  'phone',
#  'photo',
#  'plan',
#  'platform',
#  'please',
#  'pod',
#  'pope',
#  'popefrancis',
#  'popular',
#  'popularity',
#  'portugal',
#  'possible',
#  'potus',
#  'pre-order',
#  'presents',
#  'primer',
#  'print',
#  'pro-aborts',
#  'problem',
#  'procedure',
#  'procedures',
#  'project',
#  'publication',
#  'pulled',
#  'question',
#  'questions',
#  'quick',
#  'quickie',
#  'quickkey',
#  'quit',
#  'quite',
#  'r',
#  'radically',
#  'rainbow',
#  'randomly',
#  're',
#  'ready',
#  'real',
#  'really',
#  'received',
#  'recordings',
#  'reformed',
#  'refugees',
#  'regular',
#  'remake',
#  'remember',
#  'reopen',
#  'replaced',
#  'reporter',
#  'resource',
#  'resume',
#  'reuters',
#  'revolutionized',
#  'rhode',
#  'right',
#  'rolled',
#  'roma',
#  'ruffe',
#  'rules',
#  'rumor',
#  'run',
#  'saeed',
#  'said',
#  'sale',
#  'sanhedrin',
#  'sat',
#  'saturday',
#  'say',
#  'sched/stops',
#  'school',
#  'schools',
#  'schumer',
#  'security',
#  'see',
#  'sen.',
#  'send',
#  'sept',
#  'september',
#  'serra',
#  'sessions',
#  'settle',
#  'short',
#  'shot',
#  'shown',
#  'signed',
#  'signfromgod',
#  'simpler',
#  'simplifies',
#  'sin',
#  'sir',
#  'siri',
#  'sistine',
#  'site',
#  'smartwatch',
#  'so',
#  'sold',
#  'somebody',
#  'soo',
#  'soon',
#  'sound',
#  'speaking',
#  'speedenews',
#  'spiritual',
#  'start',
#  'states',
#  'still',
#  'stop',
#  'strikes',
#  'strong',
#  'style',
#  'substantial',
#  'suggests',
#  'suite',
#  'supports',
#  'sure',
#  'swift',
#  't-mobile',
#  'take',
#  'tecniq',
#  'temple',
#  'test',
#  'thanks',
#  'that',
#  'the',
#  'these',
#  'things',
#  'think',
#  'this',
#  'though',
#  'thought',
#  'thursday',
#  'tick',
#  'tickets',
#  'till',
#  'time',
#  'tix',
#  'to',
#  'today',
#  'tomorrow',
#  'top',
#  'tour',
#  'towards',
#  'town',
#  'translated',
#  'transport',
#  'travestys',
#  'tried',
#  'true',
#  'try',
#  'trying',
#  'tshirts',
#  'tues.',
#  'tuesday',
#  'tv',
#  'twitch',
#  'twitter',
#  'two',
#  'u',
#  'u.s.',
#  'uk',
#  'understand',
#  'united',
#  'update',
#  'upgraded',
#  'urn',
#  'us',
#  'usa',
#  'use',
#  'users',
#  'vatican',
#  'venial',
#  'via',
#  'video',
#  'vii',
#  'visit',
#  'visiting',
#  'visits',
#  'vote',
#  'vpn',
#  'vs',
#  'wait',
#  'walking',
#  'wan',
#  'want',
#  'wants',
#  'washington',
#  'watch',
#  'way',
#  'we',
#  'wear',
#  'web',
#  'webinar',
#  'webseries',
#  'wed',
#  'wedding',
#  'wednesday',
#  'week',
#  'weekend',
#  'well',
#  'went',
#  'what',
#  'when',
#  'where',
#  'who',
#  'will',
#  'winners',
#  'wisctv_news3',
#  'wish',
#  'woodstock',
#  'words',
#  'work',
#  'worked',
#  'working',
#  'world',
#  'worn',
#  'worry',
#  'would',
#  'wrong',
#  'wtf',
#  'x',
#  'xvi',
#  'yashan',
#  'year',
#  'years',
#  'yes',
#  'you',
#  'youtube',
#  'yrs',
#  'zeroes'}

# %%
t = [({word: (word in word_tokenize(x[0])) for word in dictionary}, x[1]) for x in train]

# %%
t
# Out:
# [({'!': False,
#    '#': False,
#    '$': False,
#    '&': False,
#    "'": False,
#    "''": False,
#    "'pope": False,
#    '(': False,
#    ')': False,
#    '+': False,
#    ',': False,
#    '-': False,
#    '--': False,
#    '.': True,
#    '..': False,
#    '...': False,
#    '/': False,
#    '0,12,0/0,12,1': False,
#    '0.12.1': False,
#    '1.99': False,
#    '1/3': False,
#    '10': False,
#    '11th': False,
#    '12': False,
#    '12est': False,
#    '1st': False,
#    '2': False,
#    '2.0': False,
#    '200': False,
#    '21': False,
#    '219': False,
#    '23rd': False,
#    '24': False,
#    '25th': False,
#    '26': False,
#    '27th': False,
#    '28': False,
#    '29': False,
#    '2nd': False,
#    '34th': False,
#    '3pm': False,
#    '3rd': True,
#    '4': False,
#    '4th': False,
#    '5-yearly': False,
#    '5.1.1': False,
#    '6': False,
#    '6.1.6': False,
#    '600': False,
#    '7-8p': False,
#    '8': False,
#    '8-': False,
#    '8/9': False,
#    '8pm': False,
#    '8th': False,
#    '9': True,
#    '9/23': False,
#    '9th': False,
#    ':': False,
#    ';': False,
#    '?': False,
#    '``': False,
#    'a': False,
#    'absentia': False,
#    'access': False,
#    'account': False,
#    'actually': False,
#    'add': False,
#    'address': False,
#    'addresses': False,
#    'aimed': False,
#    'albums': False,
#    'ale': False,
#    'along': False,
#    'already': False,
#    'always': False,
#    'amp': False,
#    'and': False,
#    'android': False,
#    'anniversary': False,
#    'annnounced': False,
#    'annonced': False,
#    'announce': False,
#    'announced': False,
#    'annoying': False,
#    'annulling': False,
#    'annulment': False,
#    'annulments': False,
#    'another': False,
#    'any': False,
#    'anyone': False,
#    'anything': False,
#    'app': False,
#    'appear': False,
#    'applause': False,
#    'apple': False,
#    'appreciate': False,
#    'apps': False,
#    'are': False,
#    'arrives': False,
#    'as': False,
#    'ask': False,
#    'asked': False,
#    'attendant': False,
#    'audience': False,
#    'audio': False,
#    'august': False,
#    'avails': False,
#    'b': False,
#    'back': False,
#    'bad': False,
#    'basilica': False,
#    'bbc': False,
#    'beat': False,
#    'before': False,
#    'begins': False,
#    'believe': False,
#    'benedict': False,
#    'best': False,
#    'biden': False,
#    'bishops': False,
#    'blessed': False,
#    'build': False,
#    'buried': False,
#    'business': False,
#    'busy': False,
#    'but': False,
#    "c'mon": False,
#    'caesar-style': False,
#    'call': False,
#    'calls': False,
#    'can': False,
#    'canada': False,
#    'canonize': False,
#    'cant': False,
#    'canvas': False,
#    'cape': False,
#    'catholic': False,
#    'celebrating': False,
#    'chance': False,
#    'changes': False,
#    'chapel': False,
#    'chat': False,
#    'check': True,
#    'checked': False,
#    'china': False,
#    'chosen': False,
#    'church': False,
#    'churches': False,
#    'city': False,
#    'close': False,
#    'closing': False,
#    'coincidence': False,
#    'come': False,
#    'comes': False,
#    'coming': False,
#    'companies': False,
#    'comparable': False,
#    'compatible': False,
#    'concert': False,
#    'congress': False,
#    'conservative': False,
#    'cont': False,
#    'cool': False,
#    'council': False,
#    'crazy': False,
#    'crossskyhigh': False,
#    'curse': False,
#    'customfoldericons': False,
#    'day': False,
#    'days': False,
#    'dc': False,
#    'december': False,
#    'decent': False,
#    'delta': False,
#    'deserved': False,
#    'developer': False,
#    'device': False,
#    'devices': False,
#    'devs': False,
#    'differences': False,
#    'disagree': False,
#    'disposable': False,
#    'disrespectful': False,
#    'dissent': False,
#    'divorce': False,
#    'dollar': False,
#    'doors': False,
#    'download': False,
#    'downloaded': False,
#    'e.g': False,
#    'easier': False,
#    'easy': False,
#    'edition': False,
#    'edt': False,
#    'else': False,
#    'ended': False,
#    'enterprises': False,
#    'europe': False,
#    'even': False,
#    'event': False,
#    'everyone': False,
#    'excuse': False,
#    'expands': False,
#    'expected': False,
#    'eyes': False,
#    'fairly': False,
#    'families': False,
#    'fans': False,
#    'fast': False,
#    'faster': False,
#    'fb': False,
#    'feared': False,
#    'features': False,
#    'feel': False,
#    'female': False,
#    'ff': False,
#    'finally': False,
#    'fish': False,
#    'fishing': False,
#    'five': False,
#    'follow-': False,
#    'foolishness': False,
#    'for': False,
#    'forgiven': False,
#    'forklift': False,
#    'francis': False,
#    'free': False,
#    'fresco': False,
#    'friday': False,
#    'fuck': False,
#    'fucked': False,
#    'game': False,
#    'games': False,
#    'gaming': False,
#    'gen': False,
#    'get': False,
#    'getting': False,
#    'giveusahint': False,
#    'glad': False,
#    'glitches': False,
#    'go': False,
#    'going': False,
#    'good': False,
#    'google': False,
#    'got': False,
#    'great': False,
#    'gt': False,
#    'guess': False,
#    'hafiz': False,
#    'hall': False,
#    'handy': False,
#    'hang': False,
#    'hard': False,
#    'harmony': False,
#    'head': False,
#    'heard': False,
#    'help': False,
#    'helping': False,
#    'hey': False,
#    'hi': False,
#    'his': False,
#    'historic': False,
#    'holiness': False,
#    'hope': False,
#    'hotter': False,
#    'huawei': False,
#    'hundred': False,
#    'hylka-room': False,
#    'i': False,
#    'if': False,
#    'inclusive': False,
#    'income': False,
#    'independence': False,
#    'indiedev': False,
#    'infiltrators': False,
#    'info': False,
#    'installation': False,
#    'interesting': False,
#    'ios': False,
#    'iphone': False,
#    'ipod': False,
#    'is': False,
#    'island': False,
#    'it': False,
#    'its': False,
#    'jailbreaking': False,
#    'jeopardy': False,
#    'jesuit': False,
#    'jesuits': False,
#    'join': False,
#    'julius': False,
#    'july': False,
#    'keyboard': False,
#    'kirby': False,
#    'know': False,
#    'knows': False,
#    'lady': False,
#    'last': False,
#    'late': False,
#    'later': False,
#    'latest': False,
#    'launched': False,
#    'launches': False,
#    'lchbuzz': False,
#    'leader': False,
#    'lean': False,
#    'less': False,
#    'let': False,
#    'life': False,
#    'like': False,
#    'limited': False,
#    'little': False,
#    'live': False,
#    'login': False,
#    'long': False,
#    'looks': False,
#    'lord': False,
#    'lost': False,
#    'love': False,
#    'loving': False,
#    'lure': False,
#    'lyft': False,
#    'made': False,
#    'make': False,
#    'makes': False,
#    'making': False,
#    'man': False,
#    'many': False,
#    'mar': False,
#    'march': False,
#    'marriage': False,
#    'masonic': False,
#    'mass': False,
#    'matter': False,
#    'may': False,
#    'maybe': False,
#    'mcpe': False,
#    'mean': False,
#    'meat': False,
#    'mercy': False,
#    'met': False,
#    'mfl': False,
#    'michelangelo': False,
#    'might': False,
#    'military': False,
#    'million': False,
#    'missed': False,
#    'mm': False,
#    'modernity': False,
#    'mon': False,
#    'monday': False,
#    'month': False,
#    'moral': False,
#    'more': False,
#    'morning': False,
#    'mp3': False,
#    'mr.': False,
#    'much': False,
#    'myspace': False,
#    'na': False,
#    'near': False,
#    'need': True,
#    'network': True,
#    'new': False,
#    'news': False,
#    'news3': False,
#    'next': False,
#    'nice': False,
#    'nintendo': False,
#    'nonsensical': False,
#    'noon': False,
#    'not': False,
#    'novus': False,
#    'nows': False,
#    'numbered': False,
#    'nw': False,
#    'obama': False,
#    'october': False,
#    'officially': False,
#    'old': False,
#    'omen': False,
#    'on': False,
#    'once': False,
#    'one': False,
#    'ones': False,
#    'online': False,
#    'only': False,
#    'open': False,
#    'option': False,
#    'ordo': False,
#    'over': False,
#    'owners': False,
#    'page': False,
#    'pages': False,
#    'pale': False,
#    'paper': False,
#    'parade': False,
#    'parkrun': False,
#    'partnership': False,
#    'party': True,
#    'pass': False,
#    'pelosi': False,
#    'people': False,
#    'phone': False,
#    'photo': False,
#    'plan': False,
#    'platform': False,
#    'please': False,
#    'pod': True,
#    'pope': False,
#    'popefrancis': False,
#    'popular': False,
#    'popularity': False,
#    'portugal': False,
#    'possible': False,
#    'potus': False,
#    'pre-order': False,
#    'presents': False,
#    'primer': False,
#    'print': False,
#    'pro-aborts': False,
#    'problem': False,
#    'procedure': False,
#    'procedures': False,
#    'project': False,
#    'publication': False,
#    'pulled': False,
#    'question': False,
#    'questions': False,
#    'quick': False,
#    'quickie': False,
#    'quickkey': False,
#    'quit': False,
#    'quite': False,
#    'r': False,
#    'radically': False,
#    'rainbow': False,
#    'randomly': False,
#    're': False,
#    'ready': False,
#    'real': False,
#    'really': False,
#    'received': False,
#    'recordings': False,
#    'reformed': False,
#    'refugees': False,
#    'regular': False,
#    'remake': False,
#    'remember': False,
#    'reopen': False,
#    'replaced': False,
#    'reporter': False,
#    'resource': False,
#    'resume': False,
#    'reuters': False,
#    'revolutionized': False,
#    'rhode': False,
#    'right': False,
#    'rolled': False,
#    'roma': False,
#    'ruffe': False,
#    'rules': False,
#    'rumor': False,
#    'run': False,
#    'saeed': False,
#    'said': False,
#    'sale': False,
#    'sanhedrin': False,
#    'sat': False,
#    'saturday': False,
#    'say': False,
#    'sched/stops': False,
#    'school': False,
#    'schools': False,
#    'schumer': False,
#    'security': False,
#    'see': False,
#    'sen.': False,
#    'send': False,
#    'sept': False,
#    'september': False,
#    'serra': False,
#    'sessions': False,
#    'settle': False,
#    'short': False,
#    'shot': False,
#    'shown': False,
#    'signed': False,
#    'signfromgod': False,
#    'simpler': False,
#    'simplifies': False,
#    'sin': False,
#    'sir': False,
#    'siri': False,
#    'sistine': False,
#    'site': False,
#    'smartwatch': False,
#    'so': False,
#    'sold': False,
#    'somebody': False,
#    'soo': False,
#    'soon': False,
#    'sound': False,
#    'speaking': False,
#    'speedenews': False,
#    'spiritual': False,
#    'start': False,
#    'states': False,
#    'still': False,
#    'stop': False,
#    'strikes': False,
#    'strong': False,
#    'style': False,
#    'substantial': False,
#    'suggests': False,
#    'suite': False,
#    'supports': True,
#    'sure': False,
#    'swift': False,
#    't-mobile': False,
#    'take': False,
#    'tecniq': False,
#    'temple': False,
#    'test': False,
#    'thanks': False,
#    'that': False,
#    'the': False,
#    'these': False,
#    'things': False,
#    'think': False,
#    'this': False,
#    'though': False,
#    'thought': False,
#    'thursday': False,
#    'tick': False,
#    'tickets': False,
#    'till': False,
#    'time': False,
#    'tix': False,
#    'to': False,
#    'today': False,
#    'tomorrow': False,
#    'top': False,
#    'tour': False,
#    'towards': False,
#    'town': False,
#    'translated': False,
#    'transport': False,
#    'travestys': False,
#    'tried': False,
#    'true': False,
#    'try': False,
#    'trying': False,
#    'tshirts': False,
#    'tues.': False,
#    'tuesday': False,
#    'tv': False,
#    'twitch': False,
#    'twitter': False,
#    'two': False,
#    'u': False,
#    'u.s.': False,
#    'uk': False,
#    'understand': False,
#    'united': False,
#    'update': False,
#    'upgraded': False,
#    'urn': False,
#    'us': False,
#    'usa': False,
#    'use': False,
#    'users': False,
#    'vatican': False,
#    'venial': False,
#    'via': False,
#    'video': False,
#    'vii': False,
#    'visit': False,
#    'visiting': False,
#    'visits': False,
#    'vote': False,
#    'vpn': False,
#    'vs': False,
#    'wait': False,
#    'walking': False,
#    'wan': False,
#    'want': False,
#    'wants': False,
#    'washington': False,
#    'watch': False,
#    'way': False,
#    'we': False,
#    'wear': False,
#    'web': False,
#    'webinar': False,
#    'webseries': False,
#    'wed': False,
#    'wedding': False,
#    'wednesday': False,
#    'week': False,
#    'weekend': False,
#    'well': False,
#    'went': False,
#    'what': False,
#    'when': False,
#    'where': False,
#    'who': False,
#    'will': False,
#    'winners': False,
#    'wisctv_news3': False,
#    'wish': False,
#    'woodstock': False,
#    'words': False,
#    'work': False,
#    'worked': False,
#    'working': False,
#    'world': False,
#    'worn': False,
#    'worry': False,
#    'would': False,
#    'wrong': False,
#    'wtf': False,
#    'x': False,
#    'xvi': False,
#    'yashan': False,
#    'year': False,
#    'years': False,
#    'yes': False,
#    'you': False,
#    'youtube': False,
#    'yrs': False,
#    'zeroes': False},
#   'pos'),
#  ({'!': False,
#    '#': False,
#    '$': False,
#    '&': False,
#    "'": False,
#    "''": False,
#    "'pope": False,
#    '(': False,
#    ')': False,
#    '+': False,
#    ',': True,
#    '-': False,
#    '--': False,
#    '.': False,
#    '..': False,
#    '...': False,
#    '/': False,
#    '0,12,0/0,12,1': False,
#    '0.12.1': False,
#    '1.99': False,
#    '1/3': False,
#    '10': False,
#    '11th': False,
#    '12': False,
#    '12est': False,
#    '1st': False,
#    '2': False,
#    '2.0': False,
#    '200': False,
#    '21': False,
#    '219': False,
#    '23rd': False,
#    '24': False,
#    '25th': False,
#    '26': False,
#    '27th': False,
#    '28': False,
#    '29': False,
#    '2nd': False,
#    '34th': False,
#    '3pm': False,
#    '3rd': False,
#    '4': False,
#    '4th': False,
#    '5-yearly': False,
#    '5.1.1': False,
#    '6': False,
#    '6.1.6': False,
#    '600': False,
#    '7-8p': False,
#    '8': False,
#    '8-': False,
#    '8/9': False,
#    '8pm': False,
#    '8th': False,
#    '9': False,
#    '9/23': False,
#    '9th': False,
#    ':': True,
#    ';': False,
#    '?': False,
#    '``': False,
#    'a': False,
#    'absentia': False,
#    'access': False,
#    'account': False,
#    'actually': False,
#    'add': False,
#    'address': False,
#    'addresses': False,
#    'aimed': False,
#    'albums': False,
#    'ale': False,
#    'along': False,
#    'already': False,
#    'always': False,
#    'amp': False,
#    'and': False,
#    'android': False,
#    'anniversary': False,
#    'annnounced': False,
#    'annonced': False,
#    'announce': False,
#    'announced': False,
#    'annoying': False,
#    'annulling': False,
#    'annulment': False,
#    'annulments': False,
#    'another': False,
#    'any': False,
#    'anyone': False,
#    'anything': False,
#    'app': True,
#    'appear': False,
#    'applause': False,
#    'apple': False,
#    'appreciate': False,
#    'apps': False,
#    'are': False,
#    'arrives': False,
#    'as': False,
#    'ask': False,
#    'asked': False,
#    'attendant': False,
#    'audience': False,
#    'audio': False,
#    'august': False,
#    'avails': False,
#    'b': False,
#    'back': False,
#    'bad': False,
#    'basilica': False,
#    'bbc': False,
#    'beat': False,
#    'before': False,
#    'begins': False,
#    'believe': False,
#    'benedict': False,
#    'best': False,
#    'biden': False,
#    'bishops': False,
#    'blessed': False,
#    'build': False,
#    'buried': False,
#    'business': False,
#    'busy': False,
#    'but': False,
#    "c'mon": False,
#    'caesar-style': False,
#    'call': False,
#    'calls': False,
#    'can': False,
#    'canada': False,
#    'canonize': False,
#    'cant': False,
#    'canvas': False,
#    'cape': False,
#    'catholic': False,
#    'celebrating': False,
#    'chance': False,
#    'changes': False,
#    'chapel': False,
#    'chat': False,
#    'check': False,
#    'checked': False,
#    'china': False,
#    'chosen': False,
#    'church': False,
#    'churches': False,
#    'city': False,
#    'close': False,
#    'closing': False,
#    'coincidence': False,
#    'come': False,
#    'comes': False,
#    'coming': False,
#    'companies': False,
#    'comparable': False,
#    'compatible': False,
#    'concert': False,
#    'congress': False,
#    'conservative': False,
#    'cont': False,
#    'cool': False,
#    'council': False,
#    'crazy': False,
#    'crossskyhigh': False,
#    'curse': False,
#    'customfoldericons': False,
#    'day': False,
#    'days': False,
#    'dc': False,
#    'december': False,
#    'decent': False,
#    'delta': False,
#    'deserved': False,
#    'developer': False,
#    'device': True,
#    'devices': False,
#    'devs': False,
#    'differences': False,
#    'disagree': False,
#    'disposable': False,
#    'disrespectful': False,
#    'dissent': False,
#    'divorce': False,
#    'dollar': False,
#    'doors': False,
#    'download': True,
#    'downloaded': False,
#    'e.g': False,
#    'easier': False,
#    'easy': False,
#    'edition': False,
#    'edt': False,
#    'else': False,
#    'ended': False,
#    'enterprises': False,
#    'europe': False,
#    'even': False,
#    'event': False,
#    'everyone': False,
#    'excuse': False,
#    'expands': False,
#    'expected': False,
#    'eyes': False,
#    'fairly': False,
#    'families': False,
#    'fans': False,
#    'fast': False,
#    'faster': False,
#    'fb': False,
#    'feared': False,
#    'features': False,
#    'feel': False,
#    'female': False,
#    'ff': False,
#    'finally': False,
#    'fish': False,
#    'fishing': False,
#    'five': False,
#    'follow-': False,
#    'foolishness': False,
#    'for': False,
#    'forgiven': False,
#    'forklift': False,
#    'francis': False,
#    'free': False,
#    'fresco': False,
#    'friday': False,
#    'fuck': False,
#    'fucked': False,
#    'game': False,
#    'games': False,
#    'gaming': False,
#    'gen': False,
#    'get': False,
#    'getting': False,
#    'giveusahint': False,
#    'glad': False,
#    'glitches': False,
#    'go': False,
#    'going': False,
#    'good': False,
#    'google': False,
#    'got': False,
#    'great': False,
#    'gt': False,
#    'guess': False,
#    'hafiz': False,
#    'hall': False,
#    'handy': False,
#    'hang': False,
#    'hard': False,
#    'harmony': False,
#    'head': False,
#    'heard': False,
#    'help': False,
#    'helping': False,
#    'hey': False,
#    'hi': False,
#    'his': False,
#    'historic': False,
#    'holiness': False,
#    'hope': False,
#    'hotter': False,
#    'huawei': False,
#    'hundred': False,
#    'hylka-room': False,
#    'i': False,
#    'if': False,
#    'inclusive': False,
#    'income': False,
#    'independence': False,
#    'indiedev': False,
#    'infiltrators': False,
#    'info': False,
#    'installation': False,
#    'interesting': False,
#    'ios': False,
#    'iphone': False,
#    'ipod': False,
#    'is': False,
#    'island': False,
#    'it': False,
#    'its': False,
#    'jailbreaking': False,
#    'jeopardy': False,
#    'jesuit': False,
#    'jesuits': False,
#    'join': False,
#    'julius': False,
#    'july': False,
#    'keyboard': False,
#    'kirby': False,
#    'know': False,
#    'knows': False,
#    'lady': False,
#    'last': False,
#    'late': False,
#    'later': False,
#    'latest': False,
#    'launched': False,
#    'launches': False,
#    'lchbuzz': False,
#    'leader': False,
#    'lean': False,
#    'less': False,
#    'let': False,
#    'life': False,
#    'like': False,
#    'limited': False,
#    'little': False,
#    'live': False,
#    'login': False,
#    'long': False,
#    'looks': False,
#    'lord': False,
#    'lost': False,
#    'love': False,
#    'loving': False,
#    'lure': False,
#    'lyft': False,
#    'made': False,
#    'make': False,
#    'makes': False,
#    'making': False,
#    'man': False,
#    'many': False,
#    'mar': False,
#    'march': False,
#    'marriage': False,
#    'masonic': False,
#    'mass': False,
#    'matter': False,
#    'may': False,
#    'maybe': False,
#    'mcpe': False,
#    'mean': False,
#    'meat': False,
#    'mercy': False,
#    'met': False,
#    'mfl': False,
#    'michelangelo': False,
#    'might': False,
#    'military': False,
#    'million': False,
#    'missed': False,
#    'mm': False,
#    'modernity': False,
#    'mon': False,
#    'monday': False,
#    'month': False,
#    'moral': False,
#    'more': False,
#    'morning': False,
#    'mp3': False,
#    'mr.': False,
#    'much': False,
#    'myspace': False,
#    'na': False,
#    'near': False,
#    'need': False,
#    'network': False,
#    'new': False,
#    'news': False,
#    'news3': False,
#    'next': False,
#    'nice': False,
#    'nintendo': False,
#    'nonsensical': False,
#    'noon': False,
#    'not': False,
#    'novus': False,
#    'nows': False,
#    'numbered': False,
#    'nw': False,
#    'obama': False,
#    'october': False,
#    'officially': False,
#    'old': False,
#    'omen': False,
#    'on': False,
#    'once': False,
#    'one': False,
#    'ones': False,
#    'online': False,
#    'only': False,
#    'open': False,
#    'option': False,
#    'ordo': False,
#    'over': False,
#    'owners': False,
#    'page': False,
#    'pages': False,
#    'pale': False,
#    'paper': False,
#    'parade': False,
#    'parkrun': False,
#    'partnership': False,
#    'party': False,
#    'pass': False,
#    'pelosi': False,
#    'people': False,
#    'phone': False,
#    'photo': False,
#    'plan': False,
#    'platform': False,
#    'please': False,
#    'pod': False,
#    'pope': False,
#    'popefrancis': False,
#    'popular': False,
#    'popularity': False,
#    'portugal': False,
#    'possible': False,
#    'potus': False,
#    'pre-order': False,
#    'presents': False,
#    'primer': False,
#    'print': False,
#    'pro-aborts': False,
#    'problem': False,
#    'procedure': False,
#    'procedures': False,
#    'project': False,
#    'publication': False,
#    'pulled': False,
#    'question': False,
#    'questions': False,
#    'quick': False,
#    'quickie': False,
#    'quickkey': False,
#    'quit': False,
#    'quite': False,
#    'r': False,
#    'radically': False,
#    'rainbow': False,
#    'randomly': False,
#    're': False,
#    'ready': False,
#    'real': False,
#    'really': False,
#    'received': False,
#    'recordings': False,
#    'reformed': False,
#    'refugees': False,
#    'regular': False,
#    'remake': False,
#    'remember': False,
#    'reopen': False,
#    'replaced': False,
#    'reporter': False,
#    'resource': False,
#    'resume': False,
#    'reuters': False,
#    'revolutionized': False,
#    'rhode': False,
#    'right': False,
#    'rolled': False,
#    'roma': False,
#    'ruffe': False,
#    'rules': False,
#    'rumor': False,
#    'run': False,
#    'saeed': False,
#    'said': False,
#    'sale': False,
#    'sanhedrin': False,
#    'sat': False,
#    'saturday': False,
#    'say': False,
#    'sched/stops': False,
#    'school': False,
#    'schools': False,
#    'schumer': False,
#    'security': False,
#    'see': False,
#    'sen.': False,
#    'send': False,
#    'sept': False,
#    'september': False,
#    'serra': False,
#    'sessions': False,
#    'settle': False,
#    'short': False,
#    'shot': False,
#    'shown': False,
#    'signed': False,
#    'signfromgod': False,
#    'simpler': False,
#    'simplifies': False,
#    'sin': False,
#    'sir': False,
#    'siri': False,
#    'sistine': False,
#    'site': False,
#    'smartwatch': False,
#    'so': False,
#    'sold': False,
#    'somebody': False,
#    'soo': False,
#    'soon': False,
#    'sound': False,
#    'speaking': False,
#    'speedenews': False,
#    'spiritual': False,
#    'start': False,
#    'states': False,
#    'still': False,
#    'stop': False,
#    'strikes': False,
#    'strong': False,
#    'style': False,
#    'substantial': False,
#    'suggests': False,
#    'suite': False,
#    'supports': False,
#    'sure': False,
#    'swift': False,
#    't-mobile': False,
#    'take': False,
#    'tecniq': False,
#    'temple': False,
#    'test': False,
#    'thanks': False,
#    'that': False,
#    'the': False,
#    'these': False,
#    'things': False,
#    'think': False,
#    'this': False,
#    'though': False,
#    'thought': False,
#    'thursday': False,
#    'tick': False,
#    'tickets': False,
#    'till': False,
#    'time': False,
#    'tix': False,
#    'to': False,
#    'today': False,
#    'tomorrow': False,
#    'top': False,
#    'tour': False,
#    'towards': False,
#    'town': False,
#    'translated': False,
#    'transport': False,
#    'travestys': False,
#    'tried': False,
#    'true': False,
#    'try': False,
#    'trying': False,
#    'tshirts': False,
#    'tues.': False,
#    'tuesday': False,
#    'tv': False,
#    'twitch': False,
#    'twitter': False,
#    'two': False,
#    'u': False,
#    'u.s.': False,
#    'uk': False,
#    'understand': False,
#    'united': False,
#    'update': False,
#    'upgraded': False,
#    'urn': False,
#    'us': False,
#    'usa': False,
#    'use': False,
#    'users': False,
#    'vatican': False,
#    'venial': False,
#    'via': False,
#    'video': False,
#    'vii': False,
#    'visit': False,
#    'visiting': False,
#    'visits': False,
#    'vote': False,
#    'vpn': False,
#    'vs': False,
#    'wait': False,
#    'walking': False,
#    'wan': False,
#    'want': False,
#    'wants': False,
#    'washington': False,
#    'watch': False,
#    'way': False,
#    'we': False,
#    'wear': False,
#    'web': False,
#    'webinar': False,
#    'webseries': False,
#    'wed': False,
#    'wedding': False,
#    'wednesday': False,
#    'week': False,
#    'weekend': False,
#    'well': False,
#    'went': False,
#    'what': False,
#    'when': False,
#    'where': False,
#    'who': False,
#    'will': False,
#    'winners': False,
#    'wisctv_news3': False,
#    'wish': False,
#    'woodstock': False,
#    'words': False,
#    'work': False,
#    'worked': False,
#    'working': False,
#    'world': False,
#    'worn': False,
#    'worry': False,
#    'would': False,
#    'wrong': False,
#    'wtf': False,
#    'x': False,
#    'xvi': False,
#    'yashan': False,
#    'year': False,
#    'years': False,
#    'yes': False,
#    'you': False,
#    'youtube': False,
#    'yrs': False,
#    'zeroes': False},
#   'neg'),
#  ({'!': False,
#    '#': False,
#    '$': False,
#    '&': False,
#    "'": False,
#    "''": False,
#    "'pope": False,
#    '(': False,
#    ')': False,
#    '+': False,
#    ',': False,
#    '-': False,
#    '--': False,
#    '.': False,
#    '..': True,
#    '...': False,
#    '/': False,
#    '0,12,0/0,12,1': False,
#    '0.12.1': False,
#    '1.99': False,
#    '1/3': False,
#    '10': False,
#    '11th': False,
#    '12': False,
#    '12est': False,
#    '1st': False,
#    '2': False,
#    '2.0': False,
#    '200': False,
#    '21': False,
#    '219': False,
#    '23rd': False,
#    '24': False,
#    '25th': False,
#    '26': False,
#    '27th': False,
#    '28': False,
#    '29': False,
#    '2nd': False,
#    '34th': False,
#    '3pm': False,
#    '3rd': False,
#    '4': False,
#    '4th': False,
#    '5-yearly': False,
#    '5.1.1': False,
#    '6': False,
#    '6.1.6': False,
#    '600': False,
#    '7-8p': False,
#    '8': False,
#    '8-': False,
#    '8/9': False,
#    '8pm': False,
#    '8th': False,
#    '9': False,
#    '9/23': False,
#    '9th': False,
#    ':': False,
#    ';': False,
#    '?': False,
#    '``': False,
#    'a': False,
#    'absentia': False,
#    'access': False,
#    'account': True,
#    'actually': False,
#    'add': False,
#    'address': False,
#    'addresses': False,
#    'aimed': False,
#    'albums': False,
#    'ale': False,
#    'along': False,
#    'already': False,
#    'always': False,
#    'amp': False,
#    'and': False,
#    'android': False,
#    'anniversary': False,
#    'annnounced': False,
#    'annonced': False,
#    'announce': False,
#    'announced': False,
#    'annoying': False,
#    'annulling': False,
#    'annulment': False,
#    'annulments': False,
#    'another': False,
#    'any': False,
#    'anyone': False,
#    'anything': False,
#    'app': False,
#    'appear': False,
#    'applause': False,
#    'apple': False,
#    'appreciate': False,
#    'apps': False,
#    'are': False,
#    'arrives': False,
#    'as': False,
#    'ask': False,
#    'asked': False,
#    'attendant': False,
#    'audience': False,
#    'audio': False,
#    'august': False,
#    'avails': False,
#    'b': False,
#    'back': False,
#    'bad': False,
#    'basilica': False,
#    'bbc': False,
#    'beat': False,
#    'before': False,
#    'begins': False,
#    'believe': False,
#    'benedict': False,
#    'best': False,
#    'biden': False,
#    'bishops': False,
#    'blessed': False,
#    'build': False,
#    'buried': False,
#    'business': False,
#    'busy': False,
#    'but': False,
#    "c'mon": False,
#    'caesar-style': False,
#    'call': False,
#    'calls': False,
#    'can': False,
#    'canada': False,
#    'canonize': False,
#    'cant': False,
#    'canvas': False,
#    'cape': False,
#    'catholic': False,
#    'celebrating': False,
#    'chance': False,
#    'changes': False,
#    'chapel': False,
#    'chat': False,
#    'check': False,
#    'checked': False,
#    'china': False,
#    'chosen': False,
#    'church': False,
#    'churches': False,
#    'city': False,
#    'close': False,
#    'closing': False,
#    'coincidence': False,
#    'come': False,
#    'comes': False,
#    'coming': False,
#    'companies': False,
#    'comparable': False,
#    'compatible': False,
#    'concert': False,
#    'congress': False,
#    'conservative': False,
#    'cont': False,
#    'cool': False,
#    'council': False,
#    'crazy': False,
#    'crossskyhigh': False,
#    'curse': False,
#    'customfoldericons': False,
#    'day': True,
#    'days': False,
#    'dc': False,
#    'december': False,
#    'decent': False,
#    'delta': False,
#    'deserved': False,
#    'developer': False,
#    'device': False,
#    'devices': False,
#    'devs': False,
#    'differences': False,
#    'disagree': False,
#    'disposable': False,
#    'disrespectful': False,
#    'dissent': False,
#    'divorce': False,
#    'dollar': False,
#    'doors': False,
#    'download': False,
#    'downloaded': False,
#    'e.g': False,
#    'easier': False,
#    'easy': False,
#    'edition': False,
#    'edt': False,
#    'else': False,
#    'ended': False,
#    'enterprises': False,
#    'europe': False,
#    'even': False,
#    'event': False,
#    'everyone': False,
#    'excuse': False,
#    'expands': False,
#    'expected': False,
#    'eyes': False,
#    'fairly': False,
#    'families': False,
#    'fans': False,
#    'fast': False,
#    'faster': False,
#    'fb': False,
#    'feared': False,
#    'features': False,
#    'feel': False,
#    'female': False,
#    'ff': False,
#    'finally': False,
#    'fish': False,
#    'fishing': False,
#    'five': False,
#    'follow-': False,
#    'foolishness': False,
#    'for': False,
#    'forgiven': False,
#    'forklift': False,
#    'francis': False,
#    'free': False,
#    'fresco': False,
#    'friday': False,
#    'fuck': False,
#    'fucked': False,
#    'game': False,
#    'games': False,
#    'gaming': False,
#    'gen': False,
#    'get': False,
#    'getting': False,
#    'giveusahint': False,
#    'glad': False,
#    'glitches': False,
#    'go': False,
#    'going': False,
#    'good': False,
#    'google': False,
#    'got': False,
#    'great': False,
#    'gt': False,
#    'guess': False,
#    'hafiz': False,
#    'hall': False,
#    'handy': False,
#    'hang': False,
#    'hard': False,
#    'harmony': False,
#    'head': False,
#    'heard': False,
#    'help': False,
#    'helping': False,
#    'hey': False,
#    'hi': False,
#    'his': False,
#    'historic': False,
#    'holiness': False,
#    'hope': False,
#    'hotter': False,
#    'huawei': False,
#    'hundred': False,
#    'hylka-room': False,
#    'i': False,
#    'if': False,
#    'inclusive': False,
#    'income': False,
#    'independence': False,
#    'indiedev': False,
#    'infiltrators': False,
#    'info': False,
#    'installation': False,
#    'interesting': False,
#    'ios': False,
#    'iphone': False,
#    'ipod': False,
#    'is': False,
#    'island': False,
#    'it': False,
#    'its': False,
#    'jailbreaking': False,
#    'jeopardy': False,
#    'jesuit': False,
#    'jesuits': False,
#    'join': False,
#    'julius': False,
#    'july': False,
#    'keyboard': False,
#    'kirby': False,
#    'know': False,
#    'knows': False,
#    'lady': False,
#    'last': False,
#    'late': False,
#    'later': False,
#    'latest': True,
#    'launched': False,
#    'launches': False,
#    'lchbuzz': False,
#    'leader': False,
#    'lean': False,
#    'less': False,
#    'let': False,
#    'life': False,
#    'like': False,
#    'limited': False,
#    'little': False,
#    'live': False,
#    'login': False,
#    'long': False,
#    'looks': False,
#    'lord': False,
#    'lost': False,
#    'love': False,
#    'loving': False,
#    'lure': False,
#    'lyft': False,
#    'made': False,
#    'make': False,
#    'makes': False,
#    'making': False,
#    'man': False,
#    'many': False,
#    'mar': False,
#    'march': False,
#    'marriage': False,
#    'masonic': False,
#    'mass': False,
#    'matter': False,
#    'may': True,
#    'maybe': False,
#    'mcpe': False,
#    'mean': False,
#    'meat': False,
#    'mercy': False,
#    'met': False,
#    'mfl': False,
#    'michelangelo': False,
#    'might': False,
#    'military': False,
#    'million': False,
#    'missed': False,
#    'mm': False,
#    'modernity': False,
#    'mon': False,
#    'monday': False,
#    'month': False,
#    'moral': False,
#    'more': False,
#    'morning': False,
#    'mp3': False,
#    'mr.': False,
#    'much': False,
#    'myspace': False,
#    'na': False,
#    'near': False,
#    'need': False,
#    'network': False,
#    'new': False,
#    'news': False,
#    'news3': False,
#    'next': False,
#    'nice': False,
#    'nintendo': False,
#    'nonsensical': False,
#    'noon': False,
#    'not': False,
#    'novus': False,
#    'nows': False,
#    'numbered': False,
#    'nw': False,
#    'obama': False,
#    'october': False,
#    'officially': False,
#    'old': False,
#    'omen': False,
#    'on': False,
#    'once': False,
#    'one': False,
#    'ones': False,
#    'online': False,
#    'only': False,
#    'open': False,
#    'option': False,
#    'ordo': False,
#    'over': False,
#    'owners': False,
#    'page': False,
#    'pages': False,
#    'pale': False,
#    'paper': False,
#    'parade': False,
#    'parkrun': False,
#    'partnership': False,
#    'party': False,
#    'pass': False,
#    'pelosi': False,
#    'people': False,
#    'phone': True,
#    'photo': False,
#    'plan': False,
#    'platform': False,
#    'please': False,
#    'pod': False,
#    'pope': False,
#    'popefrancis': False,
#    'popular': False,
#    'popularity': False,
#    'portugal': False,
#    'possible': False,
#    'potus': False,
#    'pre-order': False,
#    'presents': False,
#    'primer': False,
#    'print': False,
#    'pro-aborts': False,
#    'problem': True,
#    'procedure': False,
#    'procedures': False,
#    'project': False,
#    'publication': False,
#    'pulled': False,
#    'question': False,
#    'questions': False,
#    'quick': False,
#    'quickie': False,
#    'quickkey': False,
#    'quit': False,
#    'quite': False,
#    'r': False,
#    'radically': False,
#    'rainbow': False,
#    'randomly': False,
#    're': False,
#    'ready': False,
#    'real': False,
#    'really': False,
#    'received': False,
#    'recordings': False,
#    'reformed': False,
#    'refugees': False,
#    'regular': False,
#    'remake': False,
#    'remember': False,
#    'reopen': False,
#    'replaced': True,
#    'reporter': False,
#    'resource': False,
#    'resume': False,
#    'reuters': False,
#    'revolutionized': False,
#    'rhode': False,
#    'right': False,
#    'rolled': False,
#    'roma': False,
#    'ruffe': False,
#    'rules': False,
#    'rumor': False,
#    'run': True,
#    'saeed': False,
#    'said': False,
#    'sale': False,
#    'sanhedrin': False,
#    'sat': False,
#    'saturday': False,
#    'say': False,
#    'sched/stops': False,
#    'school': False,
#    'schools': False,
#    'schumer': False,
#    'security': False,
#    'see': False,
#    'sen.': False,
#    'send': False,
#    'sept': False,
#    'september': False,
#    'serra': False,
#    'sessions': False,
#    'settle': False,
#    'short': False,
#    'shot': False,
#    'shown': False,
#    'signed': False,
#    'signfromgod': False,
#    'simpler': False,
#    'simplifies': False,
#    'sin': False,
#    'sir': False,
#    'siri': False,
#    'sistine': False,
#    'site': False,
#    'smartwatch': False,
#    'so': False,
#    'sold': False,
#    'somebody': False,
#    'soo': False,
#    'soon': False,
#    'sound': False,
#    'speaking': False,
#    'speedenews': False,
#    'spiritual': False,
#    'start': False,
#    'states': False,
#    'still': False,
#    'stop': False,
#    'strikes': False,
#    'strong': False,
#    'style': False,
#    'substantial': False,
#    'suggests': False,
#    'suite': False,
#    'supports': False,
#    'sure': False,
#    'swift': False,
#    't-mobile': False,
#    'take': False,
#    'tecniq': False,
#    'temple': False,
#    'test': False,
#    'thanks': False,
#    'that': False,
#    'the': False,
#    'these': False,
#    'things': False,
#    'think': False,
#    'this': False,
#    'though': False,
#    'thought': False,
#    'thursday': False,
#    'tick': False,
#    'tickets': False,
#    'till': False,
#    'time': True,
#    'tix': False,
#    'to': False,
#    'today': False,
#    'tomorrow': False,
#    'top': False,
#    'tour': False,
#    'towards': False,
#    'town': False,
#    'translated': False,
#    'transport': False,
#    'travestys': False,
#    'tried': False,
#    'true': False,
#    'try': False,
#    'trying': False,
#    'tshirts': False,
#    'tues.': False,
#    'tuesday': False,
#    'tv': False,
#    'twitch': False,
#    'twitter': False,
#    'two': False,
#    'u': False,
#    'u.s.': False,
#    'uk': False,
#    'understand': False,
#    'united': False,
#    'update': False,
#    'upgraded': False,
#    'urn': False,
#    'us': False,
#    'usa': False,
#    'use': False,
#    'users': False,
#    'vatican': False,
#    'venial': False,
#    'via': False,
#    'video': False,
#    'vii': False,
#    'visit': False,
#    'visiting': False,
#    'visits': False,
#    'vote': False,
#    'vpn': False,
#    'vs': False,
#    'wait': False,
#    'walking': False,
#    'wan': False,
#    'want': False,
#    'wants': False,
#    'washington': False,
#    'watch': False,
#    'way': False,
#    'we': False,
#    'wear': False,
#    'web': False,
#    'webinar': False,
#    'webseries': False,
#    'wed': False,
#    'wedding': False,
#    'wednesday': False,
#    'week': False,
#    'weekend': False,
#    'well': False,
#    'went': False,
#    'what': False,
#    'when': False,
#    'where': False,
#    'who': False,
#    'will': False,
#    'winners': False,
#    'wisctv_news3': False,
#    'wish': False,
#    'woodstock': False,
#    'words': False,
#    'work': False,
#    'worked': False,
#    'working': False,
#    'world': False,
#    'worn': False,
#    'worry': False,
#    'would': False,
#    'wrong': False,
#    'wtf': False,
#    'x': False,
#    'xvi': False,
#    'yashan': False,
#    'year': False,
#    'years': False,
#    'yes': False,
#    'you': False,
#    'youtube': False,
#    'yrs': False,
#    'zeroes': False},
#   'neg'),
#  ({'!': False,
#    '#': False,
#    '$': False,
#    '&': False,
#    "'": True,
#    "''": False,
#    "'pope": False,
#    '(': False,
#    ')': False,
#    '+': False,
#    ',': False,
#    '-': False,
#    '--': False,
#    '.': False,
#    '..': False,
#    '...': False,
#    '/': False,
#    '0,12,0/0,12,1': False,
#    '0.12.1': False,
#    '1.99': False,
#    '1/3': False,
#    '10': False,
#    '11th': False,
#    '12': False,
#    '12est': False,
#    '1st': False,
#    '2': False,
#    '2.0': False,
#    '200': False,
#    '21': False,
#    '219': False,
#    '23rd': False,
#    '24': False,
#    '25th': False,
#    '26': False,
#    '27th': False,
#    '28': False,
#    '29': False,
#    '2nd': False,
#    '34th': False,
#    '3pm': False,
#    '3rd': False,
#    '4': False,
#    '4th': False,
#    '5-yearly': False,
#    '5.1.1': False,
#    '6': False,
#    '6.1.6': False,
#    '600': False,
#    '7-8p': False,
#    '8': False,
#    '8-': False,
#    '8/9': False,
#    '8pm': False,
#    '8th': False,
#    '9': False,
#    '9/23': False,
#    '9th': False,
#    ':': False,
#    ';': False,
#    '?': True,
#    '``': False,
#    'a': False,
#    'absentia': False,
#    'access': False,
#    'account': False,
#    'actually': False,
#    'add': False,
#    'address': False,
#    'addresses': False,
#    'aimed': False,
#    'albums': False,
#    'ale': False,
#    'along': False,
#    'already': False,
#    'always': False,
#    'amp': False,
#    'and': False,
#    'android': False,
#    'anniversary': False,
#    'annnounced': False,
#    'annonced': False,
#    'announce': False,
#    'announced': False,
#    'annoying': False,
#    'annulling': False,
#    'annulment': False,
#    'annulments': False,
#    'another': False,
#    'any': False,
#    'anyone': False,
#    'anything': True,
#    'app': False,
#    'appear': False,
#    'applause': False,
#    'apple': False,
#    'appreciate': False,
#    'apps': False,
#    'are': False,
#    'arrives': False,
#    'as': False,
#    'ask': True,
#    'asked': False,
#    'attendant': False,
#    'audience': False,
#    'audio': False,
#    'august': False,
#    'avails': False,
#    'b': False,
#    'back': False,
#    'bad': False,
#    'basilica': False,
#    'bbc': False,
#    'beat': False,
#    'before': False,
#    'begins': False,
#    'believe': False,
#    'benedict': False,
#    'best': False,
#    'biden': False,
#    'bishops': False,
#    'blessed': False,
#    'build': False,
#    'buried': False,
#    'business': False,
#    'busy': False,
#    'but': False,
#    "c'mon": False,
#    'caesar-style': False,
#    'call': False,
#    'calls': False,
#    'can': False,
#    'canada': False,
#    'canonize': False,
#    'cant': False,
#    'canvas': False,
#    'cape': False,
#    'catholic': False,
#    'celebrating': False,
#    'chance': False,
#    'changes': False,
#    'chapel': False,
#    'chat': False,
#    'check': False,
#    'checked': False,
#    'china': False,
#    'chosen': False,
#    'church': False,
#    'churches': False,
#    'city': False,
#    'close': False,
#    'closing': False,
#    'coincidence': False,
#    'come': False,
#    'comes': False,
#    'coming': False,
#    'companies': False,
#    'comparable': False,
#    'compatible': False,
#    'concert': False,
#    'congress': False,
#    'conservative': False,
#    'cont': False,
#    'cool': False,
#    'council': False,
#    'crazy': False,
#    'crossskyhigh': False,
#    'curse': False,
#    'customfoldericons': False,
#    'day': False,
#    'days': False,
#    'dc': False,
#    'december': False,
#    'decent': False,
#    'delta': False,
#    'deserved': False,
#    'developer': False,
#    'device': False,
#    'devices': False,
#    'devs': False,
#    'differences': False,
#    'disagree': False,
#    'disposable': False,
#    'disrespectful': False,
#    'dissent': False,
#    'divorce': False,
#    'dollar': False,
#    'doors': False,
#    'download': False,
#    'downloaded': False,
#    'e.g': False,
#    'easier': False,
#    'easy': False,
#    'edition': False,
#    'edt': False,
#    'else': False,
#    'ended': False,
#    'enterprises': False,
#    'europe': False,
#    'even': False,
#    'event': False,
#    'everyone': False,
#    'excuse': False,
#    'expands': False,
#    'expected': False,
#    'eyes': False,
#    'fairly': False,
#    'families': False,
#    'fans': False,
#    'fast': False,
#    'faster': False,
#    'fb': False,
#    'feared': False,
#    'features': False,
#    'feel': False,
#    'female': False,
#    'ff': False,
#    'finally': False,
#    'fish': False,
#    'fishing': False,
#    'five': False,
#    'follow-': False,
#    'foolishness': False,
#    'for': False,
#    'forgiven': False,
#    'forklift': False,
#    'francis': False,
#    'free': False,
#    'fresco': False,
#    'friday': False,
#    'fuck': False,
#    'fucked': False,
#    'game': False,
#    'games': False,
#    'gaming': False,
#    'gen': False,
#    'get': False,
#    'getting': False,
#    'giveusahint': False,
#    'glad': False,
#    'glitches': False,
#    'go': False,
#    'going': False,
#    'good': False,
#    'google': False,
#    'got': False,
#    'great': False,
#    'gt': False,
#    'guess': False,
#    'hafiz': False,
#    'hall': False,
#    'handy': False,
#    'hang': False,
#    'hard': False,
#    'harmony': False,
#    'head': False,
#    'heard': False,
#    'help': False,
#    'helping': True,
#    'hey': False,
#    'hi': False,
#    'his': False,
#    'historic': False,
#    'holiness': False,
#    'hope': False,
#    'hotter': False,
#    'huawei': False,
#    'hundred': False,
#    'hylka-room': False,
#    'i': False,
#    'if': False,
#    'inclusive': False,
#    'income': False,
#    'independence': False,
#    'indiedev': False,
#    'infiltrators': False,
#    'info': False,
#    'installation': False,
#    'interesting': False,
#    'ios': False,
#    'iphone': False,
#    'ipod': False,
#    'is': False,
#    'island': False,
#    'it': False,
#    'its': False,
#    'jailbreaking': False,
#    'jeopardy': False,
#    'jesuit': False,
#    'jesuits': False,
#    'join': False,
#    'julius': False,
#    'july': False,
#    'keyboard': False,
#    'kirby': False,
#    'know': False,
#    'knows': False,
#    'lady': False,
#    'last': False,
#    'late': False,
#    'later': False,
#    'latest': False,
#    'launched': False,
#    'launches': False,
#    'lchbuzz': False,
#    'leader': False,
#    'lean': False,
#    'less': False,
#    'let': False,
#    'life': False,
#    'like': False,
#    'limited': False,
#    'little': False,
#    'live': True,
#    'login': False,
#    'long': False,
#    'looks': False,
#    'lord': False,
#    'lost': False,
#    'love': False,
#    'loving': False,
#    'lure': False,
#    'lyft': False,
#    'made': False,
#    'make': False,
#    'makes': False,
#    'making': False,
#    'man': False,
#    'many': False,
#    'mar': False,
#    'march': False,
#    'marriage': False,
#    'masonic': False,
#    'mass': False,
#    'matter': False,
#    'may': False,
#    'maybe': False,
#    'mcpe': False,
#    'mean': False,
#    'meat': False,
#    'mercy': False,
#    'met': False,
#    'mfl': False,
#    'michelangelo': False,
#    'might': False,
#    'military': False,
#    'million': False,
#    'missed': False,
#    'mm': False,
#    'modernity': False,
#    'mon': False,
#    'monday': False,
#    'month': False,
#    'moral': False,
#    'more': False,
#    'morning': False,
#    'mp3': False,
#    'mr.': False,
#    'much': False,
#    'myspace': False,
#    'na': False,
#    'near': False,
#    'need': False,
#    'network': False,
#    'new': False,
#    'news': False,
#    'news3': False,
#    'next': False,
#    'nice': False,
#    'nintendo': False,
#    'nonsensical': False,
#    'noon': False,
#    'not': False,
#    'novus': False,
#    'nows': False,
#    'numbered': False,
#    'nw': False,
#    'obama': False,
#    'october': False,
#    'officially': False,
#    'old': False,
#    'omen': False,
#    'on': False,
#    'once': False,
#    'one': False,
#    'ones': False,
#    'online': False,
#    'only': False,
#    'open': False,
#    'option': False,
#    'ordo': False,
#    'over': False,
#    'owners': False,
#    'page': False,
#    'pages': False,
#    'pale': False,
#    'paper': False,
#    'parade': False,
#    'parkrun': False,
#    'partnership': False,
#    'party': False,
#    'pass': False,
#    'pelosi': False,
#    'people': False,
#    'phone': False,
#    'photo': False,
#    'plan': False,
#    'platform': False,
#    'please': False,
#    'pod': False,
#    'pope': False,
#    'popefrancis': False,
#    'popular': False,
#    'popularity': False,
#    'portugal': False,
#    'possible': False,
#    'potus': False,
#    'pre-order': False,
#    'presents': False,
#    'primer': False,
#    'print': False,
#    'pro-aborts': False,
#    'problem': False,
#    'procedure': False,
#    'procedures': False,
#    'project': False,
#    'publication': True,
#    'pulled': False,
#    'question': False,
#    'questions': False,
#    'quick': False,
#    'quickie': False,
#    'quickkey': False,
#    'quit': False,
#    'quite': False,
#    'r': False,
#    'radically': False,
#    'rainbow': False,
#    'randomly': False,
#    're': False,
#    'ready': False,
#    'real': False,
#    'really': False,
#    'received': False,
#    'recordings': False,
#    'reformed': False,
#    'refugees': False,
#    'regular': False,
#    'remake': False,
#    'remember': False,
#    'reopen': False,
#    'replaced': False,
#    'reporter': False,
#    'resource': False,
#    'resume': False,
#    'reuters': False,
#    'revolutionized': False,
#    'rhode': False,
#    'right': False,
#    'rolled': False,
#    'roma': False,
#    'ruffe': False,
#    'rules': False,
#    'rumor': False,
#    'run': False,
#    'saeed': False,
#    'said': False,
#    'sale': False,
#    'sanhedrin': False,
#    'sat': False,
#    'saturday': False,
#    'say': False,
#    'sched/stops': False,
#    'school': False,
#    'schools': False,
#    'schumer': False,
#    'security': False,
#    'see': False,
#    'sen.': False,
#    'send': False,
#    'sept': False,
#    'september': False,
#    'serra': False,
#    'sessions': True,
#    'settle': False,
#    'short': False,
#    'shot': False,
#    'shown': False,
#    'signed': False,
#    'signfromgod': False,
#    'simpler': False,
#    'simplifies': False,
#    'sin': False,
#    'sir': False,
#    'siri': False,
#    'sistine': False,
#    'site': False,
#    'smartwatch': False,
#    'so': False,
#    'sold': False,
#    'somebody': False,
#    'soo': False,
#    'soon': False,
#    'sound': False,
#    'speaking': False,
#    'speedenews': False,
#    'spiritual': False,
#    'start': True,
#    'states': False,
#    'still': False,
#    'stop': False,
#    'strikes': False,
#    'strong': False,
#    'style': False,
#    'substantial': False,
#    'suggests': False,
#    'suite': False,
#    'supports': False,
#    'sure': True,
#    'swift': False,
#    't-mobile': False,
#    'take': False,
#    'tecniq': False,
#    'temple': False,
#    'test': False,
#    'thanks': False,
#    'that': False,
#    'the': False,
#    'these': False,
#    'things': False,
#    'think': False,
#    'this': False,
#    'though': False,
#    'thought': False,
#    'thursday': False,
#    'tick': False,
#    'tickets': False,
#    'till': False,
#    'time': False,
#    'tix': False,
#    'to': False,
#    'today': True,
#    'tomorrow': False,
#    'top': False,
#    'tour': False,
#    'towards': False,
#    'town': False,
#    'translated': False,
#    'transport': False,
#    'travestys': False,
#    'tried': False,
#    'true': False,
#    'try': False,
#    'trying': False,
#    'tshirts': False,
#    'tues.': False,
#    'tuesday': False,
#    'tv': False,
#    'twitch': False,
#    'twitter': False,
#    'two': False,
#    'u': False,
#    'u.s.': False,
#    'uk': False,
#    'understand': False,
#    'united': False,
#    'update': False,
#    'upgraded': False,
#    'urn': False,
# ...
#    'recordings': False,
#    'reformed': False,
#    'refugees': False,
#    'regular': False,
#    'remake': False,
#    'remember': False,
#    'reopen': False,
#    'replaced': False,
#    'reporter': False,
#    'resource': False,
#    'resume': False,
#    'reuters': False,
#    'revolutionized': False,
#    'rhode': False,
#    'right': False,
#    'rolled': False,
#    'roma': False,
#    'ruffe': False,
#    'rules': False,
#    'rumor': False,
#    'run': False,
#    'saeed': False,
#    'said': False,
#    'sale': False,
#    'sanhedrin': False,
#    'sat': False,
#    'saturday': False,
#    'say': False,
#    'sched/stops': False,
#    'school': False,
#    'schools': False,
#    'schumer': False,
#    'security': False,
#    'see': True,
#    'sen.': False,
#    'send': False,
#    'sept': False,
#    'september': False,
#    'serra': False,
#    'sessions': False,
#    'settle': False,
#    'short': False,
#    'shot': False,
#    'shown': False,
#    'signed': False,
#    'signfromgod': False,
#    'simpler': False,
#    'simplifies': False,
#    'sin': False,
#    'sir': False,
#    'siri': False,
#    'sistine': False,
#    'site': False,
#    'smartwatch': False,
#    'so': False,
#    'sold': False,
#    'somebody': False,
#    'soo': False,
#    'soon': False,
#    'sound': False,
#    'speaking': False,
#    'speedenews': False,
#    'spiritual': False,
#    'start': False,
#    'states': False,
#    'still': False,
#    'stop': False,
#    'strikes': False,
#    'strong': False,
#    'style': False,
#    'substantial': False,
#    'suggests': False,
#    'suite': False,
#    'supports': False,
#    'sure': False,
#    'swift': False,
#    't-mobile': False,
#    'take': False,
#    'tecniq': False,
#    'temple': False,
#    'test': False,
#    'thanks': False,
#    'that': False,
#    'the': False,
#    'these': False,
#    'things': False,
#    'think': False,
#    'this': False,
#    'though': False,
#    'thought': False,
#    'thursday': False,
#    'tick': False,
#    'tickets': True,
#    'till': False,
#    'time': False,
#    'tix': False,
#    'to': False,
#    'today': False,
#    'tomorrow': False,
#    'top': False,
#    'tour': False,
#    'towards': False,
#    'town': False,
#    'translated': False,
#    'transport': False,
#    'travestys': False,
#    'tried': False,
#    'true': False,
#    'try': False,
#    'trying': False,
#    'tshirts': False,
#    'tues.': False,
#    'tuesday': False,
#    'tv': False,
#    'twitch': False,
#    'twitter': False,
#    'two': False,
#    'u': False,
#    'u.s.': False,
#    'uk': False,
#    'understand': False,
#    'united': False,
#    'update': False,
#    'upgraded': False,
#    'urn': False,
#    'us': False,
#    'usa': False,
#    'use': False,
#    'users': False,
#    'vatican': False,
#    'venial': False,
#    'via': False,
#    'video': False,
#    'vii': False,
#    'visit': False,
#    'visiting': False,
#    'visits': False,
#    'vote': False,
#    'vpn': False,
#    'vs': False,
#    'wait': False,
#    'walking': False,
#    'wan': False,
#    'want': False,
#    'wants': False,
#    'washington': False,
#    'watch': False,
#    'way': False,
#    'we': False,
#    'wear': False,
#    'web': False,
#    'webinar': False,
#    'webseries': False,
#    'wed': False,
#    'wedding': False,
#    'wednesday': False,
#    'week': False,
#    'weekend': False,
#    'well': False,
#    'went': False,
#    'what': False,
#    'when': False,
#    'where': False,
#    'who': False,
#    'will': False,
#    'winners': True,
#    'wisctv_news3': False,
#    'wish': False,
#    'woodstock': False,
#    'words': False,
#    'work': False,
#    'worked': False,
#    'working': False,
#    'world': False,
#    'worn': False,
#    'worry': False,
#    'would': False,
#    'wrong': False,
#    'wtf': False,
#    'x': False,
#    'xvi': False,
#    'yashan': False,
#    'year': False,
#    'years': False,
#    'yes': False,
#    'you': False,
#    'youtube': False,
#    'yrs': False,
#    'zeroes': False},
#   'pos'),
#  ({'!': False,
#    '#': True,
#    '$': False,
#    '&': False,
#    "'": True,
#    "''": False,
#    "'pope": False,
#    '(': False,
#    ')': False,
#    '+': False,
#    ',': False,
#    '-': False,
#    '--': False,
#    '.': False,
#    '..': False,
#    '...': False,
#    '/': False,
#    '0,12,0/0,12,1': False,
#    '0.12.1': False,
#    '1.99': False,
#    '1/3': False,
#    '10': False,
#    '11th': False,
#    '12': False,
#    '12est': False,
#    '1st': False,
#    '2': False,
#    '2.0': False,
#    '200': False,
#    '21': False,
#    '219': False,
#    '23rd': False,
#    '24': False,
#    '25th': False,
#    '26': False,
#    '27th': False,
#    '28': False,
#    '29': False,
#    '2nd': False,
#    '34th': False,
#    '3pm': False,
#    '3rd': False,
#    '4': False,
#    '4th': False,
#    '5-yearly': False,
#    '5.1.1': False,
#    '6': False,
#    '6.1.6': False,
#    '600': False,
#    '7-8p': False,
#    '8': False,
#    '8-': False,
#    '8/9': False,
#    '8pm': False,
#    '8th': False,
#    '9': False,
#    '9/23': False,
#    '9th': False,
#    ':': True,
#    ';': False,
#    '?': False,
#    '``': False,
#    'a': False,
#    'absentia': False,
#    'access': False,
#    'account': False,
#    'actually': False,
#    'add': False,
#    'address': False,
#    'addresses': False,
#    'aimed': False,
#    'albums': False,
#    'ale': False,
#    'along': False,
#    'already': False,
#    'always': False,
#    'amp': False,
#    'and': False,
#    'android': False,
#    'anniversary': False,
#    'annnounced': False,
#    'annonced': False,
#    'announce': False,
#    'announced': False,
#    'annoying': False,
#    'annulling': False,
#    'annulment': True,
#    'annulments': False,
#    'another': False,
#    'any': False,
#    'anyone': False,
#    'anything': False,
#    'app': False,
#    'appear': False,
#    'applause': False,
#    'apple': False,
#    'appreciate': False,
#    'apps': False,
#    'are': False,
#    'arrives': False,
#    'as': False,
#    'ask': False,
#    'asked': False,
#    'attendant': False,
#    'audience': False,
#    'audio': False,
#    'august': False,
#    'avails': False,
#    'b': False,
#    'back': False,
#    'bad': False,
#    'basilica': False,
#    'bbc': False,
#    'beat': False,
#    'before': False,
#    'begins': False,
#    'believe': False,
#    'benedict': False,
#    'best': False,
#    'biden': False,
#    'bishops': False,
#    'blessed': False,
#    'build': False,
#    'buried': False,
#    'business': False,
#    'busy': False,
#    'but': False,
#    "c'mon": False,
#    'caesar-style': False,
#    'call': False,
#    'calls': False,
#    'can': False,
#    'canada': False,
#    'canonize': False,
#    'cant': False,
#    'canvas': False,
#    'cape': False,
#    'catholic': False,
#    'celebrating': False,
#    'chance': False,
#    'changes': True,
#    'chapel': False,
#    'chat': False,
#    'check': False,
#    'checked': False,
#    'china': False,
#    'chosen': False,
#    'church': True,
#    'churches': False,
#    'city': False,
#    'close': False,
#    'closing': False,
#    'coincidence': False,
#    'come': False,
#    'comes': False,
#    'coming': False,
#    'companies': False,
#    'comparable': False,
#    'compatible': False,
#    'concert': False,
#    'congress': False,
#    'conservative': False,
#    'cont': False,
#    'cool': False,
#    'council': False,
#    'crazy': False,
#    'crossskyhigh': False,
#    'curse': False,
#    'customfoldericons': False,
#    'day': False,
#    'days': False,
#    'dc': False,
#    'december': False,
#    'decent': False,
#    'delta': False,
#    'deserved': False,
#    'developer': False,
#    'device': False,
#    'devices': False,
#    'devs': False,
#    'differences': False,
#    'disagree': False,
#    'disposable': False,
#    'disrespectful': False,
#    'dissent': False,
#    'divorce': False,
#    'dollar': False,
#    'doors': False,
#    'download': False,
#    'downloaded': False,
#    'e.g': False,
#    'easier': False,
#    'easy': False,
#    'edition': False,
#    'edt': False,
#    'else': False,
#    'ended': False,
#    'enterprises': False,
#    'europe': False,
#    'even': False,
#    'event': False,
#    'everyone': False,
#    'excuse': False,
#    'expands': False,
#    'expected': True,
#    'eyes': False,
#    'fairly': False,
#    'families': False,
#    'fans': False,
#    'fast': False,
#    'faster': False,
#    'fb': False,
#    'feared': False,
#    'features': False,
#    'feel': False,
#    'female': False,
#    'ff': False,
#    'finally': False,
#    'fish': False,
#    'fishing': False,
#    'five': False,
#    'follow-': False,
#    'foolishness': False,
#    'for': False,
#    'forgiven': False,
#    'forklift': False,
#    'francis': False,
#    'free': False,
#    'fresco': False,
#    'friday': False,
#    'fuck': False,
#    'fucked': False,
#    'game': False,
#    'games': False,
#    'gaming': False,
#    'gen': False,
#    'get': False,
#    'getting': False,
#    'giveusahint': False,
#    'glad': False,
#    'glitches': False,
#    'go': False,
#    'going': False,
#    'good': False,
#    'google': False,
#    'got': False,
#    'great': False,
#    'gt': False,
#    'guess': False,
#    'hafiz': False,
#    'hall': False,
#    'handy': False,
#    'hang': False,
#    'hard': False,
#    'harmony': False,
#    'head': False,
#    'heard': False,
#    'help': False,
#    'helping': False,
#    'hey': False,
#    'hi': False,
#    'his': False,
#    'historic': False,
#    'holiness': False,
#    'hope': False,
#    'hotter': False,
#    'huawei': False,
#    'hundred': False,
#    'hylka-room': False,
#    'i': False,
#    'if': False,
#    'inclusive': True,
#    'income': False,
#    'independence': False,
#    'indiedev': False,
#    'infiltrators': False,
#    'info': False,
#    'installation': False,
#    'interesting': False,
#    'ios': False,
#    'iphone': False,
#    'ipod': False,
#    'is': False,
#    'island': False,
#    'it': False,
#    'its': False,
#    'jailbreaking': False,
#    'jeopardy': False,
#    'jesuit': False,
#    'jesuits': False,
#    'join': False,
#    'julius': False,
#    'july': False,
#    'keyboard': False,
#    'kirby': False,
#    'know': False,
#    'knows': False,
#    'lady': False,
#    'last': False,
#    'late': False,
#    'later': False,
#    'latest': False,
#    'launched': False,
#    'launches': False,
#    'lchbuzz': False,
#    'leader': False,
#    'lean': False,
#    'less': False,
#    'let': False,
#    'life': False,
#    'like': False,
#    'limited': False,
#    'little': False,
#    'live': False,
#    'login': False,
#    'long': False,
#    'looks': False,
#    'lord': False,
#    'lost': False,
#    'love': False,
#    'loving': False,
#    'lure': False,
#    'lyft': False,
#    'made': False,
#    'make': True,
#    'makes': False,
#    'making': False,
#    'man': False,
#    'many': False,
#    'mar': False,
#    'march': False,
#    'marriage': True,
#    'masonic': False,
#    'mass': False,
#    'matter': False,
#    'may': False,
#    'maybe': False,
#    'mcpe': False,
#    'mean': False,
#    'meat': False,
#    'mercy': False,
#    'met': False,
#    'mfl': False,
#    'michelangelo': False,
#    'might': False,
#    'military': False,
#    'million': False,
#    'missed': False,
#    'mm': False,
#    'modernity': False,
#    'mon': False,
#    'monday': False,
#    'month': False,
#    'moral': False,
#    'more': False,
#    'morning': False,
#    'mp3': False,
#    'mr.': False,
#    'much': False,
#    'myspace': False,
#    'na': False,
#    'near': False,
#    'need': False,
#    'network': False,
#    'new': False,
#    'news': False,
#    'news3': True,
#    'next': False,
#    'nice': False,
#    'nintendo': False,
#    'nonsensical': False,
#    'noon': False,
#    'not': False,
#    'novus': False,
#    'nows': False,
#    'numbered': False,
#    'nw': False,
#    'obama': False,
#    'october': False,
#    'officially': False,
#    'old': False,
#    'omen': False,
#    'on': False,
#    'once': False,
#    'one': False,
#    'ones': False,
#    'online': False,
#    'only': False,
#    'open': False,
#    'option': False,
#    'ordo': False,
#    'over': False,
#    'owners': False,
#    'page': False,
#    'pages': False,
#    'pale': False,
#    'paper': False,
#    'parade': False,
#    'parkrun': False,
#    'partnership': False,
#    'party': False,
#    'pass': False,
#    'pelosi': False,
#    'people': False,
#    'phone': False,
#    'photo': False,
#    'plan': False,
#    'platform': False,
#    'please': False,
#    'pod': False,
#    'pope': False,
#    'popefrancis': False,
#    'popular': False,
#    'popularity': False,
#    'portugal': False,
#    'possible': False,
#    'potus': False,
#    'pre-order': False,
#    'presents': False,
#    'primer': False,
#    'print': False,
#    'pro-aborts': False,
#    'problem': False,
#    'procedure': False,
#    'procedures': False,
#    'project': False,
#    'publication': False,
#    'pulled': False,
#    'question': False,
#    'questions': False,
#    'quick': False,
#    'quickie': False,
#    'quickkey': False,
#    'quit': False,
#    'quite': False,
#    'r': False,
#    'radically': False,
#    'rainbow': False,
#    'randomly': False,
#    're': False,
#    'ready': False,
#    'real': False,
#    'really': False,
#    'received': False,
#    'recordings': False,
#    'reformed': False,
#    'refugees': False,
#    'regular': False,
#    'remake': False,
#    'remember': False,
#    'reopen': False,
#    'replaced': False,
#    'reporter': False,
#    'resource': False,
#    'resume': False,
#    'reuters': False,
#    'revolutionized': False,
#    'rhode': False,
#    'right': False,
#    'rolled': False,
#    'roma': False,
#    'ruffe': False,
#    'rules': False,
#    'rumor': False,
#    'run': False,
#    'saeed': False,
#    'said': False,
#    'sale': False,
#    'sanhedrin': False,
#    'sat': False,
#    'saturday': False,
#    'say': False,
#    'sched/stops': False,
#    'school': False,
#    'schools': False,
#    'schumer': False,
#    'security': False,
#    'see': False,
#    'sen.': False,
#    'send': False,
#    'sept': False,
#    'september': False,
#    'serra': False,
#    'sessions': False,
#    'settle': False,
#    'short': False,
#    'shot': False,
#    'shown': False,
#    'signed': False,
#    'signfromgod': False,
#    'simpler': False,
#    'simplifies': False,
#    'sin': False,
#    'sir': False,
#    'siri': False,
#    'sistine': False,
#    'site': False,
#    'smartwatch': False,
#    'so': False,
#    'sold': False,
#    'somebody': False,
#    'soo': False,
#    'soon': False,
#    'sound': False,
#    'speaking': False,
#    'speedenews': False,
#    'spiritual': False,
#    'start': False,
#    'states': False,
#    'still': False,
#    'stop': False,
#    'strikes': False,
#    'strong': False,
#    'style': False,
#    'substantial': False,
#    'suggests': False,
#    'suite': False,
#    'supports': False,
#    'sure': False,
#    'swift': False,
#    't-mobile': False,
#    'take': False,
#    'tecniq': False,
#    'temple': False,
#    'test': False,
#    'thanks': False,
#    'that': False,
#    'the': False,
#    'these': False,
#    'things': False,
#    'think': False,
#    'this': False,
#    'though': False,
#    'thought': False,
#    'thursday': False,
#    'tick': False,
#    'tickets': False,
#    'till': False,
#    'time': False,
#    'tix': False,
#    'to': False,
#    'today': False,
#    'tomorrow': False,
#    'top': False,
#    'tour': False,
#    'towards': False,
#    'town': False,
#    'translated': False,
#    'transport': False,
#    'travestys': False,
#    'tried': False,
#    'true': False,
#    'try': False,
#    'trying': False,
#    'tshirts': False,
#    'tues.': False,
#    'tuesday': False,
#    'tv': False,
#    'twitch': False,
#    'twitter': False,
#    'two': False,
#    'u': False,
#    'u.s.': False,
#    'uk': False,
#    'understand': False,
#    'united': False,
#    'update': False,
#    'upgraded': False,
#    'urn': False,
#    'us': False,
#    'usa': False,
#    'use': False,
#    'users': False,
#    'vatican': False,
#    'venial': False,
#    'via': False,
#    'video': False,
#    'vii': False,
#    'visit': False,
#    'visiting': False,
#    'visits': False,
#    'vote': False,
#    'vpn': False,
#    'vs': False,
#    'wait': False,
#    'walking': False,
#    'wan': False,
#    'want': False,
#    'wants': False,
#    'washington': False,
#    'watch': False,
#    'way': False,
#    'we': False,
#    'wear': False,
#    'web': False,
#    'webinar': False,
#    'webseries': False,
#    'wed': False,
#    'wedding': False,
#    'wednesday': False,
#    'week': False,
#    'weekend': False,
#    'well': False,
#    'went': False,
#    'what': False,
#    'when': False,
#    'where': False,
#    'who': False,
#    'will': False,
#    'winners': False,
#    'wisctv_news3': False,
#    'wish': False,
#    'woodstock': False,
#    'words': False,
#    'work': False,
#    'worked': False,
#    'working': False,
#    'world': False,
#    'worn': False,
#    'worry': False,
#    'would': False,
#    'wrong': False,
#    'wtf': False,
#    'x': False,
#    'xvi': False,
#    'yashan': False,
#    'year': False,
#    'years': False,
#    'yes': False,
#    'you': False,
#    'youtube': False,
#    'yrs': False,
#    'zeroes': False},
#   'neg')]

# %%
classifier = nltk.NaiveBayesClassifier.train(t)

# %%
test_data = "Why should I tweet against someone?"

# %%
test_data_features = {word.lower(): (word in word_tokenize(test_data.lower())) for word in dictionary}

# %%
test_data_features
# Out:
# {'!': False,
#  '#': False,
#  '$': False,
#  '&': False,
#  "'": False,
#  "''": False,
#  "'pope": False,
#  '(': False,
#  ')': False,
#  '+': False,
#  ',': False,
#  '-': False,
#  '--': False,
#  '.': False,
#  '..': False,
#  '...': False,
#  '/': False,
#  '0,12,0/0,12,1': False,
#  '0.12.1': False,
#  '1.99': False,
#  '1/3': False,
#  '10': False,
#  '11th': False,
#  '12': False,
#  '12est': False,
#  '1st': False,
#  '2': False,
#  '2.0': False,
#  '200': False,
#  '21': False,
#  '219': False,
#  '23rd': False,
#  '24': False,
#  '25th': False,
#  '26': False,
#  '27th': False,
#  '28': False,
#  '29': False,
#  '2nd': False,
#  '34th': False,
#  '3pm': False,
#  '3rd': False,
#  '4': False,
#  '4th': False,
#  '5-yearly': False,
#  '5.1.1': False,
#  '6': False,
#  '6.1.6': False,
#  '600': False,
#  '7-8p': False,
#  '8': False,
#  '8-': False,
#  '8/9': False,
#  '8pm': False,
#  '8th': False,
#  '9': False,
#  '9/23': False,
#  '9th': False,
#  ':': False,
#  ';': False,
#  '?': True,
#  '``': False,
#  'a': False,
#  'absentia': False,
#  'access': False,
#  'account': False,
#  'actually': False,
#  'add': False,
#  'address': False,
#  'addresses': False,
#  'aimed': False,
#  'albums': False,
#  'ale': False,
#  'along': False,
#  'already': False,
#  'always': False,
#  'amp': False,
#  'and': False,
#  'android': False,
#  'anniversary': False,
#  'annnounced': False,
#  'annonced': False,
#  'announce': False,
#  'announced': False,
#  'annoying': False,
#  'annulling': False,
#  'annulment': False,
#  'annulments': False,
#  'another': False,
#  'any': False,
#  'anyone': False,
#  'anything': False,
#  'app': False,
#  'appear': False,
#  'applause': False,
#  'apple': False,
#  'appreciate': False,
#  'apps': False,
#  'are': False,
#  'arrives': False,
#  'as': False,
#  'ask': False,
#  'asked': False,
#  'attendant': False,
#  'audience': False,
#  'audio': False,
#  'august': False,
#  'avails': False,
#  'b': False,
#  'back': False,
#  'bad': False,
#  'basilica': False,
#  'bbc': False,
#  'beat': False,
#  'before': False,
#  'begins': False,
#  'believe': False,
#  'benedict': False,
#  'best': False,
#  'biden': False,
#  'bishops': False,
#  'blessed': False,
#  'build': False,
#  'buried': False,
#  'business': False,
#  'busy': False,
#  'but': False,
#  "c'mon": False,
#  'caesar-style': False,
#  'call': False,
#  'calls': False,
#  'can': False,
#  'canada': False,
#  'canonize': False,
#  'cant': False,
#  'canvas': False,
#  'cape': False,
#  'catholic': False,
#  'celebrating': False,
#  'chance': False,
#  'changes': False,
#  'chapel': False,
#  'chat': False,
#  'check': False,
#  'checked': False,
#  'china': False,
#  'chosen': False,
#  'church': False,
#  'churches': False,
#  'city': False,
#  'close': False,
#  'closing': False,
#  'coincidence': False,
#  'come': False,
#  'comes': False,
#  'coming': False,
#  'companies': False,
#  'comparable': False,
#  'compatible': False,
#  'concert': False,
#  'congress': False,
#  'conservative': False,
#  'cont': False,
#  'cool': False,
#  'council': False,
#  'crazy': False,
#  'crossskyhigh': False,
#  'curse': False,
#  'customfoldericons': False,
#  'day': False,
#  'days': False,
#  'dc': False,
#  'december': False,
#  'decent': False,
#  'delta': False,
#  'deserved': False,
#  'developer': False,
#  'device': False,
#  'devices': False,
#  'devs': False,
#  'differences': False,
#  'disagree': False,
#  'disposable': False,
#  'disrespectful': False,
#  'dissent': False,
#  'divorce': False,
#  'dollar': False,
#  'doors': False,
#  'download': False,
#  'downloaded': False,
#  'e.g': False,
#  'easier': False,
#  'easy': False,
#  'edition': False,
#  'edt': False,
#  'else': False,
#  'ended': False,
#  'enterprises': False,
#  'europe': False,
#  'even': False,
#  'event': False,
#  'everyone': False,
#  'excuse': False,
#  'expands': False,
#  'expected': False,
#  'eyes': False,
#  'fairly': False,
#  'families': False,
#  'fans': False,
#  'fast': False,
#  'faster': False,
#  'fb': False,
#  'feared': False,
#  'features': False,
#  'feel': False,
#  'female': False,
#  'ff': False,
#  'finally': False,
#  'fish': False,
#  'fishing': False,
#  'five': False,
#  'follow-': False,
#  'foolishness': False,
#  'for': False,
#  'forgiven': False,
#  'forklift': False,
#  'francis': False,
#  'free': False,
#  'fresco': False,
#  'friday': False,
#  'fuck': False,
#  'fucked': False,
#  'game': False,
#  'games': False,
#  'gaming': False,
#  'gen': False,
#  'get': False,
#  'getting': False,
#  'giveusahint': False,
#  'glad': False,
#  'glitches': False,
#  'go': False,
#  'going': False,
#  'good': False,
#  'google': False,
#  'got': False,
#  'great': False,
#  'gt': False,
#  'guess': False,
#  'hafiz': False,
#  'hall': False,
#  'handy': False,
#  'hang': False,
#  'hard': False,
#  'harmony': False,
#  'head': False,
#  'heard': False,
#  'help': False,
#  'helping': False,
#  'hey': False,
#  'hi': False,
#  'his': False,
#  'historic': False,
#  'holiness': False,
#  'hope': False,
#  'hotter': False,
#  'huawei': False,
#  'hundred': False,
#  'hylka-room': False,
#  'i': True,
#  'if': False,
#  'inclusive': False,
#  'income': False,
#  'independence': False,
#  'indiedev': False,
#  'infiltrators': False,
#  'info': False,
#  'installation': False,
#  'interesting': False,
#  'ios': False,
#  'iphone': False,
#  'ipod': False,
#  'is': False,
#  'island': False,
#  'it': False,
#  'its': False,
#  'jailbreaking': False,
#  'jeopardy': False,
#  'jesuit': False,
#  'jesuits': False,
#  'join': False,
#  'julius': False,
#  'july': False,
#  'keyboard': False,
#  'kirby': False,
#  'know': False,
#  'knows': False,
#  'lady': False,
#  'last': False,
#  'late': False,
#  'later': False,
#  'latest': False,
#  'launched': False,
#  'launches': False,
#  'lchbuzz': False,
#  'leader': False,
#  'lean': False,
#  'less': False,
#  'let': False,
#  'life': False,
#  'like': False,
#  'limited': False,
#  'little': False,
#  'live': False,
#  'login': False,
#  'long': False,
#  'looks': False,
#  'lord': False,
#  'lost': False,
#  'love': False,
#  'loving': False,
#  'lure': False,
#  'lyft': False,
#  'made': False,
#  'make': False,
#  'makes': False,
#  'making': False,
#  'man': False,
#  'many': False,
#  'mar': False,
#  'march': False,
#  'marriage': False,
#  'masonic': False,
#  'mass': False,
#  'matter': False,
#  'may': False,
#  'maybe': False,
#  'mcpe': False,
#  'mean': False,
#  'meat': False,
#  'mercy': False,
#  'met': False,
#  'mfl': False,
#  'michelangelo': False,
#  'might': False,
#  'military': False,
#  'million': False,
#  'missed': False,
#  'mm': False,
#  'modernity': False,
#  'mon': False,
#  'monday': False,
#  'month': False,
#  'moral': False,
#  'more': False,
#  'morning': False,
#  'mp3': False,
#  'mr.': False,
#  'much': False,
#  'myspace': False,
#  'na': False,
#  'near': False,
#  'need': False,
#  'network': False,
#  'new': False,
#  'news': False,
#  'news3': False,
#  'next': False,
#  'nice': False,
#  'nintendo': False,
#  'nonsensical': False,
#  'noon': False,
#  'not': False,
#  'novus': False,
#  'nows': False,
#  'numbered': False,
#  'nw': False,
#  'obama': False,
#  'october': False,
#  'officially': False,
#  'old': False,
#  'omen': False,
#  'on': False,
#  'once': False,
#  'one': False,
#  'ones': False,
#  'online': False,
#  'only': False,
#  'open': False,
#  'option': False,
#  'ordo': False,
#  'over': False,
#  'owners': False,
#  'page': False,
#  'pages': False,
#  'pale': False,
#  'paper': False,
#  'parade': False,
#  'parkrun': False,
#  'partnership': False,
#  'party': False,
#  'pass': False,
#  'pelosi': False,
#  'people': False,
#  'phone': False,
#  'photo': False,
#  'plan': False,
#  'platform': False,
#  'please': False,
#  'pod': False,
#  'pope': False,
#  'popefrancis': False,
#  'popular': False,
#  'popularity': False,
#  'portugal': False,
#  'possible': False,
#  'potus': False,
#  'pre-order': False,
#  'presents': False,
#  'primer': False,
#  'print': False,
#  'pro-aborts': False,
#  'problem': False,
#  'procedure': False,
#  'procedures': False,
#  'project': False,
#  'publication': False,
#  'pulled': False,
#  'question': False,
#  'questions': False,
#  'quick': False,
#  'quickie': False,
#  'quickkey': False,
#  'quit': False,
#  'quite': False,
#  'r': False,
#  'radically': False,
#  'rainbow': False,
#  'randomly': False,
#  're': False,
#  'ready': False,
#  'real': False,
#  'really': False,
#  'received': False,
#  'recordings': False,
#  'reformed': False,
#  'refugees': False,
#  'regular': False,
#  'remake': False,
#  'remember': False,
#  'reopen': False,
#  'replaced': False,
#  'reporter': False,
#  'resource': False,
#  'resume': False,
#  'reuters': False,
#  'revolutionized': False,
#  'rhode': False,
#  'right': False,
#  'rolled': False,
#  'roma': False,
#  'ruffe': False,
#  'rules': False,
#  'rumor': False,
#  'run': False,
#  'saeed': False,
#  'said': False,
#  'sale': False,
#  'sanhedrin': False,
#  'sat': False,
#  'saturday': False,
#  'say': False,
#  'sched/stops': False,
#  'school': False,
#  'schools': False,
#  'schumer': False,
#  'security': False,
#  'see': False,
#  'sen.': False,
#  'send': False,
#  'sept': False,
#  'september': False,
#  'serra': False,
#  'sessions': False,
#  'settle': False,
#  'short': False,
#  'shot': False,
#  'shown': False,
#  'signed': False,
#  'signfromgod': False,
#  'simpler': False,
#  'simplifies': False,
#  'sin': False,
#  'sir': False,
#  'siri': False,
#  'sistine': False,
#  'site': False,
#  'smartwatch': False,
#  'so': False,
#  'sold': False,
#  'somebody': False,
#  'soo': False,
#  'soon': False,
#  'sound': False,
#  'speaking': False,
#  'speedenews': False,
#  'spiritual': False,
#  'start': False,
#  'states': False,
#  'still': False,
#  'stop': False,
#  'strikes': False,
#  'strong': False,
#  'style': False,
#  'substantial': False,
#  'suggests': False,
#  'suite': False,
#  'supports': False,
#  'sure': False,
#  'swift': False,
#  't-mobile': False,
#  'take': False,
#  'tecniq': False,
#  'temple': False,
#  'test': False,
#  'thanks': False,
#  'that': False,
#  'the': False,
#  'these': False,
#  'things': False,
#  'think': False,
#  'this': False,
#  'though': False,
#  'thought': False,
#  'thursday': False,
#  'tick': False,
#  'tickets': False,
#  'till': False,
#  'time': False,
#  'tix': False,
#  'to': False,
#  'today': False,
#  'tomorrow': False,
#  'top': False,
#  'tour': False,
#  'towards': False,
#  'town': False,
#  'translated': False,
#  'transport': False,
#  'travestys': False,
#  'tried': False,
#  'true': False,
#  'try': False,
#  'trying': False,
#  'tshirts': False,
#  'tues.': False,
#  'tuesday': False,
#  'tv': False,
#  'twitch': False,
#  'twitter': False,
#  'two': False,
#  'u': False,
#  'u.s.': False,
#  'uk': False,
#  'understand': False,
#  'united': False,
#  'update': False,
#  'upgraded': False,
#  'urn': False,
#  'us': False,
#  'usa': False,
#  'use': False,
#  'users': False,
#  'vatican': False,
#  'venial': False,
#  'via': False,
#  'video': False,
#  'vii': False,
#  'visit': False,
#  'visiting': False,
#  'visits': False,
#  'vote': False,
#  'vpn': False,
#  'vs': False,
#  'wait': False,
#  'walking': False,
#  'wan': False,
#  'want': False,
#  'wants': False,
#  'washington': False,
#  'watch': False,
#  'way': False,
#  'we': False,
#  'wear': False,
#  'web': False,
#  'webinar': False,
#  'webseries': False,
#  'wed': False,
#  'wedding': False,
#  'wednesday': False,
#  'week': False,
#  'weekend': False,
#  'well': False,
#  'went': False,
#  'what': False,
#  'when': False,
#  'where': False,
#  'who': False,
#  'will': False,
#  'winners': False,
#  'wisctv_news3': False,
#  'wish': False,
#  'woodstock': False,
#  'words': False,
#  'work': False,
#  'worked': False,
#  'working': False,
#  'world': False,
#  'worn': False,
#  'worry': False,
#  'would': False,
#  'wrong': False,
#  'wtf': False,
#  'x': False,
#  'xvi': False,
#  'yashan': False,
#  'year': False,
#  'years': False,
#  'yes': False,
#  'you': False,
#  'youtube': False,
#  'yrs': False,
#  'zeroes': False}

# %%
classifier.classify(test_data_features)
# Out:
# 'pos'

# %%
test_data2 = "It's a beautiful day!"

# %%
test_data_features2 = {word.lower(): (word in word_tokenize(test_data2.lower())) for word in dictionary}

# %%
test_data_features2
# Out:
# {'!': True,
#  '#': False,
#  '$': False,
#  '&': False,
#  "'": False,
#  "''": False,
#  "'pope": False,
#  '(': False,
#  ')': False,
#  '+': False,
#  ',': False,
#  '-': False,
#  '--': False,
#  '.': False,
#  '..': False,
#  '...': False,
#  '/': False,
#  '0,12,0/0,12,1': False,
#  '0.12.1': False,
#  '1.99': False,
#  '1/3': False,
#  '10': False,
#  '11th': False,
#  '12': False,
#  '12est': False,
#  '1st': False,
#  '2': False,
#  '2.0': False,
#  '200': False,
#  '21': False,
#  '219': False,
#  '23rd': False,
#  '24': False,
#  '25th': False,
#  '26': False,
#  '27th': False,
#  '28': False,
#  '29': False,
#  '2nd': False,
#  '34th': False,
#  '3pm': False,
#  '3rd': False,
#  '4': False,
#  '4th': False,
#  '5-yearly': False,
#  '5.1.1': False,
#  '6': False,
#  '6.1.6': False,
#  '600': False,
#  '7-8p': False,
#  '8': False,
#  '8-': False,
#  '8/9': False,
#  '8pm': False,
#  '8th': False,
#  '9': False,
#  '9/23': False,
#  '9th': False,
#  ':': False,
#  ';': False,
#  '?': False,
#  '``': False,
#  'a': True,
#  'absentia': False,
#  'access': False,
#  'account': False,
#  'actually': False,
#  'add': False,
#  'address': False,
#  'addresses': False,
#  'aimed': False,
#  'albums': False,
#  'ale': False,
#  'along': False,
#  'already': False,
#  'always': False,
#  'amp': False,
#  'and': False,
#  'android': False,
#  'anniversary': False,
#  'annnounced': False,
#  'annonced': False,
#  'announce': False,
#  'announced': False,
#  'annoying': False,
#  'annulling': False,
#  'annulment': False,
#  'annulments': False,
#  'another': False,
#  'any': False,
#  'anyone': False,
#  'anything': False,
#  'app': False,
#  'appear': False,
#  'applause': False,
#  'apple': False,
#  'appreciate': False,
#  'apps': False,
#  'are': False,
#  'arrives': False,
#  'as': False,
#  'ask': False,
#  'asked': False,
#  'attendant': False,
#  'audience': False,
#  'audio': False,
#  'august': False,
#  'avails': False,
#  'b': False,
#  'back': False,
#  'bad': False,
#  'basilica': False,
#  'bbc': False,
#  'beat': False,
#  'before': False,
#  'begins': False,
#  'believe': False,
#  'benedict': False,
#  'best': False,
#  'biden': False,
#  'bishops': False,
#  'blessed': False,
#  'build': False,
#  'buried': False,
#  'business': False,
#  'busy': False,
#  'but': False,
#  "c'mon": False,
#  'caesar-style': False,
#  'call': False,
#  'calls': False,
#  'can': False,
#  'canada': False,
#  'canonize': False,
#  'cant': False,
#  'canvas': False,
#  'cape': False,
#  'catholic': False,
#  'celebrating': False,
#  'chance': False,
#  'changes': False,
#  'chapel': False,
#  'chat': False,
#  'check': False,
#  'checked': False,
#  'china': False,
#  'chosen': False,
#  'church': False,
#  'churches': False,
#  'city': False,
#  'close': False,
#  'closing': False,
#  'coincidence': False,
#  'come': False,
#  'comes': False,
#  'coming': False,
#  'companies': False,
#  'comparable': False,
#  'compatible': False,
#  'concert': False,
#  'congress': False,
#  'conservative': False,
#  'cont': False,
#  'cool': False,
#  'council': False,
#  'crazy': False,
#  'crossskyhigh': False,
#  'curse': False,
#  'customfoldericons': False,
#  'day': True,
#  'days': False,
#  'dc': False,
#  'december': False,
#  'decent': False,
#  'delta': False,
#  'deserved': False,
#  'developer': False,
#  'device': False,
#  'devices': False,
#  'devs': False,
#  'differences': False,
#  'disagree': False,
#  'disposable': False,
#  'disrespectful': False,
#  'dissent': False,
#  'divorce': False,
#  'dollar': False,
#  'doors': False,
#  'download': False,
#  'downloaded': False,
#  'e.g': False,
#  'easier': False,
#  'easy': False,
#  'edition': False,
#  'edt': False,
#  'else': False,
#  'ended': False,
#  'enterprises': False,
#  'europe': False,
#  'even': False,
#  'event': False,
#  'everyone': False,
#  'excuse': False,
#  'expands': False,
#  'expected': False,
#  'eyes': False,
#  'fairly': False,
#  'families': False,
#  'fans': False,
#  'fast': False,
#  'faster': False,
#  'fb': False,
#  'feared': False,
#  'features': False,
#  'feel': False,
#  'female': False,
#  'ff': False,
#  'finally': False,
#  'fish': False,
#  'fishing': False,
#  'five': False,
#  'follow-': False,
#  'foolishness': False,
#  'for': False,
#  'forgiven': False,
#  'forklift': False,
#  'francis': False,
#  'free': False,
#  'fresco': False,
#  'friday': False,
#  'fuck': False,
#  'fucked': False,
#  'game': False,
#  'games': False,
#  'gaming': False,
#  'gen': False,
#  'get': False,
#  'getting': False,
#  'giveusahint': False,
#  'glad': False,
#  'glitches': False,
#  'go': False,
#  'going': False,
#  'good': False,
#  'google': False,
#  'got': False,
#  'great': False,
#  'gt': False,
#  'guess': False,
#  'hafiz': False,
#  'hall': False,
#  'handy': False,
#  'hang': False,
#  'hard': False,
#  'harmony': False,
#  'head': False,
#  'heard': False,
#  'help': False,
#  'helping': False,
#  'hey': False,
#  'hi': False,
#  'his': False,
#  'historic': False,
#  'holiness': False,
#  'hope': False,
#  'hotter': False,
#  'huawei': False,
#  'hundred': False,
#  'hylka-room': False,
#  'i': False,
#  'if': False,
#  'inclusive': False,
#  'income': False,
#  'independence': False,
#  'indiedev': False,
#  'infiltrators': False,
#  'info': False,
#  'installation': False,
#  'interesting': False,
#  'ios': False,
#  'iphone': False,
#  'ipod': False,
#  'is': False,
#  'island': False,
#  'it': True,
#  'its': False,
#  'jailbreaking': False,
#  'jeopardy': False,
#  'jesuit': False,
#  'jesuits': False,
#  'join': False,
#  'julius': False,
#  'july': False,
#  'keyboard': False,
#  'kirby': False,
#  'know': False,
#  'knows': False,
#  'lady': False,
#  'last': False,
#  'late': False,
#  'later': False,
#  'latest': False,
#  'launched': False,
#  'launches': False,
#  'lchbuzz': False,
#  'leader': False,
#  'lean': False,
#  'less': False,
#  'let': False,
#  'life': False,
#  'like': False,
#  'limited': False,
#  'little': False,
#  'live': False,
#  'login': False,
#  'long': False,
#  'looks': False,
#  'lord': False,
#  'lost': False,
#  'love': False,
#  'loving': False,
#  'lure': False,
#  'lyft': False,
#  'made': False,
#  'make': False,
#  'makes': False,
#  'making': False,
#  'man': False,
#  'many': False,
#  'mar': False,
#  'march': False,
#  'marriage': False,
#  'masonic': False,
#  'mass': False,
#  'matter': False,
#  'may': False,
#  'maybe': False,
#  'mcpe': False,
#  'mean': False,
#  'meat': False,
#  'mercy': False,
#  'met': False,
#  'mfl': False,
#  'michelangelo': False,
#  'might': False,
#  'military': False,
#  'million': False,
#  'missed': False,
#  'mm': False,
#  'modernity': False,
#  'mon': False,
#  'monday': False,
#  'month': False,
#  'moral': False,
#  'more': False,
#  'morning': False,
#  'mp3': False,
#  'mr.': False,
#  'much': False,
#  'myspace': False,
#  'na': False,
#  'near': False,
#  'need': False,
#  'network': False,
#  'new': False,
#  'news': False,
#  'news3': False,
#  'next': False,
#  'nice': False,
#  'nintendo': False,
#  'nonsensical': False,
#  'noon': False,
#  'not': False,
#  'novus': False,
#  'nows': False,
#  'numbered': False,
#  'nw': False,
#  'obama': False,
#  'october': False,
#  'officially': False,
#  'old': False,
#  'omen': False,
#  'on': False,
#  'once': False,
#  'one': False,
#  'ones': False,
#  'online': False,
#  'only': False,
#  'open': False,
#  'option': False,
#  'ordo': False,
#  'over': False,
#  'owners': False,
#  'page': False,
#  'pages': False,
#  'pale': False,
#  'paper': False,
#  'parade': False,
#  'parkrun': False,
#  'partnership': False,
#  'party': False,
#  'pass': False,
#  'pelosi': False,
#  'people': False,
#  'phone': False,
#  'photo': False,
#  'plan': False,
#  'platform': False,
#  'please': False,
#  'pod': False,
#  'pope': False,
#  'popefrancis': False,
#  'popular': False,
#  'popularity': False,
#  'portugal': False,
#  'possible': False,
#  'potus': False,
#  'pre-order': False,
#  'presents': False,
#  'primer': False,
#  'print': False,
#  'pro-aborts': False,
#  'problem': False,
#  'procedure': False,
#  'procedures': False,
#  'project': False,
#  'publication': False,
#  'pulled': False,
#  'question': False,
#  'questions': False,
#  'quick': False,
#  'quickie': False,
#  'quickkey': False,
#  'quit': False,
#  'quite': False,
#  'r': False,
#  'radically': False,
#  'rainbow': False,
#  'randomly': False,
#  're': False,
#  'ready': False,
#  'real': False,
#  'really': False,
#  'received': False,
#  'recordings': False,
#  'reformed': False,
#  'refugees': False,
#  'regular': False,
#  'remake': False,
#  'remember': False,
#  'reopen': False,
#  'replaced': False,
#  'reporter': False,
#  'resource': False,
#  'resume': False,
#  'reuters': False,
#  'revolutionized': False,
#  'rhode': False,
#  'right': False,
#  'rolled': False,
#  'roma': False,
#  'ruffe': False,
#  'rules': False,
#  'rumor': False,
#  'run': False,
#  'saeed': False,
#  'said': False,
#  'sale': False,
#  'sanhedrin': False,
#  'sat': False,
#  'saturday': False,
#  'say': False,
#  'sched/stops': False,
#  'school': False,
#  'schools': False,
#  'schumer': False,
#  'security': False,
#  'see': False,
#  'sen.': False,
#  'send': False,
#  'sept': False,
#  'september': False,
#  'serra': False,
#  'sessions': False,
#  'settle': False,
#  'short': False,
#  'shot': False,
#  'shown': False,
#  'signed': False,
#  'signfromgod': False,
#  'simpler': False,
#  'simplifies': False,
#  'sin': False,
#  'sir': False,
#  'siri': False,
#  'sistine': False,
#  'site': False,
#  'smartwatch': False,
#  'so': False,
#  'sold': False,
#  'somebody': False,
#  'soo': False,
#  'soon': False,
#  'sound': False,
#  'speaking': False,
#  'speedenews': False,
#  'spiritual': False,
#  'start': False,
#  'states': False,
#  'still': False,
#  'stop': False,
#  'strikes': False,
#  'strong': False,
#  'style': False,
#  'substantial': False,
#  'suggests': False,
#  'suite': False,
#  'supports': False,
#  'sure': False,
#  'swift': False,
#  't-mobile': False,
#  'take': False,
#  'tecniq': False,
#  'temple': False,
#  'test': False,
#  'thanks': False,
#  'that': False,
#  'the': False,
#  'these': False,
#  'things': False,
#  'think': False,
#  'this': False,
#  'though': False,
#  'thought': False,
#  'thursday': False,
#  'tick': False,
#  'tickets': False,
#  'till': False,
#  'time': False,
#  'tix': False,
#  'to': False,
#  'today': False,
#  'tomorrow': False,
#  'top': False,
#  'tour': False,
#  'towards': False,
#  'town': False,
#  'translated': False,
#  'transport': False,
#  'travestys': False,
#  'tried': False,
#  'true': False,
#  'try': False,
#  'trying': False,
#  'tshirts': False,
#  'tues.': False,
#  'tuesday': False,
#  'tv': False,
#  'twitch': False,
#  'twitter': False,
#  'two': False,
#  'u': False,
#  'u.s.': False,
#  'uk': False,
#  'understand': False,
#  'united': False,
#  'update': False,
#  'upgraded': False,
#  'urn': False,
#  'us': False,
#  'usa': False,
#  'use': False,
#  'users': False,
#  'vatican': False,
#  'venial': False,
#  'via': False,
#  'video': False,
#  'vii': False,
#  'visit': False,
#  'visiting': False,
#  'visits': False,
#  'vote': False,
#  'vpn': False,
#  'vs': False,
#  'wait': False,
#  'walking': False,
#  'wan': False,
#  'want': False,
#  'wants': False,
#  'washington': False,
#  'watch': False,
#  'way': False,
#  'we': False,
#  'wear': False,
#  'web': False,
#  'webinar': False,
#  'webseries': False,
#  'wed': False,
#  'wedding': False,
#  'wednesday': False,
#  'week': False,
#  'weekend': False,
#  'well': False,
#  'went': False,
#  'what': False,
#  'when': False,
#  'where': False,
#  'who': False,
#  'will': False,
#  'winners': False,
#  'wisctv_news3': False,
#  'wish': False,
#  'woodstock': False,
#  'words': False,
#  'work': False,
#  'worked': False,
#  'working': False,
#  'world': False,
#  'worn': False,
#  'worry': False,
#  'would': False,
#  'wrong': False,
#  'wtf': False,
#  'x': False,
#  'xvi': False,
#  'yashan': False,
#  'year': False,
#  'years': False,
#  'yes': False,
#  'you': False,
#  'youtube': False,
#  'yrs': False,
#  'zeroes': False}

# %%
classifier.classify(test_data_features2)
# Out:
# 'neg'
