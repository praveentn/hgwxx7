# %% [markdown]
# # Pattern Recognition

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker
import matplotlib.dates as mdates
import numpy as np

from matplotlib import style
style.use("ggplot")

# %%
fn = lambda astr: mdates.strpdate2num('%Y%m%d%H%M%S')(astr.decode())

# %% [markdown]
# To avoid the following error
#
# TypeError: strptime() argument 0 must be str, not <class 'bytes'>

# %%
def graphRawFX():
    date,bid,ask = np.loadtxt('GBPUSD1m.txt', unpack=True, delimiter=',', converters={0:fn})

    fig = plt.figure(figsize=(10,7))

    ax1 = plt.subplot2grid((40,40), (0,0), rowspan=40, colspan=40)
    ax1.plot(date,bid)
    ax1.plot(date,ask)

    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    plt.subplots_adjust(bottom=.23)
    plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
    plt.grid(True)
    plt.show()

# %%
graphRawFX()

# %%
def mingraphRawFX():
    date,bid,ask = np.loadtxt('GBPUSD1d.txt', unpack=True, delimiter=',', converters={0:fn})

    fig = plt.figure(figsize=(10,7))

    ax1 = plt.subplot2grid((40,40), (0,0), rowspan=40, colspan=40)
    ax1.plot(date,bid)
    ax1.plot(date,ask)

    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    plt.subplots_adjust(bottom=.23)
    plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)
    plt.grid(True)
    plt.show()

# %%
mingraphRawFX()

# %%
def mingraphRawFX2():
    date,bid,ask = np.loadtxt('GBPUSD1d.txt', unpack=True, delimiter=',', converters={0:fn})

    fig = plt.figure(figsize=(10,7))

    ax1 = plt.subplot2grid((40,40), (0,0), rowspan=40, colspan=40)
    ax1.plot(date,bid)
    ax1.plot(date,ask)

    ax1.xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))

    for label in ax1.xaxis.get_ticklabels():
        label.set_rotation(45)
    plt.subplots_adjust(bottom=.23)
    plt.gca().get_yaxis().get_major_formatter().set_useOffset(False)

    #######
    ax1_2 = ax1.twinx()
    ax1_2.fill_between(date, 0, (ask-bid), facecolor='c',alpha=.3)
    plt.subplots_adjust(bottom=.23)
    
    plt.grid(True)
    plt.show()

# %%
mingraphRawFX2()

# %%
import pandas as pd

# %%
data = pd.read_csv('GBPUSD1d.txt', names = ['date', 'bid', 'ask'])

# %%
data.head()
# Out:
#              date      bid      ask
# 0  20130501000000  1.55358  1.55371
# 1  20130501000000  1.55357  1.55369
# 2  20130501000000  1.55353  1.55367
# 3  20130501000000  1.55349  1.55367
# 4  20130501000000  1.55349  1.55367

# %%
data['date'] = data['date'].apply(lambda x: pd.to_datetime(str(x), format='%Y%m%d%H%M%S'))

# %%
data.head()
# Out:
#         date      bid      ask
# 0 2013-05-01  1.55358  1.55371
# 1 2013-05-01  1.55357  1.55369
# 2 2013-05-01  1.55353  1.55367
# 3 2013-05-01  1.55349  1.55367
# 4 2013-05-01  1.55349  1.55367

# %%
data.tail()
# Out:
#                      date      bid      ask
# 62007 2013-05-01 23:59:53  1.55693  1.55710
# 62008 2013-05-01 23:59:54  1.55694  1.55709
# 62009 2013-05-01 23:59:58  1.55694  1.55709
# 62010 2013-05-01 23:59:59  1.55696  1.55711
# 62011 2013-05-01 23:59:59  1.55696  1.55711

# %%
data.describe()
# Out:
#                 bid           ask
# count  62012.000000  62012.000000
# mean       1.556589      1.556708
# std        0.001704      0.001695
# min        1.552630      1.552730
# 25%        1.555700      1.555860
# 50%        1.556890      1.557000
# 75%        1.557900      1.557990
# max        1.560510      1.560650

# %%
plt.rcParams['figure.figsize'] = 11,7

# %%
ax1 = plt.subplot2grid((40,40), (0,0), rowspan=40, colspan=40)
plt.plot(data['date'], data['bid'])
plt.plot(data['date'], data['ask'])

# %%
plt.rcParams['figure.figsize'] = 21,37

fig, axes = plt.subplots(nrows=3)
items = [data['bid'], data['ask'], data['ask']-data['bid']]
colors = ('k', 'r', 'b')

for ax, color, item in zip(axes, colors, items):
    ax.plot(data['date'], item, marker='o', linestyle='none', color=color)

# %%
plt.plot(data['date'], data['ask']-data['bid'])

# %%
type(data['date'])
# Out:
# pandas.core.series.Series

# %%
type(data['bid'])
# Out:
# pandas.core.series.Series
