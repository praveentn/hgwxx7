# %% [markdown]
# # Univariate Analysis

# %%
# load libraries

import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
df = pd.read_csv('insurance_claims.csv')

# %%
df.columns
# Out:
# Index(['CustomerID', 'State', 'ClaimAmount', 'Education', 'Income', 'Gender',
#        'Policy', 'NumberOfPolicies', 'PolicyType', 'MonthsInstallment',
#        'VehicleType', 'TotalClaimAmount'],
#       dtype='object')

# %%
df.dtypes
# Out:
# CustomerID            object
# State                 object
# ClaimAmount            int64
# Education             object
# Income                 int64
# Gender                object
# Policy                object
# NumberOfPolicies       int64
# PolicyType            object
# MonthsInstallment      int64
# VehicleType           object
# TotalClaimAmount     float64
# dtype: object

# %%
df.head()
# Out:
#   CustomerID State  ClaimAmount     Education  Income Gender Policy  \
# 0     CID311    IA           59   High School  196419      M   Auto
# 1     CID838    PH           71  Professional  171186      F   Auto
# 2     CID607    PH          103      Graduate  285004      F   Auto
# 3     CID436    TX          103  Professional  181780      M   Auto
# 4     CID018    PH          112       College  275022      F   Auto
#
#    NumberOfPolicies      PolicyType  MonthsInstallment   VehicleType  \
# 0                 4        Business                 70           MUV
# 1                 4        Business                 31  Medium sized
# 2                 4       Self Auto                 67         Sedan
# 3                 4  Corporate Auto                 78  Medium sized
# 4                 3       Self Auto                 21  Medium sized
#
#    TotalClaimAmount
# 0            112.09
# 1            113.47
# 2            113.86
# 3            114.16
# 4            116.19

# %%
df.describe(include='all')
# Out:
#        CustomerID State  ClaimAmount     Education         Income Gender  \
# count        1000  1000  1000.000000          1000    1000.000000   1000
# unique       1000     5          NaN             5            NaN      2
# top        CID907    TX          NaN  Professional            NaN      M
# freq            1   222          NaN           224            NaN    513
# mean          NaN   NaN  4973.940000           NaN  154488.310000    NaN
# std           NaN   NaN  2765.799312           NaN   86622.613704    NaN
# min           NaN   NaN    59.000000           NaN     681.000000    NaN
# 25%           NaN   NaN  2700.500000           NaN   80608.750000    NaN
# 50%           NaN   NaN  4962.500000           NaN  156377.500000    NaN
# 75%           NaN   NaN  7217.000000           NaN  231740.250000    NaN
# max           NaN   NaN  9981.000000           NaN  299783.000000    NaN
#
#        Policy  NumberOfPolicies PolicyType  MonthsInstallment   VehicleType  \
# ...

# %% [markdown]
# ### Categorical and Continuous variables

# %%
cont_col_dict, cat_col_dict, unk_col_dict = {}, {}, {}

for item in df.dtypes.items():
    col_type = str(item[1])
    if 'int' in col_type or 'float' in col_type:
        cont_col_dict[item[0]] = col_type
    elif 'object' in col_type:
        cat_col_dict[item[0]] = col_type
    else:
        unk_col_dict[item[0]] = col_type

cat_cols = [x for x in cat_col_dict.keys()]
con_cols = [x for x in cont_col_dict.keys()]
unk_cols = [x for x in unk_col_dict.keys()]

cat_cols, con_cols, unk_cols
# Out:
# (['CustomerID',
#   'State',
#   'Education',
#   'Gender',
#   'Policy',
#   'PolicyType',
#   'VehicleType'],
#  ['ClaimAmount',
#   'Income',
#   'NumberOfPolicies',
#   'MonthsInstallment',
#   'TotalClaimAmount'],
#  [])

# %%
type(cat_cols)
# Out:
# list

# %% [markdown]
# ### Bar charts

# %%
df['State'].value_counts().plot.bar()

# %%
df['Education'].value_counts().plot.bar()

# %%
df['Gender'].value_counts().plot.bar()

# %%
df['Policy'].value_counts().plot.bar()

# %%
df['PolicyType'].value_counts().plot.bar()

# %%
df['VehicleType'].value_counts().plot.bar()

# %% [markdown]
# ### Line Charts

# %%
df['ClaimAmount'].value_counts().sort_index().plot.line()

# %%
df['ClaimAmount'].value_counts().sort_index().plot.line()

# %%
df['Income'].value_counts().sort_index().plot.line()

# %%
df['NumberOfPolicies'].value_counts().sort_index().plot.line()

# %%
df['TotalClaimAmount'].value_counts().sort_index().plot.line()

# %%
df['MonthsInstallment'].value_counts().sort_index().plot.line()

# %% [markdown]
# ### Histograms

# %%
df['ClaimAmount'].plot.hist()

# %%
df['Income'].plot.hist()

# %%
df['NumberOfPolicies'].plot.hist()

# %%
df['MonthsInstallment'].plot.hist()

# %%
df['TotalClaimAmount'].plot.hist()

# %% [markdown]
# ### Area Charts

# %%
df['ClaimAmount'].value_counts().sort_index().plot.area()

# %%
df['Income'].value_counts().sort_index().plot.area()

# %%
df['NumberOfPolicies'].value_counts().sort_index().plot.area()

# %%
df['MonthsInstallment'].value_counts().sort_index().plot.area()

# %%
df['TotalClaimAmount'].value_counts().sort_index().plot.area()

# %% [markdown]
# ### Conditional plots

# %%
df['Income'].loc[df.TotalClaimAmount > 15000].plot.hist()

# %%
df['ClaimAmount'].loc[df.TotalClaimAmount > 9900].plot.hist()

# %%
df['ClaimAmount'].loc[df.TotalClaimAmount == 0].plot.hist()

# %%
df['CustomerID'].loc[(df.VehicleType == 'MUV') & (df.ClaimAmount > 9000)].value_counts().plot.bar()
plt.legend()

# %%
x = df['CustomerID'].loc[(df.VehicleType == 'MUV') & (df.ClaimAmount > 9000)]
y = df['Income'].loc[(df.VehicleType == 'MUV') & (df.ClaimAmount > 9000)]

# %%
plt.figure(figsize=(13,11))
plt.scatter(x, y)
plt.legend()

# %% [markdown]
# ### Kdeplots

# %%
x1 = df['Income']
sns.kdeplot(x1)

# %%
x2 = df['TotalClaimAmount']
sns.kdeplot(x2)

# %%
x3 = df['MonthsInstallment']
sns.kdeplot(x3)

# %% [markdown]
# ### Correlations

# %%
corr = df.corr()

# %%
corr
# Out:
#                    ClaimAmount    Income  NumberOfPolicies  MonthsInstallment  \
# ClaimAmount           1.000000 -0.006695         -0.027937           0.010592
# Income               -0.006695  1.000000          0.026386           0.077124
# NumberOfPolicies     -0.027937  0.026386          1.000000          -0.018974
# MonthsInstallment     0.010592  0.077124         -0.018974           1.000000
# TotalClaimAmount      0.885516 -0.003049         -0.016065           0.009959
#
#                    TotalClaimAmount
# ClaimAmount                0.885516
# Income                    -0.003049
# NumberOfPolicies          -0.016065
# MonthsInstallment          0.009959
# TotalClaimAmount           1.000000

# %%
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True

# %%
sns.heatmap(corr, annot=True, square=True, cmap="YlGnBu", mask=mask)

# %% [markdown]
# ### Observations

# %% [markdown]
# <b>
#
# 1. Number of policies should be treated as a categorical variable, even though the values are numerical
# 2. Strong positive correlation between Claim Amount and Total Claim Amount
# 3. We can classify customers based on their income, vehicle type, education etc.
# 4.
#
# </b>
