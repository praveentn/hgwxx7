# %% [markdown]
# # EPL Historical Data | Clustering clubs

# %%
# load libraries
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# reading data
df = pd.read_json('ml_python_epl_data_17_18.json')

# %%
df = df.T
df.reset_index(level=0, inplace = True)

# %%
cols = list(df.columns)
cols
# Out:
# ['index',
#  'Accurate Long Balls',
#  'Aerial Battles Lost',
#  'Aerial Battles Won',
#  'Appearances',
#  'Assists',
#  'Attack',
#  'Big Chances Created',
#  'Big Chances Missed',
#  'Blocked Shots',
#  'Catches',
#  'Clean Sheets',
#  'Clearances',
#  'Clearances Off Line',
#  'Club',
#  'Cross Accuracy %',
#  'Crosses',
#  'Defence',
#  'Discipline',
#  'Duels Lost',
#  'Duels Won',
#  'Errors Leading To Goal',
#  'Fouls',
#  'Goal Kicks',
#  'Goalkeeping',
#  'Goals',
#  'Goals Conceded',
#  'Goals From Freekick',
#  'Goals Per Match',
#  'Goals With Header',
#  'Goals With Left Foot',
#  'Goals With Right Foot',
#  'Headed Clearance',
#  'High Claims',
#  'Hit Woodwork',
#  'Interceptions',
#  'Last Man Tackles',
#  'Losses',
#  'Offsides',
#  'Own Goals',
#  'Passes',
#  'Passes Per Match',
#  'Penalties Saved',
#  'Penalties Scored',
#  'Position',
#  'Punches',
#  'Recoveries',
#  'Red Cards',
#  'Saves',
#  'Shooting Accuracy %',
#  'Shots',
#  'Shots On Target',
#  'Successful /s',
#  'Successful 0/0s',
#  'Successful 5/5s',
#  'Successful 50/50s',
#  'Sweeper Clearances',
#  'Tackle Success %',
#  'Tackles',
#  'Team Play',
#  'Through Balls',
#  'Throw Outs',
#  'Wins',
#  'Yellow Cards']

# %%
df.describe()
# Out:
#                 index Accurate Long Balls Aerial Battles Lost  \
# count             627                 512                 445
# unique            627                 248                 179
# top     Jonjo Shelvey                   0                   0
# freq                1                 116                  97
#
#        Aerial Battles Won Appearances Assists Attack Big Chances Created  \
# count                 445         627     627    560                 560
# unique                174         193      49      1                  50
# top                     0           0       0                          0
# freq                  107         109     303    560                 229
#
#        Big Chances Missed Blocked Shots     ...      Successful 5/5s  \
# count                 355           560     ...                  110
# unique                 44            95     ...                    1
# top                     0             0     ...                    0
# freq                  147           172     ...                  110
#
#        Successful 50/50s Sweeper Clearances Tackle Success % Tackles  \
# count                326                 67              445     560
# unique               136                 37               45     233
# top                    1                  0               0%       0
# freq                  24                 20               85     111
#
#        Team Play Through Balls Throw Outs Wins Yellow Cards
# count        627           445         67  627          627
# unique         1            67         48  118           54
# top                          0          0    0            0
# freq         627           204         17  144          241
#
# [4 rows x 64 columns]

# %%
df.describe(include='all')
# Out:
#                 index Accurate Long Balls Aerial Battles Lost  \
# count             627                 512                 445
# unique            627                 248                 179
# top     Jonjo Shelvey                   0                   0
# freq                1                 116                  97
#
#        Aerial Battles Won Appearances Assists Attack Big Chances Created  \
# count                 445         627     627    560                 560
# unique                174         193      49      1                  50
# top                     0           0       0                          0
# freq                  107         109     303    560                 229
#
#        Big Chances Missed Blocked Shots     ...      Successful 5/5s  \
# count                 355           560     ...                  110
# unique                 44            95     ...                    1
# top                     0             0     ...                    0
# freq                  147           172     ...                  110
#
#        Successful 50/50s Sweeper Clearances Tackle Success % Tackles  \
# count                326                 67              445     560
# unique               136                 37               45     233
# top                    1                  0               0%       0
# freq                  24                 20               85     111
#
#        Team Play Through Balls Throw Outs Wins Yellow Cards
# count        627           445         67  627          627
# unique         1            67         48  118           54
# top                          0          0    0            0
# freq         627           204         17  144          241
#
# [4 rows x 64 columns]

# %%
col_types = list(df.dtypes)
len(col_types), set(col_types)
# Out:
# (64, {dtype('O')})

# %% [markdown]
# ##### all columns are of type object

# %%
df.head()
# Out:
#              index Accurate Long Balls Aerial Battles Lost Aerial Battles Won  \
# 0   Rolando Aarons                   7                   9                  6
# 1    Tammy Abraham                 NaN                 NaN                NaN
# 2     Charlie Adam                 784                 148                216
# 3           Adrián                 862                 NaN                NaN
# 4  Ibrahim Afellay                  72                  20                 15
#
#   Appearances Assists Attack Big Chances Created Big Chances Missed  \
# 0          14       1                          1                  0
# 1           7       0                          1                  2
# 2         196      25                         39                  6
# 3         106       0    NaN                 NaN                NaN
# 4          43       2                          4                  2
#
#   Blocked Shots     ...      Successful 5/5s Successful 50/50s  \
# 0             2     ...                  NaN                10
# 1             4     ...                  NaN               NaN
# 2           118     ...                  NaN               156
# 3           NaN     ...                  NaN               NaN
# 4            12     ...                  NaN               NaN
#
#   Sweeper Clearances Tackle Success % Tackles Team Play Through Balls  \
# 0                NaN              63%      16                       0
# 1                NaN              NaN       5                     NaN
# 2                NaN              79%     304                      61
# 3                 84              NaN     NaN                     NaN
# 4                NaN              80%      30                       4
#
#   Throw Outs Wins Yellow Cards
# 0        NaN    3            2
# 1        NaN    1            0
# 2        NaN   64           46
# 3        433   38            7
# 4        NaN   17            3
#
# [5 rows x 64 columns]

# %% [markdown]
# ##### sorting by goals scored

# %%
df.sort_values(by=['Goals'], ascending=False)
# Out:
#                        index Accurate Long Balls Aerial Battles Lost  \
# 348            Romelu Lukaku                 NaN                 NaN
# 284              Jordan Ayew                 NaN                 NaN
# 447  Alex Oxlade-Chamberlain                 158                  75
# 623             Mauro Zárate                 NaN                 NaN
# 20             Marcos Alonso                 110                  83
# 125             Jack Colback                 341                 138
# 619           Pablo Zabaleta                 337                 264
# 103           Etienne Capoue                 309                  78
# 574      Patrick van Aanholt                 157                  55
# 78               George Boyd                  46                 149
# 498               Danny Rose                 268                 118
# 294               Harry Kane                 NaN                 NaN
# 519          Xherdan Shaqiri                  67                  18
# 144               David Luiz                 582                 136
# 590           Victor Wanyama                 346                 236
# 137          Charlie Daniels                 137                  64
# 326           Lee Chung-yong                  48                  91
# 321              Erik Lamela                  53                  77
# 120             Ciaran Clark                 284                 210
# 553         Daniel Sturridge                 NaN                 NaN
# 215           Olivier Giroud                 NaN                 NaN
# 532            Islam Slimani                 NaN                 NaN
# 599           Dean Whitehead                 426                 143
# 80              Robbie Brady                 156                  83
# 592        James Ward-Prowse                 168                 139
# 45             Phil Bardsley                 469                 203
# 533           Chris Smalling                 423                 215
# 563            James Tomkins                 509                 288
# 418             Jordon Mutch                  87                 155
# 102                 Emre Can                 300                 140
# ..                       ...                 ...                 ...
# 389               Roque Mesa                   0                   0
# 400           Jayson Molumby                   0                   0
# 387             Mikel Merino                  14                   7
# 386           Nampalys Mendy                   4                   4
# 385            Max Melbourne                   0                   0
# 222             Robert Green               1,502                 NaN
# 383          Scott McTominay                   2                   2
# 382              Sam McQueen                  11                  12
# 223              Matt Grimes                   7                   2
# 399                     Moha                   0                   0
# 211            Florin Gardos                  17                   3
# 421         Luciano Narsingh                   1                  15
# 198           Fraser Forster                 684                 NaN
# 420            Clinton N'Jie                 NaN                 NaN
# 419              Boaz Myhill                 888                 NaN
# 193                Sam Field                   5                   5
# 416           Charly Musonda                   0                   0
# 196               Phil Foden                 NaN                 NaN
# 197           Michael Folivi                 NaN                 NaN
# 413             Jamie Murphy                   1                   1
# 411             Erwin Mulder                   0                 NaN
# 402            Elliott Moore                   0                   0
# 410              Lys Mousset                 NaN                 NaN
# 199               Ben Foster               1,829                 NaN
# 200      Timothy Fosu-Mensah                  15                  18
# 201               Juan Foyth                   0                   0
# 202            Simon Francis                 330                 150
# 204           Freddie Ladapo                 NaN                 NaN
# 206               Jay Fulton                  16                  27
# 313           Sead Kolasinac                   3                   3
#
#     Aerial Battles Won Appearances Assists Attack Big Chances Created  \
# 348                NaN         191      29                         27
# 284                NaN          49       3                          6
# 447                 51         134      14                         23
# 623                NaN          43       2                          1
# 20                 129          61       4                          5
# 125                 95         179      10                          9
# 619                327         235      19                         27
# 103                 91          96       2                          1
# 574                 37         101       9                         10
# 78                  79         101       5                          8
# 498                145         135      13                         16
# 294                NaN         121      12                         19
# 519                  4          53       9                         16
# 144                200         119       4                          9
# 590                252         123       3                          5
# 137                 65          76       8                          6
# 326                 70         100      10                         12
# 321                 22          85      18                         20
# 120                313         139       4                          9
# 553                NaN         188      19                         21
# 215                NaN         169      23                         31
# 532                NaN          27       4                          2
# 599                112         230      11                          4
# 80                 106          98       8                         19
# 592                 64         142      16                         17
# 45                 200         246       4                         10
# 533                435         166       2                          3
# 563                559         191       5                          6
# 418                 88          78       7                          8
# 102                164          93       4                         12
# ..                 ...         ...     ...    ...                 ...
# 389                  0           1       0                          0
# 400                  0           0       0                          0
# 387                  9           5       0                          1
# 386                  4           4       0                          0
# 385                  0           0       0                          0
# 222                NaN         267       0    NaN                 NaN
# 383                  1           2       0                          0
# 382                 21          15       0                          1
# 223                  1           4       0                          0
# 399                  0           0       0                          0
# 211                 22          11       0                          0
# 421                  3          15       3                          1
# 198                NaN          91       0    NaN                 NaN
# 420                NaN           8       1                          1
# 419                NaN         117       0    NaN                 NaN
# 193                  5          11       0                          0
# 416                  0           1       0                          0
# 196                NaN           0       0                          0
# 197                NaN           1       0                          0
# 413                  0           3       0                          0
# 411                NaN           0       0    NaN                 NaN
# 402                  0           0       0                          0
# 410                NaN          14       0                          0
# 199                NaN         256       0    NaN                 NaN
# 200                  9          17       1                          1
# 201                  0           0       0                          0
# 202                234          75       5                          3
# 204                NaN           0       0                          0
# 206                 21          18       0                          0
# 313                  7           4       2                          2
#
#     Big Chances Missed Blocked Shots     ...      Successful 5/5s  \
# 348                 64           140     ...                  NaN
# 284                  2            24     ...                  NaN
# 447                 10            57     ...                  NaN
# 623                  2            24     ...                  NaN
# 20                 NaN            24     ...                  NaN
# 125                  2            19     ...                  NaN
# 619                NaN            48     ...                  NaN
# 103                  9            26     ...                  NaN
# 574                NaN            24     ...                  NaN
# 78                   3            40     ...                  NaN
# 498                NaN            29     ...                  NaN
# 294                 52           110     ...                  NaN
# 519                  4            25     ...                  NaN
# 144                NaN            39     ...                  NaN
# 590                  4            27     ...                  NaN
# 137                NaN            11     ...                  NaN
# 326                  2            10     ...                  NaN
# 321                  8            46     ...                  NaN
# 120                NaN            13     ...                  NaN
# 553                 56            90     ...                  NaN
# 215                 63            81     ...                  NaN
# 532                  9             5     ...                  NaN
# 599                  5            25     ...                  NaN
# 80                   0            36     ...                  NaN
# 592                  8            40     ...                  NaN
# 45                 NaN            49     ...                  NaN
# 533                NaN            27     ...                  NaN
# 563                NaN            21     ...                  NaN
# 418                  8            21     ...                  NaN
# 102                  2            29     ...                  NaN
# ..                 ...           ...     ...                  ...
# 389                  0             0     ...                    0
# 400                  0             0     ...                    0
# 387                  0             2     ...                  NaN
# 386                  0             0     ...                  NaN
# 385                NaN             0     ...                    0
# 222                NaN           NaN     ...                  NaN
# 383                  0             0     ...                    0
# 382                  0             0     ...                    0
# 223                  0             1     ...                    0
# 399                  0             0     ...                    0
# 211                NaN             1     ...                    0
# 421                  0             1     ...                  NaN
# 198                NaN           NaN     ...                  NaN
# 420                  0             2     ...                  NaN
# 419                NaN           NaN     ...                  NaN
# 193                  0             0     ...                  NaN
# 416                  0             0     ...                    0
# 196                  0             0     ...                  NaN
# 197                  0             0     ...                  NaN
# 413                  0             1     ...                  NaN
# 411                NaN           NaN     ...                  NaN
# 402                NaN             0     ...                    0
# 410                  2             3     ...                  NaN
# 199                NaN           NaN     ...                  NaN
# 200                NaN             2     ...                  NaN
# 201                NaN             0     ...                    0
# 202                NaN             7     ...                  NaN
# 204                  0             0     ...                  NaN
# 206                  0             2     ...                  NaN
# 313                NaN             1     ...                  NaN
#
#     Successful 50/50s Sweeper Clearances Tackle Success % Tackles Team Play  \
# 348               NaN                NaN              NaN      51
# 284               NaN                NaN              NaN      67
# 447               274                NaN              79%     138
# 623               NaN                NaN              NaN      42
# 20                 47                NaN              74%     146
# 125                56                NaN              78%     409
# 619                64                NaN              74%     805
# 103                97                NaN              72%     211
# 574               122                NaN              77%     220
# 78                 63                NaN              72%     240
# 498               140                NaN              82%     342
# 294               NaN                NaN              NaN      94
# 519                81                NaN              59%      39
# 144                64                NaN              78%     163
# 590               130                NaN              77%     345
# 137                90                NaN              77%     139
# 326                73                NaN              77%     144
# 321               119                NaN              75%     183
# 120                38                NaN              76%     248
# 553               NaN                NaN              NaN      33
# 215               NaN                NaN              NaN     126
# 532               NaN                NaN              NaN      13
# 599                26                NaN              71%     416
# 80                106                NaN              76%     192
# 592                25                NaN              77%     108
# 45                 92                NaN              79%     627
# 533                55                NaN              71%     213
# 563                16                NaN              74%     341
# 418                61                NaN              82%      99
# 102                99                NaN              82%     230
# ..                ...                ...              ...     ...       ...
# 389               NaN                NaN               0%       0
# 400               NaN                NaN               0%       0
# 387                 7                NaN              85%      13
# 386                 4                NaN              50%       2
# 385               NaN                NaN               0%       0
# 222               NaN                 94              NaN     NaN
# 383               NaN                NaN               0%       0
# 382               NaN                NaN              75%      16
# 223               NaN                NaN              33%       3
# 399               NaN                NaN               0%       0
# 211               NaN                NaN              85%      20
# 421                12                NaN              20%       5
# 198               NaN                 19              NaN     NaN
# 420               NaN                NaN              NaN       7
# 419               NaN                 57              NaN     NaN
# 193                 1                NaN              71%       7
# 416               NaN                NaN               0%       0
# 196               NaN                NaN              NaN       0
# 197               NaN                NaN              NaN       0
# 413                 1                NaN             100%       2
# 411               NaN                  0              NaN     NaN
# 402               NaN                NaN               0%       0
# 410               NaN                NaN              NaN       4
# 199               NaN                137              NaN     NaN
# 200                 4                NaN              81%      27
# 201               NaN                NaN               0%       0
# 202                49                NaN              75%     174
# 204               NaN                NaN              NaN       0
# 206                 2                NaN              60%      40
# 313                 2                NaN             100%       9
#
#     Through Balls Throw Outs Wins Yellow Cards
# 348           NaN        NaN   78           11
# 284           NaN        NaN    9            7
# 447            36        NaN   70            6
# 623           NaN        NaN   13            4
# 20              5        NaN   40           11
# 125             9        NaN   49           37
# 619            21        NaN  135           57
# 103             7        NaN   35           15
# 574             4        NaN   25           10
# 78              5        NaN   25           12
# 498             4        NaN   66           33
# 294           NaN        NaN   68           14
# 519            34        NaN   19            5
# 144            26        NaN   78           31
# 590             5        NaN   64           31
# 137             4        NaN   23            3
# 326            28        NaN   28            5
# 321            23        NaN   42           17
# 120             1        NaN   34           41
# 553           NaN        NaN   93            8
# 215           NaN        NaN   96           16
# 532           NaN        NaN   10            1
# 599            10        NaN   61           50
# 80              7        NaN   24           10
# 592            15        NaN   56           12
# 45             16        NaN   80           57
# 533             6        NaN   92           13
# 563             3        NaN   61           27
# 418            13        NaN   20           11
# 102            16        NaN   46           19
# ..            ...        ...  ...          ...
# 389             0        NaN    0            0
# 400             0        NaN    0            0
# 387             0        NaN    3            2
# 386             0        NaN    0            1
# 385             0        NaN    0            0
# 222           NaN      1,188   71            3
# 383             0        NaN    1            1
# 382             0        NaN    5            0
# 223             1        NaN    2            0
# 399             0        NaN    0            0
# 211             0        NaN    8            1
# 421             0        NaN    5            0
# 198           NaN        242   42            4
# 420           NaN        NaN    3            0
# 419           NaN        376   29            6
# 193             0        NaN    5            2
# 416             0        NaN    0            0
# 196           NaN        NaN    0            0
# 197           NaN        NaN    0            0
# 413             0        NaN    0            0
# 411           NaN          0    0            0
# 402             0        NaN    0            0
# 410           NaN        NaN    4            0
# 199           NaN        955   75           10
# 200             1        NaN    9            1
# 201             0        NaN    0            0
# 202             0        NaN   24           10
# 204           NaN        NaN    0            0
# 206             1        NaN    9            4
# 313             0        NaN    2            1
#
# [627 rows x 64 columns]

# %%
players = df['index'].unique()

# %% [markdown]
# ##### check if any player field has missing values

# %%
for i, player in enumerate(players):
    if player == '':
        print(i)
# Out:
# 14

# %%
df.iloc[[14]]
# Out:
#    index Accurate Long Balls Aerial Battles Lost Aerial Battles Won  \
# 14                        70                 NaN                NaN
#
#    Appearances Assists Attack Big Chances Created Big Chances Missed  \
# 14           9       0    NaN                 NaN                NaN
#
#    Blocked Shots     ...      Successful 5/5s Successful 50/50s  \
# 14           NaN     ...                  NaN               NaN
#
#    Sweeper Clearances Tackle Success % Tackles Team Play Through Balls  \
# 14                  5              NaN     NaN                     NaN
#
#    Throw Outs Wins Yellow Cards
# 14         13    3            0
#
# [1 rows x 64 columns]

# %% [markdown]
# ##### drop row 14 - player name is blank

# %%
df.drop(df.index[[14]], inplace=True)

# %%
df.iloc[[14]]
# Out:
#                      index Accurate Long Balls Aerial Battles Lost  \
# 15  Trent Alexander-Arnold                  23                   2
#
#    Aerial Battles Won Appearances Assists Attack Big Chances Created  \
# 15                  2          10       0                          1
#
#    Big Chances Missed Blocked Shots     ...      Successful 5/5s  \
# 15                NaN             1     ...                  NaN
#
#    Successful 50/50s Sweeper Clearances Tackle Success % Tackles Team Play  \
# 15                 4                NaN              62%      13
#
#    Through Balls Throw Outs Wins Yellow Cards
# 15             0        NaN    5            2
#
# [1 rows x 64 columns]

# %% [markdown]
# ##### filling na values

# %%
# na values
df.fillna(0, inplace=True)

# %%
tx = df.isnull().any()

tx.describe()
# Out:
# count        64
# unique        1
# top       False
# freq         64
# dtype: object

# %%
##### if any column still has got na values it should have displayed True

# %%
set(tx)
# Out:
# {False}

# %% [markdown]
# ##### Accurate Long Balls        True

# %%
df['Accurate Long Balls'].isnull().sum()
# Out:
# 0

# %%
df['Throw Outs'].isnull().sum()
# Out:
# 0

# %%
df['Throw Outs'].unique()
# Out:
# array([0, '433', '9', '0', '705', '74', '612', '94', '183', '1,777',
#        '440', '29', '766', '28', '134', '30', '862', '68', '242', '955',
#        '83', '100', '1,188', '20', '1,432', '15', '292', '541', '98',
#        '39', '581', '832', '42', '818', '376', '12', '58', '115', '5',
#        '93', '191', '34', '273', '146', '208', '24', '801', '558'],
#       dtype=object)

# %%
# df['Accurate Long Balls'] = df['Accurate Long Balls'].fillna(0)

# df['Accurate Long Balls'].isnull().sum()

##### replace ',''s from columns

# df['Accurate Long Balls'] = df['Accurate Long Balls'].str.replace(',','')
# df['Accurate Long Balls'] = pd.to_numeric(df['Accurate Long Balls'])

# df['Accurate Long Balls'].isnull().sum()

# df['Accurate Long Balls'].iloc[[0,1,2,3,4]]

# df['Accurate Long Balls'].head(5)

##### clearances column

# df['Clearances'].describe()

# df['Clearances'].unique()

# %% [markdown]
# ##### helper function to remove ',', '.' and '%' from values in columns

# %%
def remove_commas(df, col):
    df[col] = df[col].str.replace(',','')
    df.fillna(0, inplace=True)
    return pd.to_numeric(df[col])

def remove_dots(df, col):
    df[col] = df[col].str.replace('.','')
    df.fillna(0, inplace=True)
    return pd.to_numeric(df[col])

def remove_percentages(df, col):
    df[col] = df[col].str.replace('%','')
    df.fillna(0, inplace=True)
    return pd.to_numeric(df[col])

# %%
num_cols_with_commas = ['Accurate Long Balls','Clearances','Crosses','Duels Lost','Shots',
                        'Duels Won','Goal Kicks','Headed Clearance','Passes','Recoveries','Throw Outs']

# num_cols_with_dots = ['Throw Outs']

num_cols_with_percentages = ['Cross Accuracy %','Shooting Accuracy %','Tackle Success %']

# %%
for col in num_cols_with_commas:
    df[col] = remove_commas(df, col)

# %%
for col in num_cols_with_percentages:
    df[col] = remove_percentages(df, col)

# %%
df['Throw Outs'].isnull().sum()
df['Throw Outs'].unique()

set(df.isnull().any())
# Out:
# {False}

# %%
df['Throw Outs'].unique()
# Out:
# array([   0,  433,    9,  705,   74,  612,   94,  183, 1777,  440,   29,
#         766,   28,  134,   30,  862,   68,  242,  955,   83,  100, 1188,
#          20, 1432,   15,  292,  541,   98,   39,  581,  832,   42,  818,
#         376,   12,   58,  115,    5,   93,  191,   34,  273,  146,  208,
#          24,  801,  558], dtype=int64)

# %%
# for col in num_cols_with_dots:
#    df[col] = remove_dots(df, col)

# %% [markdown]
# ##### convert columns with numeric values to type int

# %%
numeric_cols = cols.copy()
numeric_cols.remove('index')
numeric_cols.remove('Club')
numeric_cols.remove('Position')

#numeric_cols.remove('Throw Outs')
#numeric_cols.remove('Cross Accuracy %')
#numeric_cols.remove('Crosses')
#numeric_cols.remove('Duels Lost')
#numeric_cols.remove('Duels Won')
#numeric_cols.remove('Goal Kicks')
#numeric_cols.remove('Headed Clearance')
#numeric_cols.remove('Passes')
#numeric_cols.remove('Recoveries')
#numeric_cols.remove('Shooting Accuracy %')
#numeric_cols.remove('Shots')
#numeric_cols.remove('Tackle Success %')
numeric_cols
# Out:
# ['Accurate Long Balls',
#  'Aerial Battles Lost',
#  'Aerial Battles Won',
#  'Appearances',
#  'Assists',
#  'Attack',
#  'Big Chances Created',
#  'Big Chances Missed',
#  'Blocked Shots',
#  'Catches',
#  'Clean Sheets',
#  'Clearances',
#  'Clearances Off Line',
#  'Cross Accuracy %',
#  'Crosses',
#  'Defence',
#  'Discipline',
#  'Duels Lost',
#  'Duels Won',
#  'Errors Leading To Goal',
#  'Fouls',
#  'Goal Kicks',
#  'Goalkeeping',
#  'Goals',
#  'Goals Conceded',
#  'Goals From Freekick',
#  'Goals Per Match',
#  'Goals With Header',
#  'Goals With Left Foot',
#  'Goals With Right Foot',
#  'Headed Clearance',
#  'High Claims',
#  'Hit Woodwork',
#  'Interceptions',
#  'Last Man Tackles',
#  'Losses',
#  'Offsides',
#  'Own Goals',
#  'Passes',
#  'Passes Per Match',
#  'Penalties Saved',
#  'Penalties Scored',
#  'Punches',
#  'Recoveries',
#  'Red Cards',
#  'Saves',
#  'Shooting Accuracy %',
#  'Shots',
#  'Shots On Target',
#  'Successful /s',
#  'Successful 0/0s',
#  'Successful 5/5s',
#  'Successful 50/50s',
#  'Sweeper Clearances',
#  'Tackle Success %',
#  'Tackles',
#  'Team Play',
#  'Through Balls',
#  'Throw Outs',
#  'Wins',
#  'Yellow Cards']

# %%
try:
    for i, col in enumerate(numeric_cols):
        print(i, col)
        df[col] = df[col].apply(pd.to_numeric)
except:
    print('%s cannot convert to numeric' % (col))
# Out:
# 0 Accurate Long Balls
# 1 Aerial Battles Lost
# 2 Aerial Battles Won
# 3 Appearances
# 4 Assists
# 5 Attack
# 6 Big Chances Created
# 7 Big Chances Missed
# 8 Blocked Shots
# 9 Catches
# 10 Clean Sheets
# 11 Clearances
# 12 Clearances Off Line
# 13 Cross Accuracy %
# 14 Crosses
# 15 Defence
# 16 Discipline
# 17 Duels Lost
# 18 Duels Won
# 19 Errors Leading To Goal
# 20 Fouls
# 21 Goal Kicks
# 22 Goalkeeping
# 23 Goals
# 24 Goals Conceded
# 25 Goals From Freekick
# 26 Goals Per Match
# 27 Goals With Header
# 28 Goals With Left Foot
# 29 Goals With Right Foot
# 30 Headed Clearance
# 31 High Claims
# 32 Hit Woodwork
# 33 Interceptions
# 34 Last Man Tackles
# 35 Losses
# 36 Offsides
# 37 Own Goals
# 38 Passes
# 39 Passes Per Match
# 40 Penalties Saved
# 41 Penalties Scored
# 42 Punches
# 43 Recoveries
# 44 Red Cards
# 45 Saves
# 46 Shooting Accuracy %
# 47 Shots
# 48 Shots On Target
# 49 Successful /s
# 50 Successful 0/0s
# 51 Successful 5/5s
# 52 Successful 50/50s
# 53 Sweeper Clearances
# 54 Tackle Success %
# 55 Tackles
# 56 Team Play
# 57 Through Balls
# 58 Throw Outs
# 59 Wins
# 60 Yellow Cards

# %%
tx = df.dtypes

set(list(tx))
# Out:
# {dtype('int64'), dtype('float64'), dtype('O')}

# %%
df.describe()
# Out:
#        Accurate Long Balls  Aerial Battles Lost  Aerial Battles Won  \
# count           626.000000           626.000000          626.000000
# mean            154.145367            51.035144           57.707668
# std             286.704636            85.323490          120.735012
# min               0.000000             0.000000            0.000000
# 25%               0.000000             0.000000            0.000000
# 50%              18.000000             4.000000            2.000000
# 75%             199.500000            76.000000           60.000000
# max            1947.000000           520.000000          977.000000
#
#        Appearances     Assists  Attack  Big Chances Created  \
# count   626.000000  626.000000    66.0           626.000000
# mean     67.110224    5.268371     0.0             5.817891
# std      88.787904   11.435028     0.0            10.985754
# min       0.000000    0.000000     0.0             0.000000
# 25%       3.000000    0.000000     0.0             0.000000
# 50%      27.500000    1.000000     0.0             1.000000
# 75%     106.000000    5.000000     0.0             6.000000
# max     632.000000  107.000000     0.0            82.000000
#
#        Big Chances Missed  Blocked Shots     Catches      ...       \
# count          626.000000     626.000000  626.000000      ...
# mean             3.723642      18.124601    3.722045      ...
# std              9.727420      32.803763   22.515475      ...
# min              0.000000       0.000000    0.000000      ...
# 25%              0.000000       0.000000    0.000000      ...
# 50%              0.000000       3.000000    0.000000      ...
# 75%              2.000000      23.000000    0.000000      ...
# max             94.000000     294.000000  262.000000      ...
#
#        Successful 5/5s  Successful 50/50s  Sweeper Clearances  \
# count            626.0         626.000000          626.000000
# mean               0.0          35.945687            4.313099
# std                0.0          72.848096           22.512455
# min                0.0           0.000000            0.000000
# 25%                0.0           0.000000            0.000000
# 50%                0.0           1.000000            0.000000
# 75%                0.0          38.000000            0.000000
# max                0.0         609.000000          204.000000
#
#        Tackle Success %     Tackles  Team Play  Through Balls   Throw Outs  \
# count         626.00000  626.000000        0.0     626.000000   626.000000
# mean           41.86262   96.162939        NaN       8.638978    26.450479
# std            37.88277  153.996527        NaN      27.651731   145.448883
# min             0.00000    0.000000        NaN       0.000000     0.000000
# 25%             0.00000    0.000000        NaN       0.000000     0.000000
# 50%            64.50000   17.000000        NaN       0.000000     0.000000
# 75%            76.00000  138.750000        NaN       4.000000     0.000000
# max           100.00000  998.000000        NaN     354.000000  1777.000000
#
#              Wins  Yellow Cards
# count  626.000000    626.000000
# mean    27.929712      8.076677
# std     40.992388     13.152662
# min      0.000000      0.000000
# 25%      1.000000      0.000000
# 50%     10.000000      2.000000
# 75%     41.000000     11.000000
# max    272.000000    119.000000
#
# [8 rows x 61 columns]

# %%
for col in cols:
    print(col, df[col].dtype)
# Out:
# index object
# Accurate Long Balls int64
# Aerial Battles Lost int64
# Aerial Battles Won int64
# Appearances int64
# Assists int64
# Attack float64
# Big Chances Created int64
# Big Chances Missed int64
# Blocked Shots int64
# Catches int64
# Clean Sheets int64
# Clearances int64
# Clearances Off Line int64
# Club object
# Cross Accuracy % int64
# Crosses int64
# Defence float64
# Discipline float64
# Duels Lost int64
# Duels Won int64
# Errors Leading To Goal int64
# Fouls int64
# Goal Kicks int64
# Goalkeeping float64
# Goals int64
# Goals Conceded int64
# Goals From Freekick int64
# Goals Per Match float64
# Goals With Header int64
# Goals With Left Foot int64
# Goals With Right Foot int64
# Headed Clearance int64
# High Claims int64
# Hit Woodwork int64
# Interceptions int64
# Last Man Tackles int64
# Losses int64
# Offsides int64
# Own Goals int64
# Passes int64
# Passes Per Match float64
# Penalties Saved int64
# Penalties Scored int64
# Position object
# Punches int64
# Recoveries int64
# Red Cards int64
# Saves int64
# Shooting Accuracy % int64
# Shots int64
# Shots On Target int64
# Successful /s int64
# Successful 0/0s int64
# Successful 5/5s int64
# Successful 50/50s int64
# Sweeper Clearances int64
# Tackle Success % int64
# Tackles int64
# Team Play float64
# Through Balls int64
# Throw Outs int64
# Wins int64
# Yellow Cards int64

# %%
df['Team Play']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 15    NaN
# 16    NaN
# 17    NaN
# 18    NaN
# 19    NaN
# 20    NaN
# 21    NaN
# 22    NaN
# 23    NaN
# 24    NaN
# 25    NaN
# 26    NaN
# 27    NaN
# 28    NaN
# 29    NaN
# 30    NaN
#        ..
# 597   NaN
# 598   NaN
# 599   NaN
# 600   NaN
# 601   NaN
# 602   NaN
# 603   NaN
# 604   NaN
# 605   NaN
# 606   NaN
# 607   NaN
# 608   NaN
# 609   NaN
# 610   NaN
# 611   NaN
# 612   NaN
# 613   NaN
# 614   NaN
# 615   NaN
# 616   NaN
# 617   NaN
# 618   NaN
# 619   NaN
# 620   NaN
# 621   NaN
# 622   NaN
# 623   NaN
# 624   NaN
# 625   NaN
# 626   NaN
# Name: Team Play, Length: 626, dtype: float64

# %%
pd.CategoricalIndex(df)
# Out:
# CategoricalIndex(['index', 'Accurate Long Balls', 'Aerial Battles Lost',
#                   'Aerial Battles Won', 'Appearances', 'Assists', 'Attack',
#                   'Big Chances Created', 'Big Chances Missed', 'Blocked Shots',
#                   'Catches', 'Clean Sheets', 'Clearances',
#                   'Clearances Off Line', 'Club', 'Cross Accuracy %', 'Crosses',
#                   'Defence', 'Discipline', 'Duels Lost', 'Duels Won',
#                   'Errors Leading To Goal', 'Fouls', 'Goal Kicks',
#                   'Goalkeeping', 'Goals', 'Goals Conceded',
#                   'Goals From Freekick', 'Goals Per Match',
#                   'Goals With Header', 'Goals With Left Foot',
#                   'Goals With Right Foot', 'Headed Clearance', 'High Claims',
#                   'Hit Woodwork', 'Interceptions', 'Last Man Tackles',
#                   'Losses', 'Offsides', 'Own Goals', 'Passes',
#                   'Passes Per Match', 'Penalties Saved', 'Penalties Scored',
#                   'Position', 'Punches', 'Recoveries', 'Red Cards', 'Saves',
#                   'Shooting Accuracy %', 'Shots', 'Shots On Target',
#                   'Successful /s', 'Successful 0/0s', 'Successful 5/5s',
#                   'Successful 50/50s', 'Sweeper Clearances',
#                   'Tackle Success %', 'Tackles', 'Team Play', 'Through Balls',
#                   'Throw Outs', 'Wins', 'Yellow Cards'],
#                  categories=['Accurate Long Balls', 'Aerial Battles Lost', 'Aerial Battles Won', 'Appearances', 'Assists', 'Attack', 'Big Chances Created', 'Big Chances Missed', ...], ordered=False, dtype='category')

# %% [markdown]
# #### Correlation

# %%
correlations = df.corr()

# %%
# Generate a mask for the upper triangle
mask = np.zeros_like(correlations, dtype=np.bool)
# array([[False, False],
#       [False, False]])

mask[np.triu_indices_from(mask)] = True
# array([[ True,  True],
#       [False,  True]])

# %%
# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(17, 13))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(correlations, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# ### Visualizations!!
#
# ---
#
# #### Univariate analysis
# ---

# %%
plt.figure(figsize=(17,7))
df['Club'].value_counts().plot.bar()
plt.title('Clubs')
plt.xlabel('Club')
plt.ylabel('Number of players')
plt.legend()

# %%
len(df['index'].unique()), len(df['Club'].unique())
# Out:
# (626, 81)

# %% [markdown]
# ##### Out of the data for 626 players from 81 clubs, Brighton and Howe Albion has got the max number of players - 35, followed by Watford, Arsenal, Liverpool and Newcastle United

# %%
plt.figure(figsize=(17,7))
df['Goals'].value_counts().plot.bar()
plt.title('Goals scored by players')
plt.xlabel('Goals')
plt.ylabel('Count')

# for a,b in zip(df.Goals.values, df.index.values):
#    plt.text(0,0,b)
    
plt.legend()
# plt.savefig('dd.png')

# %% [markdown]
# ##### Maximum number of goals scored by a player is 200; whereas more than 300 players (nearly half) has not scored a single goal!

# %%
df[['Goals','Own Goals']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x00000229E6795828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000229E68D4160>]],
#       dtype=object)

# %%
len(numeric_cols)
# Out:
# 61

# %%
len(df.columns)
# Out:
# 64

# %%
cat_cols = ['index','Club','Position']
len(cat_cols)
# Out:
# 3

# %%
df['Throw Outs'].unique()
# Out:
# array([   0,  433,    9,  705,   74,  612,   94,  183, 1777,  440,   29,
#         766,   28,  134,   30,  862,   68,  242,  955,   83,  100, 1188,
#          20, 1432,   15,  292,  541,   98,   39,  581,  832,   42,  818,
#         376,   12,   58,  115,    5,   93,  191,   34,  273,  146,  208,
#          24,  801,  558], dtype=int64)

# %%
pd.get_dummies(df['Position']).head(7)
# Out:
#    Defender  Forward  Goalkeeper  Midfielder
# 0         0        0           0           1
# 1         0        1           0           0
# 2         0        0           0           1
# 3         0        0           1           0
# 4         0        0           0           1
# 5         0        1           0           0
# 6         0        1           0           0

# %%
df = pd.concat([df, pd.get_dummies(df['Position'])], axis=1)

df.head()
# Out:
#              index  Accurate Long Balls  Aerial Battles Lost  \
# 0   Rolando Aarons                    7                    9
# 1    Tammy Abraham                    0                    0
# 2     Charlie Adam                  784                  148
# 3           Adrián                  862                    0
# 4  Ibrahim Afellay                   72                   20
#
#    Aerial Battles Won  Appearances  Assists  Attack  Big Chances Created  \
# 0                   6           14        1     NaN                    1
# 1                   0            7        0     NaN                    1
# 2                 216          196       25     NaN                   39
# 3                   0          106        0     0.0                    0
# 4                  15           43        2     NaN                    4
#
#    Big Chances Missed  Blocked Shots     ...      Tackles  Team Play  \
# 0                   0              2     ...           16        NaN
# 1                   2              4     ...            5        NaN
# 2                   6            118     ...          304        NaN
# 3                   0              0     ...            0        NaN
# 4                   2             12     ...           30        NaN
#
#    Through Balls  Throw Outs Wins  Yellow Cards  Defender  Forward  \
# 0              0           0    3             2         0        0
# 1              0           0    1             0         0        1
# 2             61           0   64            46         0        0
# 3              0         433   38             7         0        0
# 4              4           0   17             3         0        0
#
#    Goalkeeper  Midfielder
# 0           0           1
# 1           0           0
# 2           0           1
# 3           1           0
# 4           0           1
#
# [5 rows x 68 columns]

# %%
numeric_cols.append('Defender')
numeric_cols.append('Forward')
numeric_cols.append('Goalkeeper')
numeric_cols.append('Midfielder')
len(numeric_cols)
# Out:
# 65

# %%
# numeric_cols.append('Team Play')
# numeric_cols.remove('Attack')
# numeric_cols.remove('Defence')
# numeric_cols.remove('Discipline')
# 
# len(numeric_cols)

# %% [markdown]
# ### Clustering

# %%
from sklearn.cluster import KMeans
from mpl_toolkits.mplot3d import Axes3D

# %%
df.fillna(0, inplace=True)

# %%
X_epl = df[numeric_cols].values
X_epl.shape
# Out:
# (626, 65)

# %%
# df.fillna(0, inplace=True)

# %%
# df.isnull().any()

# %%
#KMeans
km = KMeans(n_clusters=3)
km.fit(X_epl)
km.predict(X_epl)
labels = km.labels_

# %%
#Plotting
fig = plt.figure(1, figsize=(17,11))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=88, azim=-14)
ax.scatter(X_epl[:, 3], X_epl[:, 0], X_epl[:, 2], cmap='rainbow', 
          c=labels.astype(np.float), edgecolor="k", s=50)
ax.set_xlabel("")
ax.set_ylabel("")
ax.set_zlabel("")
plt.title("K Means", fontsize=14)
# Out:
# Text(0.5,0.92,'K Means')

# %% [markdown]
# ##### ValueError: Colormap blue is not recognized. Possible values are: Accent, Accent_r, Blues, Blues_r, BrBG, BrBG_r, BuGn, BuGn_r, BuPu, BuPu_r, CMRmap, CMRmap_r, Dark2, Dark2_r, GnBu, GnBu_r, Greens, Greens_r, Greys, Greys_r, OrRd, OrRd_r, Oranges, Oranges_r, PRGn, PRGn_r, Paired, Paired_r, Pastel1, Pastel1_r, Pastel2, Pastel2_r, PiYG, PiYG_r, PuBu, PuBuGn, PuBuGn_r, PuBu_r, PuOr, PuOr_r, PuRd, PuRd_r, Purples, Purples_r, RdBu, RdBu_r, RdGy, RdGy_r, RdPu, RdPu_r, RdYlBu, RdYlBu_r, RdYlGn, RdYlGn_r, Reds, Reds_r, Set1, Set1_r, Set2, Set2_r, Set3, Set3_r, Spectral, Spectral_r, Wistia, Wistia_r, YlGn, YlGnBu, YlGnBu_r, YlGn_r, YlOrBr, YlOrBr_r, YlOrRd, YlOrRd_r, afmhot, afmhot_r, autumn, autumn_r, binary, binary_r, bone, bone_r, brg, brg_r, bwr, bwr_r, cividis, cividis_r, cool, cool_r, coolwarm, coolwarm_r, copper, copper_r, cubehelix, cubehelix_r, flag, flag_r, gist_earth, gist_earth_r, gist_gray, gist_gray_r, gist_heat, gist_heat_r, gist_ncar, gist_ncar_r, gist_rainbow, gist_rainbow_r, gist_stern, gist_stern_r, gist_yarg, gist_yarg_r, gnuplot, gnuplot2, gnuplot2_r, gnuplot_r, gray, gray_r, hot, hot_r, hsv, hsv_r, icefire, icefire_r, inferno, inferno_r, jet, jet_r, magma, magma_r, mako, mako_r, nipy_spectral, nipy_spectral_r, ocean, ocean_r, pink, pink_r, plasma, plasma_r, prism, prism_r, rainbow, rainbow_r, rocket, rocket_r, seismic, seismic_r, spring, spring_r, summer, summer_r, tab10, tab10_r, tab20, tab20_r, tab20b, tab20b_r, tab20c, tab20c_r, terrain, terrain_r, viridis, viridis_r, vlag, vlag_r, winter, winter_r

# %% [markdown]
# # to be continued!
